# %% [markdown]
# # 독도라인

# %% [markdown]
#  - skincare12	젤로션
#     skincare21	플루이드
#     skincare29	로션
#     skincare31	미스트
#     skincare36	앰플
#     skincare37	토너
#
#  - skincare11   젤로션 기획
#     skincare22   플루이드 기획
#     skincare34   로션 기획
#     skincare15   토너 대용량 기획
#     skincare35   크림 기획
#     skincare38   토너 + 로션 기획

# %% [markdown]
# ##  독도라인 파일불러오기

# %% [markdown]
# #### 단품

# %%
#skincare12 젤로션
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare12_crc.xlsx"
skincare12_crc_df = pd.read_excel(file_path)
print(skincare12_crc_df)
# Out:
#                                         0
# 0                민감 피부 남자 친구 듯 꾸준히 쓰 있 어요
# 1         신랑 피부 지성 바르 나 뒤 끈적이 않 유분 없 넘 어요
# 2     플라이트 바르 나 시간 지나 유분 때문 너 번들거리 젤 안 어요
# 3                         남자 친구 선물 구매 습니다
# 4                          지성 피부 산뜻 듯 ᆸ니다
# ...                                   ...
# 3229     진하 남자 스킨 향 시원 맑 향 나 아빠 마음 들 시 네요
# 3230                   순하 트러블 없 촉촉하 아주 어요
# 3231                     전 쓰 제품 매우 만족 ᆸ니다
# 3232                   산뜻 유분 없이 촉촉하 발리 어요
# 3233                        인원 하나 바르 되 어요
#
# [3234 rows x 1 columns]

# %%
#skincare21 플루이드
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare21_crc.xlsx"
skincare21_crc_df = pd.read_excel(file_path)
print(skincare21_crc_df)
# Out:
#                                            0
# 0                                  무난 제품 ᆸ니다
# 1                            가격 적당 성분 도매 습니다
# 2                      성분 순하 여름 바르 같 선물 사 어요
# 3                      이거 진짜 안나 오 펌프 오랫동안 어요
# 4                                  교환 가 뻔 어요
# ...                                      ...
# 2202        유명 독도 라인 오 인원 나오 바로 구매 잘 사용 중 에요
# 2203                진짜 포맨 제품 남자 딱 맞추 있 느낌 어요
# 2204  촉촉 끈적이 않 보송 마무리 끈적이 싫 분 정말 딱 맞 제품 같 어요
# 2205             성분 괜찮 보습 크림 선물 주 찾 보 선택 습니다
# 2206                           무난 잘 쓰 있 같 어요
#
# [2207 rows x 1 columns]

# %%
#skincare29 로션
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare29_crc.xlsx"
skincare29_crc_df = pd.read_excel(file_path)
print(skincare29_crc_df)
# Out:
#                                               0
# 0                                 엄청나 순하 제품 ᆸ니다
# 1                           아주 기름지 않 지성인 추천 ᆸ니다
# 2          용량 ml 엄청나 용량 휴대 힘들 화장대 위 올리 놓 쓰 같 어요
# 3                                보습 제품 약하 같 습니다
# 4                    아직 안 쓰 보 여름 가 있 미리 사 보 습니다
# ...                                         ...
# 2341                          저 아빠 쓰 시 사 드리 습니다
# 2342                              항상 쓰 독도 로션 에요
# 2343                                      순하 어요
# 2344                                      굿 ᆸ니다
# 2345  보습 크림 로션 기능 충실히 ᆷ 조금 찐득 남 여름 쓰 저 형 용량 많 다
#
# [2346 rows x 1 columns]

# %%
#skincare31 미스트
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare31_crc.xlsx"
skincare31_crc_df = pd.read_excel(file_path)
print(skincare31_crc_df)
# Out:
#                                                       0
# 0                                        자극 없이 안개 분사 어요
# 1                    이거 쓰 클리니크 쓰 보 분 사력 보 완전 물뿌리개 느낌 네요
# 2                                          독도 미스트 짱 ᆸ니다
# 3                                    냄새 너무 별로 빼 다 괜찮 어요
# 4                                   나쁘 않 굳이 다시 사 않 같 어요
# ...                                                 ...
# 2393          솔직히 보습 쓰 알 후 물 닦 내 토너 패드 팩 쓰 전 피부 진정 쓰 어요
# 2394  쿠션 바르 때 퍼프 번 뿌리 두드리 흡수 다음 메이크업 얇 발리 물 광 피부 연출 ...
# 2395                           속 건조 피부 뿌리 나 확실히 괜찮 같 어요
# 2396                                  분사 뭉치 않 골고루 분사 어요
# 2397                                         흡수 빠르 편 에요
#
# [2398 rows x 1 columns]

# %%
#skincare36 앰플
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare36_crc.xlsx"
skincare36_crc_df = pd.read_excel(file_path)
print(skincare36_crc_df)
# Out:
#                                                       0
# 0                         독도 라인 잘 쓰 있 앰풀 한번 사 보 나쁘 않 네요
# 1     Hydrating serum that has good absorbing proper...
# 2                         굉장히 순하 피부 예민 시 분 적극 추천 드리 ᆸ니다
# 3                                      저희 엄마 가장 좋아하 아이템
# 4                             독도 라인 다 아주 무난하 쓰 제품 매력 매력
# ...                                                 ...
# 2570                                           구매 예정 에요
# 2571                                                크크크
# 2572                                       앰풀 치 끈적 없 어요
# 2573                 물 흐르 느낌 근데 양 생각 없 스포이트 잘 안 되 뿌리 어요
# 2574                                    보습 강 않 바르 촉촉 느낌
#
# [2575 rows x 1 columns]

# %%
#skincare37 토너
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare37_crc.xlsx"
skincare37_crc_df = pd.read_excel(file_path)
print(skincare37_crc_df)
# Out:
#                                                   0
# 0     영양분 공급 오히려 트러블 유발 같 생각 들 아예 투명 듯 보이 토너 사 되 어요
# 1               수분 부족 분 조금 건조 수 있 크림 듬뿍 바르 주 괜찮 더라고
# 2                              년 쓰 있 토너 순하 닦토 너무 어요
# 3                                  좁쌀 많이 줄어들 애용 ᆸ니다
# 4                                         거의 물 같 어요
# ...                                             ...
# 2430                                          입문 괜찮
# 2431                                         추천 ᆸ니다
# 2432    저 사실 올리브 영 위 제품 사 남녀 구분 없이 용량 사 나누 쓰 수 있 네요
# 2433                                       물 막 쓰 어요
# 2434                                 남자 친구 주 궁금하 네요
#
# [2435 rows x 1 columns]

# %%
import pandas as pd

# 데이터프레임을 리스트에 저장(단품)
dataframes_list1 = [
    skincare12_crc_df,
    skincare21_crc_df,
    skincare29_crc_df,
    skincare31_crc_df,
    skincare36_crc_df,
    skincare37_crc_df
]

dataframes_list1
# Out:
# [                                        0
#  0                민감 피부 남자 친구 듯 꾸준히 쓰 있 어요
#  1         신랑 피부 지성 바르 나 뒤 끈적이 않 유분 없 넘 어요
#  2     플라이트 바르 나 시간 지나 유분 때문 너 번들거리 젤 안 어요
#  3                         남자 친구 선물 구매 습니다
#  4                          지성 피부 산뜻 듯 ᆸ니다
#  ...                                   ...
#  3229     진하 남자 스킨 향 시원 맑 향 나 아빠 마음 들 시 네요
#  3230                   순하 트러블 없 촉촉하 아주 어요
#  3231                     전 쓰 제품 매우 만족 ᆸ니다
#  3232                   산뜻 유분 없이 촉촉하 발리 어요
#  3233                        인원 하나 바르 되 어요
#
#  [3234 rows x 1 columns],
#                                             0
#  0                                  무난 제품 ᆸ니다
#  1                            가격 적당 성분 도매 습니다
#  2                      성분 순하 여름 바르 같 선물 사 어요
#  3                      이거 진짜 안나 오 펌프 오랫동안 어요
#  4                                  교환 가 뻔 어요
#  ...                                      ...
#  2202        유명 독도 라인 오 인원 나오 바로 구매 잘 사용 중 에요
# ...

# %% [markdown]
# #### 기획

# %%
#skincare11 젤로션 기획
import pandas as pd
file_path = r"C:\Users\82104\Downloads\제품리뷰전처리\skincare11_crc.xlsx"
skincare11_crc_df = pd.read_excel(file_path)
print(skincare11_crc_df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 4
#       2 import pandas as pd
#       3 file_path = r"C:\Users\82104\Downloads\제품리뷰전처리\skincare11_crc.xlsx"
# ----> 4 skincare11_crc_df = pd.read_excel(file_path)
#       5 print(skincare11_crc_df)
#
# File c:\Users\82108\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
# ...

# %%
#skincare22 플루이드 기획
import pandas as pd
file_path = r"C:\Users\82104\Downloads\제품리뷰전처리\skincare22_crc.xlsx"
skincare22_crc_df = pd.read_excel(file_path)
print(skincare22_crc_df)
# Out:
#                                            0
# 0                                  무난 제품 ᆸ니다
# 1                            가격 적당 성분 도매 습니다
# 2                      성분 순하 여름 바르 같 선물 사 어요
# 3                      이거 진짜 안나 오 펌프 오랫동안 어요
# 4                                  교환 가 뻔 어요
# ...                                      ...
# 2202        유명 독도 라인 오 인원 나오 바로 구매 잘 사용 중 에요
# 2203                진짜 포맨 제품 남자 딱 맞추 있 느낌 어요
# 2204  촉촉 끈적이 않 보송 마무리 끈적이 싫 분 정말 딱 맞 제품 같 어요
# 2205             성분 괜찮 보습 크림 선물 주 찾 보 선택 습니다
# 2206                           무난 잘 쓰 있 같 어요
#
# [2207 rows x 1 columns]

# %%
#skincare34 로션 기획
import pandas as pd
file_path = r"C:\Users\82104\Downloads\제품리뷰전처리\skincare34_crc.xlsx"
skincare34_crc_df = pd.read_excel(file_path)
print(skincare34_crc_df)
# Out:
#                             0
# 0               늘 쓰 독도 로션 ᆸ니다
# 1            자극 않 끈적이 별로 없 어요
# 2     함께 오 여행 로션 아주 잘 쓰 있 답니다
# 3                  남편 쓰 순하 어요
# 4                      용량 습니다
# ...                       ...
# 2378    건성 지성인 분 약간 기름지 수 있 점
# 2379                    유의 세요
# 2380         진짜 트러블 안 나 너무 어요
# 2381     근데 용량 너무 크 개월 넘 쓰 어요
# 2382              그냥 작 싸 만들 주
#
# [2383 rows x 1 columns]

# %%
#skincare15 토너 대용량 기획
import pandas as pd
file_path = r"C:\Users\82104\Downloads\제품리뷰전처리\skincare15_crc.xlsx"
skincare15_crc_df = pd.read_excel(file_path)
print(skincare15_crc_df)
# Out:
#                                               0
# 0                             확실히 아주 무난 사용 같 어요
# 1             만약 토너 뭐 쓰 고민 피부 유형 사용 놓 무난 토너 ᆸ니다
# 2             일단 유명 친구 다 너무 듯 구입 보 일단 짖 발리 같 어요
# 3                                완전 촉촉하 않 너무 어요
# 4                          조금 더 쓰 보 알 지금 만족 ᆸ니다
# ...                                         ...
# 2338                                    꼭 구매 세요
# 2339         매일 매일 꾸준히 닦 주 데 자극 없이 닦이 보습 잘 되 어요
# 2340  크 트러블 안 생기 막 주 같 별다르 향 안 나 호불호 갈리 않 듯 ᆸ니다
# 2341                                 년 사용 중 ᆸ니다
# 2342                     순하 결정 잘 되 어요 가성비 편 ᆸ니다
#
# [2343 rows x 1 columns]

# %%
#skincare35 크림 기획
import pandas as pd
file_path = r"C:\Users\82104\Downloads\제품리뷰전처리\skincare35_crc.xlsx"
skincare35_crc_df = pd.read_excel(file_path)
print(skincare35_crc_df)
# Out:
#                                                       0
# 0                                   추천 구매 보 무난 사용 같 습니다
# 1                                           보습 크림 강력 추천
# 2                                                 순하 어요
# 3                                   향 거의 없 같 완전 무 나 터 ᆷ
# 4                                           순하 보습 크림 에요
# ...                                                 ...
# 2672        독도 토너 리뷰 언급 효과 을까 생각 들 었었 친구 사용 보 정말 괜찮 더라고
# 2673                   다음 무조건 독도 시리즈 사용 보 생각 들 주 경험 습니다
# 2674     우선 보습 크림 크 쫀쫀 제형 묽 제형 있 생각 독도 보습 크림 사이 제형 같 어요
# 2675  너무 쫀쫀 피부 올리 때 좀 답답 느낌 들 묽 제형 수분 완전히 채우 느낌 잘 못 ...
# 2676              복합 기준 사계절 내내 사용 제품 같 딱히 트러블 올라오 없 습니다
#
# [2677 rows x 1 columns]

# %%
#skincare38 토너 + 로션 기획
import pandas as pd
file_path = r"C:\Users\82104\Downloads\제품리뷰전처리\skincare38_crc.xlsx"
skincare38_crc_df = pd.read_excel(file_path)
print(skincare38_crc_df)
# Out:
#                                             0
# 0                  너무 유명 많이 쓰 데일리 무난하 바르 같 어요
# 1     자극 없 토너 그냥 물 느낌 로션 아기 로션 느낌 민감 저 만족 ᆸ니다
# 2                               보습 효과 없 제품 에요
# 3                                 독도 진짜 아주 어요
# 4                              밀착 력 쩔 얇 발리 어요
# ...                                       ...
# 2803                                여름 사용 수 있
# 2804                          가 독도 날 의미 모르 네요
# 2805                         제품명 의미 포함 있 참 네요
# 2806                            생각 크기 작 놀라 어요
# 2807                 하하 스킨 로션 모두 순하 너무 만족 ᆸ니다
#
# [2808 rows x 1 columns]

# %% [markdown]
# # 독도라인 감성분석

# %%
# 형태소 분석기
from konlpy.tag import Okt
okt = Okt()

# SentiWord_Dict.txt 감성사전 불러오기
def load_senti_dict(file_path):
    senti_dict = {}
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split()  # 공백으로 분리
            if len(parts) > 1:
                word = ' '.join(parts[:-1])  # 마지막 항목을 제외한 나머지를 단어로 결합
                score = int(parts[-1])  # 마지막 항목을 점수로 처리
                senti_dict[word] = score
            else:
                print(f"해당 줄을 무시합니다: {line}")
    return senti_dict

# 감성 사전 로드
senti_dict = load_senti_dict(r"C:\Users\82108\Downloads\KnuSentiLex-master(1)\KnuSentiLex-master\SentiWord_Dict.txt")

# 감성 분석 함수 
def analyze_sentiment(text, senti_dict):
    # 형태소 분석
    morphs = okt.morphs(text)
    
    # 감정 점수 계산
    sentiment_score = 0
    for word in morphs:
        if word in senti_dict:  # 단어가 사전에 있는 경우
            sentiment_score += senti_dict[word]
    
    # 점수에 따라 감정 판단
    if sentiment_score > 0:
        return "긍정"
    elif sentiment_score < 0:
        return "부정"
    else:
        return "중립"

# %% [markdown]
# ## 긍정/중립/부정

# %% [markdown]
# #### 단품(리스트)

# %%
#단품 리스트
# 데이터프레임과 이름을 튜플로 저장
dataframes = [
    ("skincare12_crc_df", skincare12_crc_df),
    ("skincare21_crc_df", skincare21_crc_df),
    ("skincare29_crc_df", skincare29_crc_df),
    ("skincare31_crc_df", skincare31_crc_df),
    ("skincare36_crc_df", skincare36_crc_df),
    ("skincare37_crc_df", skincare37_crc_df)
]

results_list = []

# 각 데이터프레임 처리 및 결과 출력
for name, df in dataframes:
    print(f"Processing DataFrame: {name}")
    
    # 텍스트를 리스트로 변환
    skincare_text_list1 = df.iloc[:, 0].astype(str).tolist()
    
    # 감성 분석 수행
    skincare_results1 = [(text, analyze_sentiment(text, senti_dict)) for text in skincare_text_list1]
    
    # 결과 데이터프레임 생성
    skincare_results1_df = pd.DataFrame(skincare_results1, columns=['Text', 'Sentiment'])
    
    # 결과를 리스트에 저장
    results_list.append((name, skincare_results1_df))
    
    # 결과 출력
    print(skincare_results1_df)
    print("\n")  # 각 데이터프레임 결과 사이에 공백 추가
# Out:
# Processing DataFrame: skincare12_crc_df
#                                      Text Sentiment
# 0                민감 피부 남자 친구 듯 꾸준히 쓰 있 어요        긍정
# 1         신랑 피부 지성 바르 나 뒤 끈적이 않 유분 없 넘 어요        중립
# 2     플라이트 바르 나 시간 지나 유분 때문 너 번들거리 젤 안 어요        중립
# 3                         남자 친구 선물 구매 습니다        긍정
# 4                          지성 피부 산뜻 듯 ᆸ니다        중립
# ...                                   ...       ...
# 3229     진하 남자 스킨 향 시원 맑 향 나 아빠 마음 들 시 네요        중립
# 3230                   순하 트러블 없 촉촉하 아주 어요        중립
# 3231                     전 쓰 제품 매우 만족 ᆸ니다        긍정
# 3232                   산뜻 유분 없이 촉촉하 발리 어요        중립
# 3233                        인원 하나 바르 되 어요        중립
#
# [3234 rows x 2 columns]
#
#
# Processing DataFrame: skincare21_crc_df
#                                         Text Sentiment
# 0                                  무난 제품 ᆸ니다        중립
# 1                            가격 적당 성분 도매 습니다        중립
# 2                      성분 순하 여름 바르 같 선물 사 어요        중립
# ...

# %%
# #skincare12
# # 특정 데이터프레임의 결과를 선택하여 출력
# def view_results(results_list, name):
#     for df_name, df in results_list:
#         if df_name == name:
#             print(f"Results for DataFrame: {name}")
#             print(df)
#             break

# # 예시: 특정 데이터프레임의 결과 보기
# view_results(results_list, "skincare12_crc_df")

# %%
# #skincare31
# # 특정 데이터프레임의 결과를 선택하여 출력
# def view_results(results_list, name):
#     for df_name, df in results_list:
#         if df_name == name:
#             print(f"Results for DataFrame: {name}")
#             print(df)
#             break

# # 예시: 특정 데이터프레임의 결과 보기
# view_results(results_list, "skincare31_crc_df")

# %% [markdown]
# #### 단품 하나씩(결과)

# %%
#skincare12 젤로션
skincare12_crc_list = skincare12_crc_df.iloc[:, 0].astype(str).tolist()
skincare12_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare12_crc_list]

# 결과 출력
skincare12_crc_results_df = pd.DataFrame(skincare12_crc_results, columns=['Text', 'Sentiment'])
print(skincare12_crc_results_df)
# Out:
#                                      Text Sentiment
# 0                민감 피부 남자 친구 듯 꾸준히 쓰 있 어요        긍정
# 1         신랑 피부 지성 바르 나 뒤 끈적이 않 유분 없 넘 어요        중립
# 2     플라이트 바르 나 시간 지나 유분 때문 너 번들거리 젤 안 어요        중립
# 3                         남자 친구 선물 구매 습니다        긍정
# 4                          지성 피부 산뜻 듯 ᆸ니다        중립
# ...                                   ...       ...
# 3229     진하 남자 스킨 향 시원 맑 향 나 아빠 마음 들 시 네요        중립
# 3230                   순하 트러블 없 촉촉하 아주 어요        중립
# 3231                     전 쓰 제품 매우 만족 ᆸ니다        긍정
# 3232                   산뜻 유분 없이 촉촉하 발리 어요        중립
# 3233                        인원 하나 바르 되 어요        중립
#
# [3234 rows x 2 columns]

# %%
#skincare21 풀루이드
skincare21_crc_list = skincare21_crc_df.iloc[:, 0].astype(str).tolist()
skincare21_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare21_crc_list]

# 결과 출력
skincare21_crc_results_df = pd.DataFrame(skincare21_crc_results, columns=['Text', 'Sentiment'])
print(skincare21_crc_results_df)
# Out:
#                                         Text Sentiment
# 0                                  무난 제품 ᆸ니다        중립
# 1                            가격 적당 성분 도매 습니다        중립
# 2                      성분 순하 여름 바르 같 선물 사 어요        중립
# 3                      이거 진짜 안나 오 펌프 오랫동안 어요        중립
# 4                                  교환 가 뻔 어요        중립
# ...                                      ...       ...
# 2202        유명 독도 라인 오 인원 나오 바로 구매 잘 사용 중 에요        긍정
# 2203                진짜 포맨 제품 남자 딱 맞추 있 느낌 어요        중립
# 2204  촉촉 끈적이 않 보송 마무리 끈적이 싫 분 정말 딱 맞 제품 같 어요        중립
# 2205             성분 괜찮 보습 크림 선물 주 찾 보 선택 습니다        중립
# 2206                           무난 잘 쓰 있 같 어요        긍정
#
# [2207 rows x 2 columns]

# %%
#skincare29 로션
skincare29_crc_list = skincare29_crc_df.iloc[:, 0].astype(str).tolist()
skincare29_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare29_crc_list]

# 결과 출력
skincare29_crc_results_df = pd.DataFrame(skincare29_crc_results, columns=['Text', 'Sentiment'])
print(skincare29_crc_results_df)
# Out:
#                                            Text Sentiment
# 0                                 엄청나 순하 제품 ᆸ니다        중립
# 1                           아주 기름지 않 지성인 추천 ᆸ니다        중립
# 2          용량 ml 엄청나 용량 휴대 힘들 화장대 위 올리 놓 쓰 같 어요        부정
# 3                                보습 제품 약하 같 습니다        중립
# 4                    아직 안 쓰 보 여름 가 있 미리 사 보 습니다        중립
# ...                                         ...       ...
# 2341                          저 아빠 쓰 시 사 드리 습니다        중립
# 2342                              항상 쓰 독도 로션 에요        중립
# 2343                                      순하 어요        중립
# 2344                                      굿 ᆸ니다        중립
# 2345  보습 크림 로션 기능 충실히 ᆷ 조금 찐득 남 여름 쓰 저 형 용량 많 다        중립
#
# [2346 rows x 2 columns]

# %%
#skincare31 미스트
skincare31_crc_list = skincare31_crc_df.iloc[:, 0].astype(str).tolist()
skincare31_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare31_crc_list]

# 결과 출력
skincare31_crc_results_df = pd.DataFrame(skincare31_crc_results, columns=['Text', 'Sentiment'])
print(skincare31_crc_results_df)
# Out:
#                                                    Text Sentiment
# 0                                        자극 없이 안개 분사 어요        중립
# 1                    이거 쓰 클리니크 쓰 보 분 사력 보 완전 물뿌리개 느낌 네요        중립
# 2                                          독도 미스트 짱 ᆸ니다        중립
# 3                                    냄새 너무 별로 빼 다 괜찮 어요        중립
# 4                                   나쁘 않 굳이 다시 사 않 같 어요        중립
# ...                                                 ...       ...
# 2393          솔직히 보습 쓰 알 후 물 닦 내 토너 패드 팩 쓰 전 피부 진정 쓰 어요        중립
# 2394  쿠션 바르 때 퍼프 번 뿌리 두드리 흡수 다음 메이크업 얇 발리 물 광 피부 연출 ...        중립
# 2395                           속 건조 피부 뿌리 나 확실히 괜찮 같 어요        중립
# 2396                                  분사 뭉치 않 골고루 분사 어요        중립
# 2397                                         흡수 빠르 편 에요        중립
#
# [2398 rows x 2 columns]

# %%
#skincare36 앰플
skincare36_crc_list = skincare36_crc_df.iloc[:, 0].astype(str).tolist()
skincare36_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare36_crc_list]

# 결과 출력
skincare36_crc_results_df = pd.DataFrame(skincare36_crc_results, columns=['Text', 'Sentiment'])
print(skincare36_crc_results_df)
# Out:
#                                                    Text Sentiment
# 0                         독도 라인 잘 쓰 있 앰풀 한번 사 보 나쁘 않 네요        긍정
# 1     Hydrating serum that has good absorbing proper...        중립
# 2                         굉장히 순하 피부 예민 시 분 적극 추천 드리 ᆸ니다        긍정
# 3                                      저희 엄마 가장 좋아하 아이템        중립
# 4                             독도 라인 다 아주 무난하 쓰 제품 매력 매력        중립
# ...                                                 ...       ...
# 2570                                           구매 예정 에요        중립
# 2571                                                크크크        중립
# 2572                                       앰풀 치 끈적 없 어요        중립
# 2573                 물 흐르 느낌 근데 양 생각 없 스포이트 잘 안 되 뿌리 어요        긍정
# 2574                                    보습 강 않 바르 촉촉 느낌        중립
#
# [2575 rows x 2 columns]

# %%
#skincare37 토너
skincare37_crc_list = skincare37_crc_df.iloc[:, 0].astype(str).tolist()
skincare37_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare37_crc_list]

# 결과 출력
skincare37_crc_results_df = pd.DataFrame(skincare37_crc_results, columns=['Text', 'Sentiment'])
print(skincare37_crc_results_df)
# Out:
#                                                Text Sentiment
# 0     영양분 공급 오히려 트러블 유발 같 생각 들 아예 투명 듯 보이 토너 사 되 어요        중립
# 1               수분 부족 분 조금 건조 수 있 크림 듬뿍 바르 주 괜찮 더라고        부정
# 2                              년 쓰 있 토너 순하 닦토 너무 어요        중립
# 3                                  좁쌀 많이 줄어들 애용 ᆸ니다        중립
# 4                                         거의 물 같 어요        중립
# ...                                             ...       ...
# 2430                                          입문 괜찮        중립
# 2431                                         추천 ᆸ니다        중립
# 2432    저 사실 올리브 영 위 제품 사 남녀 구분 없이 용량 사 나누 쓰 수 있 네요        중립
# 2433                                       물 막 쓰 어요        중립
# 2434                                 남자 친구 주 궁금하 네요        긍정
#
# [2435 rows x 2 columns]

# %% [markdown]
# #### 기획전

# %%
#skincare11 젤로션 기획
skincare11_crc_list = skincare11_crc_df.iloc[:, 0].astype(str).tolist()
skincare11_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare11_crc_list]

# 결과 출력
skincare11_crc_results_df = pd.DataFrame(skincare11_crc_results, columns=['Text', 'Sentiment'])
print(skincare11_crc_results_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 #skincare11 젤로션 기획
# ----> 2 skincare11_crc_list = skincare11_crc_df.iloc[:, 0].astype(str).tolist()
#       3 skincare11_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare11_crc_list]
#       5 # 결과 출력
#
# NameError: name 'skincare11_crc_df' is not defined

# %%
#skincare22 플루이드 기획
skincare22_crc_list = skincare22_crc_df.iloc[:, 0].astype(str).tolist()
skincare22_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare22_crc_list]

# 결과 출력
skincare22_crc_results_df = pd.DataFrame(skincare22_crc_results, columns=['Text', 'Sentiment'])
print(skincare22_crc_results_df)
# Out:
#                                         Text Sentiment
# 0                                  무난 제품 ᆸ니다        중립
# 1                            가격 적당 성분 도매 습니다        중립
# 2                      성분 순하 여름 바르 같 선물 사 어요        중립
# 3                      이거 진짜 안나 오 펌프 오랫동안 어요        중립
# 4                                  교환 가 뻔 어요        중립
# ...                                      ...       ...
# 2202        유명 독도 라인 오 인원 나오 바로 구매 잘 사용 중 에요        긍정
# 2203                진짜 포맨 제품 남자 딱 맞추 있 느낌 어요        중립
# 2204  촉촉 끈적이 않 보송 마무리 끈적이 싫 분 정말 딱 맞 제품 같 어요        중립
# 2205             성분 괜찮 보습 크림 선물 주 찾 보 선택 습니다        중립
# 2206                           무난 잘 쓰 있 같 어요        긍정
#
# [2207 rows x 2 columns]

# %%
#skincare34 로션 기획
skincare34_crc_list = skincare34_crc_df.iloc[:, 0].astype(str).tolist()
skincare34_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare34_crc_list]

# 결과 출력
skincare34_crc_results_df = pd.DataFrame(skincare34_crc_results, columns=['Text', 'Sentiment'])
print(skincare34_crc_results_df)
# Out:
#                          Text Sentiment
# 0               늘 쓰 독도 로션 ᆸ니다        중립
# 1            자극 않 끈적이 별로 없 어요        중립
# 2     함께 오 여행 로션 아주 잘 쓰 있 답니다        긍정
# 3                  남편 쓰 순하 어요        중립
# 4                      용량 습니다        중립
# ...                       ...       ...
# 2378    건성 지성인 분 약간 기름지 수 있 점        중립
# 2379                    유의 세요        중립
# 2380         진짜 트러블 안 나 너무 어요        중립
# 2381     근데 용량 너무 크 개월 넘 쓰 어요        중립
# 2382              그냥 작 싸 만들 주        중립
#
# [2383 rows x 2 columns]

# %%
#skincare15 토녀 대용량 기획
skincare15_crc_list = skincare15_crc_df.iloc[:, 0].astype(str).tolist()
skincare15_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare15_crc_list]

# 결과 출력
skincare15_crc_results_df = pd.DataFrame(skincare15_crc_results, columns=['Text', 'Sentiment'])
print(skincare15_crc_results_df)
# Out:
#                                            Text Sentiment
# 0                             확실히 아주 무난 사용 같 어요        중립
# 1             만약 토너 뭐 쓰 고민 피부 유형 사용 놓 무난 토너 ᆸ니다        중립
# 2             일단 유명 친구 다 너무 듯 구입 보 일단 짖 발리 같 어요        긍정
# 3                                완전 촉촉하 않 너무 어요        중립
# 4                          조금 더 쓰 보 알 지금 만족 ᆸ니다        긍정
# ...                                         ...       ...
# 2338                                    꼭 구매 세요        중립
# 2339         매일 매일 꾸준히 닦 주 데 자극 없이 닦이 보습 잘 되 어요        긍정
# 2340  크 트러블 안 생기 막 주 같 별다르 향 안 나 호불호 갈리 않 듯 ᆸ니다        중립
# 2341                                 년 사용 중 ᆸ니다        중립
# 2342                     순하 결정 잘 되 어요 가성비 편 ᆸ니다        긍정
#
# [2343 rows x 2 columns]

# %%
#skincare35 크림 기획
skincare35_crc_list = skincare35_crc_df.iloc[:, 0].astype(str).tolist()
skincare35_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare35_crc_list]

# 결과 출력
skincare35_crc_results_df = pd.DataFrame(skincare35_crc_results, columns=['Text', 'Sentiment'])
print(skincare35_crc_results_df)
# Out:
#                                                    Text Sentiment
# 0                                   추천 구매 보 무난 사용 같 습니다        중립
# 1                                           보습 크림 강력 추천        중립
# 2                                                 순하 어요        중립
# 3                                   향 거의 없 같 완전 무 나 터 ᆷ        중립
# 4                                           순하 보습 크림 에요        중립
# ...                                                 ...       ...
# 2672        독도 토너 리뷰 언급 효과 을까 생각 들 었었 친구 사용 보 정말 괜찮 더라고        긍정
# 2673                   다음 무조건 독도 시리즈 사용 보 생각 들 주 경험 습니다        중립
# 2674     우선 보습 크림 크 쫀쫀 제형 묽 제형 있 생각 독도 보습 크림 사이 제형 같 어요        중립
# 2675  너무 쫀쫀 피부 올리 때 좀 답답 느낌 들 묽 제형 수분 완전히 채우 느낌 잘 못 ...        긍정
# 2676              복합 기준 사계절 내내 사용 제품 같 딱히 트러블 올라오 없 습니다        중립
#
# [2677 rows x 2 columns]

# %%
#skincare38 토너 + 로션 기획
skincare38_crc_list = skincare38_crc_df.iloc[:, 0].astype(str).tolist()
skincare38_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare38_crc_list]

# 결과 출력
skincare38_crc_results_df = pd.DataFrame(skincare38_crc_results, columns=['Text', 'Sentiment'])
print(skincare38_crc_results_df)
# Out:
#                                          Text Sentiment
# 0                  너무 유명 많이 쓰 데일리 무난하 바르 같 어요        중립
# 1     자극 없 토너 그냥 물 느낌 로션 아기 로션 느낌 민감 저 만족 ᆸ니다        긍정
# 2                               보습 효과 없 제품 에요        중립
# 3                                 독도 진짜 아주 어요        중립
# 4                              밀착 력 쩔 얇 발리 어요        중립
# ...                                       ...       ...
# 2803                                여름 사용 수 있        중립
# 2804                          가 독도 날 의미 모르 네요        중립
# 2805                         제품명 의미 포함 있 참 네요        중립
# 2806                            생각 크기 작 놀라 어요        중립
# 2807                 하하 스킨 로션 모두 순하 너무 만족 ᆸ니다        긍정
#
# [2808 rows x 2 columns]

# %% [markdown]
# ## 긍정/부정/중립 리스트 만들기

# %% [markdown]
# #### 단품(리스트)

# %%
import pandas as pd
from konlpy.tag import Okt

# 형태소 분석기 초기화
okt = Okt()

# 감성 분석 함수 정의
def analyze_sentiment(text, senti_dict):
    # 형태소 분석
    morphs = okt.morphs(text)
    
    # 감정 점수 계산
    sentiment_score = 0
    for word in morphs:
        if word in senti_dict:  # 단어가 사전에 있는 경우
            sentiment_score += senti_dict[word]
    
    # 점수에 따라 감정 판단
    if sentiment_score > 0:
        return "긍정"
    elif sentiment_score < 0:
        return "부정"
    else:
        return "중립"


# 데이터프레임과 이름을 튜플로 저장
dataframes = [
    ("skincare12_crc_df", skincare12_crc_df),
    ("skincare21_crc_df", skincare21_crc_df),
    ("skincare29_crc_df", skincare29_crc_df),
    ("skincare31_crc_df", skincare31_crc_df),
    ("skincare36_crc_df", skincare36_crc_df),
    ("skincare37_crc_df", skincare37_crc_df)
]

# 결과를 저장할 딕셔너리 (각 데이터프레임별로)
results_dict = {}

# 각 데이터프레임 처리 및 감정 분석 수행
for name, df in dataframes:
    print(f"Processing DataFrame: {name}")
    
    # 텍스트를 리스트로 변환
    text_list = df.iloc[:, 0].astype(str).tolist()
    
    # 긍정, 부정, 중립 리스트 초기화
    positive_list = []
    negative_list = []
    neutral_list = []
    
    # 감성 분석 수행 및 리스트에 저장
    for text in text_list:
        sentiment = analyze_sentiment(text, senti_dict)
        if sentiment == "긍정":
            positive_list.append(text)
        elif sentiment == "부정":
            negative_list.append(text)
        else:
            neutral_list.append(text)
    
    # 결과를 각 데이터프레임 이름별로 저장
    results_dict[name] = {
        "긍정": positive_list,
        "부정": negative_list,
        "중립": neutral_list
    }
# Out:
# Processing DataFrame: skincare12_crc_df
# Processing DataFrame: skincare21_crc_df
# Processing DataFrame: skincare29_crc_df
# Processing DataFrame: skincare31_crc_df
# Processing DataFrame: skincare36_crc_df
# Processing DataFrame: skincare37_crc_df

# %%
results_dict['skincare21_crc_df']
# Out:
# {'긍정': ['지성 피부 복합 잘 맞 같 어요',
#   '오늘 오늘 하루 잘 보내 시',
#   '남편 잘 쓰 있 어요',
#   '피부 잘 맞 네요',
#   '남자 친구 선물 주 어요',
#   '무난 잘 사용 수 있 같 어요',
#   '흡수 잘 되 어쩌 때 볼 쪽 건조 었었 많이 바르 괜찮 더라고',
#   '올리브 영 구매 제품 중 가장 만족 ᆸ니다',
#   '친구 선물 주 굉장히 마음 들 네요',
#   '올리브 영 물건 자주 시키 배송 빠르 포장 안전 오 믿음 가 어요',
#   '감사 ᆸ니다',
#   '자극 없 유분 많 않 복합 잘 맞 어요',
#   '저 쓰 보 브랜드 괜찮 남자 친구 사 어요',
#   '남자 친구 잘 맞 네요',
#   '아주 잘 어요',
#   '아주 만족 ᆸ니다',
#   '개 바르 귀찮 사람 필수 저 남자 친구 추천 어요',
#   '아들 아빠 함께 사용 어요',
#   '인원 사용 편리 어요',
#   '자극 없 잘 모르 어요',
#   '남자 친구 사용 데 어요',
#   '남자 친구 선물 주 엄청 마음 들 어요',
#   '만족',
#   '좋아하 잘 쓰 있 어요 굿',
#   '특별 잘 모르 어요',
#   '최고 흐흐흐',
#   '독도 라인 쓰 라인 역시 순하 보습 잘 되 같 어요',
#   '피부 관리 관심 없 남동생 사 주 잘 쓰 더라고요',
#   '독도 토너 너무 너무 유명 남자 친구 사 주 어요',
#   '남자 친구 사 주 이거 바르 피부 쫀득쫀득 너무 좋아하 네요',
#   '군대 가 오빠 엄마 주 제품 남자 얼굴 로션 잘 안 바르 수 있 이거 간단 바르 같 굿 에요',
#   '잘 사용 습니다',
#   '남자 친구 남동생 선물 올인 원 귀찮 사람 시간 아끼 주 같 매우 만족 습니다',
#   '군대 가 동생 사 주 잘 쓰 있 대',
#   '꾸준히 사용 중 알 ᆸ니다',
#   '만족 ᆸ니다',
# ...

# %%
#결과 수 확인
df_name = 'skincare12_crc_df'

if df_name in results_dict:
    # 긍정 항목의 수 출력
    positive_count = len(results_dict[df_name]['긍정'])
    print(f"긍정 항목의 수 for {df_name}: {positive_count}")

    # 부정 항목의 수 출력
    negative_count = len(results_dict[df_name]['부정'])
    print(f"부정 항목의 수 for {df_name}: {negative_count}")

    # 중립 항목의 수 출력
    neutral_count = len(results_dict[df_name]['중립'])
    print(f"중립 항목의 수 for {df_name}: {neutral_count}")

    # 전체 항목의 수 계산 및 출력
    total_count = positive_count + negative_count + neutral_count
    print(f"\n전체 항목의 수 for {df_name}: {total_count}")
else:
    print(f"No results found for {df_name}")
# Out:
# 긍정 항목의 수 for skincare12_crc_df: 690
# 부정 항목의 수 for skincare12_crc_df: 119
# 중립 항목의 수 for skincare12_crc_df: 2425
#
# 전체 항목의 수 for skincare12_crc_df: 3234

# %%
#부정
# 특정 데이터프레임의 긍정, 부정, 중립 결과를 한 번에 출력하는 코드
df_name = 'skincare21_crc_df'

if df_name in results_dict:
    #print(f"긍정 리스트 for {df_name}:")
    #for item in results_dict[df_name]['긍정']:
        #print(f"- {item}")
    
    print("\n부정 리스트:")
    for item in results_dict[df_name]['부정']:
        print(f"- {item}")

    #print("\n중립 리스트:")
    #for item in results_dict[df_name]['중립']:
        #print(f"- {item}")
else:
    print(f"No results found for {df_name}")
# Out:
# 부정 리스트:
# - 선물 구매 무난하 부담 없이 사용 수 있 ᆸ니다
# - 사실 번째 구매 오 인원 부담 없이 쓱 챙기 여행 가 로션 못 챙기 때 빌리 쓰 부담 없 어요
# - 다만 피부 유형 따르 일부 사용자 보습 다소 부족 느끼 수 있 습니다
# - 남편 끈적이 딱 질색 무조건 산뜻 사 는데요
# - 부족 부분 로션 채우 되 같 어요
# - 로션 뜻 많 불편 보습 감 흡수력 어요
# - 복합 피부 쓰 사용 후 속 건조 잡히 않 느낌 있 독 로션 비 유분 있 음
# - 저 끈적이 혐오 피부 아무것 안 바르 남친 거의 반 강제 바르 하나 안 끈적이 매일 나 스스로 바르 더라고요
# - 처음 사용 보 로션 원하 느낌 로션 부담 없이 매일 사용 있 어요
# - 화 앱 로션 검색 찾 제품 왜 포맨 나오 모르 남녀노소 사용 제품 듯 ᆸ니다
# - 번 사 두 최소 개월 걱정 없 습니다
# - 불만 없이 사용 보 아주 아이템 보 ᆸ니다
# - 유동 보습 살짝 부족 같 무난 인원 피부 관리 찾 으시 나쁘 않 같 어요
# - 여행 가 때 사용 사 짐 덜 수 있 어요
# - 피부 만지 보 뭐 나 않 뭐 수분 부족 꺼칠꺼 칠하 약값 긴가민가 본인 괜찮
# - 보습 자극 없이 순하 아침 메이크업 전 부담 없이 사영 어요
# - 남자 친구 사용 중 오 인원 편하 부담 없 네요
# - 저 몰래 쓰 보 휘뚜루마뚜루 쓰 너무 어요
# - 보습 순하 너무 않 부담 없이 사용 습니다
# - 보습 순하 너무 않 부담 없이 사용 습니다
# - 튜브 형 불편 시 통 있 다 쓰 시 쭉 짜 통 채우 쓰 시 되 같 어요
# - 남자 친구 사 그냥 막 바르 부담 없이 데일리 바르 어요
# - 사실 토너 사 잘못 사 반품 번 쓰 너무 계속 쓰 있 어요
# - 순하 부담 없 굿
# - 유리병 좀 편 펌프 용기 깔끔 ᆸ니다
# - 이것 부족 느끼 않 어요
# - 인원 편하 남자 화장품 독 냄새 없 어요
# - 순하 막 바르 부담 없이 바르 어요
# - 수분 부족 지성 예민 피부 바르 음
# ...

# %%
#긍정
# 특정 데이터프레임의 긍정, 부정, 중립 결과를 한 번에 출력하는 코드
df_name = 'skincare12_crc_df'

if df_name in results_dict:
    print(f"긍정 리스트 for {df_name}:")
    for item in results_dict[df_name]['긍정']:
        print(f"- {item}")
    
    # print("\n부정 리스트:")
    # for item in results_dict[df_name]['부정']:
    #     print(f"- {item}")

    # print("\n중립 리스트:")
    # for item in results_dict[df_name]['중립']:
    #     print(f"- {item}")
else:
    print(f"No results found for {df_name}")
# Out:
# 긍정 리스트 for skincare12_crc_df:
# - 민감 피부 남자 친구 듯 꾸준히 쓰 있 어요
# - 남자 친구 선물 구매 습니다
# - 보습 잘 주 너무 유분 있 만족 ᆸ니다
# - 없이 피부 잘 같 또 주문 습니다
# - 제품 쓰 가격 계속 올리 대안 제품 찾 번 사용 이후 꾸준히 구매 중 ᆸ니다
# - 선물 구매 순 잘 쓰 더라고
# - 저 극구 극 지성 이거 잘 쓰 있 습니다
# - 없이 잘 사용 있 어요
# - 앰풀 발리 산뜻 다 흡수 마무리 만족 ᆸ니다
# - 남자 친구 군대 가 이거 추천 주 올 인원 쓰 편하 네요
# - 동생 피부 관리 잘 안 사 주 어요
# - 남자 친구 선물 구매 어요
# - 친구 따르 남성 인원 제품 사 보 습니다
# - 스킨 로션 합치 제품 편리 ᆸ니다
# - 친구 쓰 보 보이 사 보 어요
# - 보송보송 아직 문제없이 잘 쓰 있 습니다
# - 남자 친구 구 잘 쓰 있 만족 네요
# - 남자 친구 선물 사 주 피붓결 느끼 어요
# - 잘 쓰 중 같 어요
# - 남자 친구 인원 제품 좋아하 독도 라인 순 좋아하 구매 어요
# - 열심히 자기 루틴 맞 잘 사용 중 더라고
# - 남편 사 주 잘 쓰 있 습니다
# - 아빠 올 인원 쓰 사 보 바르 편하 순하 잘 사용 있 어요
# - 남자 친구 선물 구매 너무 듯 어요
# - 짤 타입 쓰 편하 남자 친구 어요
# - 순하 촉촉 흡수 잘 되 ᆸ니다
# - 남자 친구 제형 안 좋아하 사 주 흡수 빠르 데요
# - 신랑 잘 쓰 있 네요
# - 예민 편 얼굴 트러블 없이 잘 쓰 있 중
# - 이거 저거 바르 귀찮 요즘 종류 줄이 트렌드 시도 보 잘 살 같 어요
# - 남자 친구 엄청나 잘 사용 있 습니다
# - 피부 아주 민감 남자 친구 이거
# - 잘 맞 어요
# - 만족 ᆷ
# - 이벤트 할인 구매 저렴하 잘 사 어요
# - 잘 바르 다니 던데
# - 이것저것 바르 귀찮 으시 분 최고 듯
# - 잘 사용 있 어요
# - 남자 친구 지성 피부 제품 구매 습니다
# ...

# %% [markdown]
# #### 단품(테스트)

# %%
# 긍정, 부정, 중립 리스트 생성
positive_list = []
negative_list = []
neutral_list = []

# 각 텍스트에 대해 감정 분석을 수행하고 리스트에 저장
for text in skincare12_crc_list:
    sentiment = analyze_sentiment(text, senti_dict)
    if sentiment == "긍정":
        positive_list.append(text)
    elif sentiment == "부정":
        negative_list.append(text)
    else:
        neutral_list.append(text)

# 각 리스트 출력
print("긍정 리스트:")
print(positive_list)

print("\n부정 리스트:")
print(negative_list)

print("\n중립 리스트:")
print(neutral_list)
# Out:
# 긍정 리스트:
# ...

# %%
# 긍정, 부정, 중립 리스트 생성
positive_list = []
negative_list = []
neutral_list = []

# 각 텍스트에 대해 감정 분석을 수행하고 리스트에 저장
for text in skincare12_crc_list:
    sentiment = analyze_sentiment(text, senti_dict)
    if sentiment == "긍정":
        positive_list.append(text)
    elif sentiment == "부정":
        negative_list.append(text)
    else:
        neutral_list.append(text)

# 각 리스트 출력
print("긍정 리스트:")
print(positive_list)

print("\n부정 리스트:")
print(negative_list)

print("\n중립 리스트:")
print(neutral_list)
# Out:
# 긍정 리스트:
# ...

# %% [markdown]
# ## 엑셀로 저장

# %%
#단품 리스트
import pandas as pd

# 결과를 저장할 경로 설정
output_dir = r"C:\Users\82108\Downloads"

# 각 데이터프레임 처리 및 엑셀 파일로 저장
for df_name in results_dict:
    # 긍정 리스트를 데이터프레임으로 변환 및 저장
    skincare_positive_df = pd.DataFrame({'Text': results_dict[df_name]['긍정']})
    skincare_positive_df.to_excel(f"{output_dir}\{df_name}_positive_list_D.xlsx", index=False)

    # 부정 리스트를 데이터프레임으로 변환 및 저장
    skincare_negative_df = pd.DataFrame({'Text': results_dict[df_name]['부정']})
    skincare_negative_df.to_excel(f"{output_dir}\{df_name}_negative_list_D.xlsx", index=False)

    # 중립 리스트를 데이터프레임으로 변환 및 저장
    #skincare_neutral_df = pd.DataFrame({'Text': results_dict[df_name]['중립']})
    #skincare_neutral_df.to_excel(f"{output_dir}\{df_name}_neutral_list.xlsx", index=False)

    print(f"{df_name} 데이터프레임의 긍정, 부정, 중립 리스트가 각각 엑셀 파일로 저장되었습니다.")
# Out:
# skincare12_crc_df 데이터프레임의 긍정, 부정, 중립 리스트가 각각 엑셀 파일로 저장되었습니다.
# skincare21_crc_df 데이터프레임의 긍정, 부정, 중립 리스트가 각각 엑셀 파일로 저장되었습니다.
# skincare29_crc_df 데이터프레임의 긍정, 부정, 중립 리스트가 각각 엑셀 파일로 저장되었습니다.
# skincare31_crc_df 데이터프레임의 긍정, 부정, 중립 리스트가 각각 엑셀 파일로 저장되었습니다.
# skincare36_crc_df 데이터프레임의 긍정, 부정, 중립 리스트가 각각 엑셀 파일로 저장되었습니다.
# skincare37_crc_df 데이터프레임의 긍정, 부정, 중립 리스트가 각각 엑셀 파일로 저장되었습니다.

# %% [markdown]
# # 독도라인 빈도분석

# %% [markdown]
# ## 엑셀파일 불러오기

# %%
import pandas as pd

# 불러올 파일 경로 설정
output_dir = r"C:\Users\82108\Downloads"

# 불러올 데이터프레임 목록
df_names = [
    'skincare12_crc_df',
    'skincare21_crc_df',
    'skincare29_crc_df',
    'skincare31_crc_df',
    'skincare36_crc_df',
    'skincare37_crc_df'
]

# 각 데이터프레임 이름별로 데이터를 불러와 개별 변수에 저장
for df_name in df_names:
    # 긍정 리스트 엑셀 파일 불러오기
    positive_df = pd.read_excel(f"{output_dir}\{df_name}_positive_list_D.xlsx")
    positive_var_name = f"{df_name.replace('_df', '')}_positive_list_df"
    globals()[positive_var_name] = positive_df

    # 부정 리스트 엑셀 파일 불러오기
    negative_df = pd.read_excel(f"{output_dir}\{df_name}_negative_list_D.xlsx")
    negative_var_name = f"{df_name.replace('_df', '')}_negative_list_df"
    globals()[negative_var_name] = negative_df

    # 중립 리스트 엑셀 파일 불러오기 (필요한 경우)
    # neutral_df = pd.read_excel(f"{output_dir}\{df_name}_neutral_list.xlsx")
    # neutral_var_name = f"{df_name.replace('_df', '')}_neutral_list_df"
    # globals()[neutral_var_name] = neutral_df

# 예시: skincare12_crc_positive_list_df 출력해보기
print(skincare12_crc_positive_list_df.head())
print(skincare12_crc_negative_list_df.head())
# Out:
#                                          Text
# 0                    민감 피부 남자 친구 듯 꾸준히 쓰 있 어요
# 1                             남자 친구 선물 구매 습니다
# 2                       보습 잘 주 너무 유분 있 만족 ᆸ니다
# 3                          없이 피부 잘 같 또 주문 습니다
# 4  제품 쓰 가격 계속 올리 대안 제품 찾 번 사용 이후 꾸준히 구매 중 ᆸ니다
#                                                 Text
# 0                        항상 피부 뒤집히 걱정 안 쓰 수 있 무난 터 ᆷ
# 1                     수분 부족 지성 산뜻 습니다 수분 조금 부족 여름 어요
# 2                    너무 묽 지성 여름 쓰 그거 조금 부족 번 바르 같 어요
# 3          알 리뷰 보 구매 편 걱정 안 저 옆 한번 테스트 보 괜찮 기억 있 습니다
# 4  순하 보습 느끼 제형 민감 피부 부담 없이 사용 제형 가지 있 또한 유분 주 피지 ...

# %%
print(skincare31_crc_positive_list_df.head())
print(skincare31_crc_negative_list_df.head())
# Out:
#                                Text
# 0                          분사 나름 만족
# 1                       하하 잘 구매 습니다
# 2                             감사 어요
# 3           라운드 랩 워낙 순하 제품 잘 쓰 있 어요
# 4  기대 없이 사 안개 분사 스타일 골고루 나오 쓰 편하 네요
#                                    Text
# 0  통 쓰 무난 템 무난 데 없 불안 정도 기초 일 단계 미스트 예요
# 1                          두통 쓰 있 너무 어요
# 2  저 지성 로션 앰풀 바르 바로 유분 올라오 스트레스 이거 하나 안
# 3       저 살짝 붉 기 올라오 걱정 쓰 보 괜찮 사용 중 ᆸ니다
# 4              얼마나 쓰 모르 순하 부담 없 타입 같 어요

# %%
#긍정리스트
positive_list_dfs = [skincare12_crc_positive_list_df, skincare21_crc_positive_list_df, skincare29_crc_positive_list_df, skincare31_crc_positive_list_df, skincare36_crc_positive_list_df, skincare37_crc_positive_list_df]
positive_list_dfs
# Out:
# [                                           Text
#  0                      민감 피부 남자 친구 듯 꾸준히 쓰 있 어요
#  1                               남자 친구 선물 구매 습니다
#  2                         보습 잘 주 너무 유분 있 만족 ᆸ니다
#  3                            없이 피부 잘 같 또 주문 습니다
#  4    제품 쓰 가격 계속 올리 대안 제품 찾 번 사용 이후 꾸준히 구매 중 ᆸ니다
#  ..                                          ...
#  685                            잘 사용 중 다음 구매 려고요
#  686                                      최고 ᆸ니다
#  687                       바르 때 쫙 흡수 유분 잘 주 같 어요
#  688             아침 따로 필요 없이 오 인원 필요 구매 데 만족 ᆸ니다
#  689                            전 쓰 제품 매우 만족 ᆸ니다
#
#  [690 rows x 1 columns],
#                                   Text
#  0                   지성 피부 복합 잘 맞 같 어요
#  1                     오늘 오늘 하루 잘 보내 시
#  2                         남편 잘 쓰 있 어요
#  3                           피부 잘 맞 네요
#  4                       남자 친구 선물 주 어요
#  ..                                ...
#  507             남자 친구 선물 주 올 인원 제품 네요
# ...

# %%
#부정리스트
negative_list_dfs = [skincare12_crc_negative_list_df, skincare21_crc_negative_list_df, skincare29_crc_negative_list_df, skincare31_crc_negative_list_df, skincare36_crc_negative_list_df, skincare37_crc_negative_list_df]
negative_list_dfs
# Out:
# [                                                  Text
#  0                          항상 피부 뒤집히 걱정 안 쓰 수 있 무난 터 ᆷ
#  1                       수분 부족 지성 산뜻 습니다 수분 조금 부족 여름 어요
#  2                      너무 묽 지성 여름 쓰 그거 조금 부족 번 바르 같 어요
#  3            알 리뷰 보 구매 편 걱정 안 저 옆 한번 테스트 보 괜찮 기억 있 습니다
#  4    순하 보습 느끼 제형 민감 피부 부담 없이 사용 제형 가지 있 또한 유분 주 피지 ...
#  ..                                                 ...
#  114                    독 토너 마니아 라운드 랩 제품 의심 없이 늘 구입 어요
#  115  남성 젤로서니라 향 세 어떡하 걱정 남녀노소 다 쓰 되 정도 순하 향 거의 없 편 ᆸ니다
#  116                      독 다 쓰 때 엄마 화장품 가지 이야기 없 으시 어요
#  117                                    점성 부담 없이 바르 같 음
#  118         향 전혀 부담 없 끈적이 없 운동 후 샤워 쓰 올 인원 로션 아주 제격 네요
#
#  [119 rows x 1 columns],
#                                                   Text
#  0                          선물 구매 무난하 부담 없이 사용 수 있 ᆸ니다
#  1   사실 번째 구매 오 인원 부담 없이 쓱 챙기 여행 가 로션 못 챙기 때 빌리 쓰 부...
#  2              다만 피부 유형 따르 일부 사용자 보습 다소 부족 느끼 수 있 습니다
# ...

# %% [markdown]
# ## 긍정(30개 추출)

# %%
import pandas as pd
from collections import Counter

positive_list_dfs = [
    ('skincare12_crc_positive_list_df', skincare12_crc_positive_list_df),
    ('skincare21_crc_positive_list_df', skincare21_crc_positive_list_df),
    ('skincare29_crc_positive_list_df', skincare29_crc_positive_list_df),
    ('skincare31_crc_positive_list_df', skincare31_crc_positive_list_df),
    ('skincare36_crc_positive_list_df', skincare36_crc_positive_list_df),
    ('skincare37_crc_positive_list_df', skincare37_crc_positive_list_df)
]

positive_list_df_results = []

# 각 데이터프레임을 순차적으로 처리합니다.
for name, df in positive_list_dfs:
    # 텍스트 열에서 단어를 추출하여 리스트로 만듭니다.
    words = df['Text'].str.split().sum()
    
    # 단어 빈도 계산
    words_freq = Counter(words)
    
    # 빈도 데이터를 데이터프레임으로 변환하고 정렬합니다.
    words_freq_df = pd.DataFrame(words_freq.items(), columns=['단어', '빈도']).sort_values(by='빈도', ascending=False).reset_index(drop=True)
    
    # 결과를 리스트에 추가합니다.
    positive_list_df_results.append((name, words_freq_df))

# 각 데이터프레임의 결과를 출력합니다. (예를 들어, 상위 10개 단어를 출력)
for name, positive_list_result_df in positive_list_df_results:
    print(f"{name}의 상위 10개 단어:")
    print(positive_list_result_df.head(10))
    print("\n")
# Out:
# skincare12_crc_positive_list_df의 상위 10개 단어:
#     단어   빈도
# 0    잘  326
# 1   어요  260
# 2    있  184
# 3    쓰  179
# 4   사용  143
# 5  ᆸ니다  143
# 6   만족  133
# 7   바르  132
# 8   남자  123
# 9   피부  120
#
#
# skincare21_crc_positive_list_df의 상위 10개 단어:
#    단어   빈도
# 0   잘  271
# 1  어요  197
# 2   쓰  160
# 3  친구  156
# 4  남자  147
# 5   있  123
# 6   사  119
# 7   주  116
# 8  사용   98
# 9  바르   81
#
#
# skincare29_crc_positive_list_df의 상위 10개 단어:
#     단어   빈도
# 0    잘  246
# 1   어요  156
# 2    쓰  153
# 3    있  113
# 4  ᆸ니다   81
# 5   순하   75
# 6   사용   71
# 7   로션   63
# 8  습니다   54
# 9   만족   53
#
#
# skincare31_crc_positive_list_df의 상위 10개 단어:
#     단어   빈도
# 0    잘  221
# 1   어요  190
# 2    쓰  102
# 3   분사   92
# 4    있   80
# 5   뿌리   75
# 6  미스트   71
# 7    되   69
# 8    주   58
# 9   만족   56
#
#
# skincare36_crc_positive_list_df의 상위 10개 단어:
#     단어   빈도
# 0    잘  281
# 1   어요  215
# 2    쓰  151
# 3    있  112
# 4   피부  103
# 5   사용  103
# 6    되  102
# 7  ᆸ니다   98
# 8    같   85
# ...

# %%
# 특정 데이터프레임의 긍정 키워드만 보고 싶다면
def print_keywords_by_name(df_name):
    # 결과 리스트에서 특정 데이터프레임의 이름과 결과를 찾습니다.
    for name, result_df in positive_list_df_results:
        if name == df_name:
            print(f"{name}의 상위 30개 단어:")
            print(result_df.head(30))
            break
    else:
        print(f"{df_name} 데이터프레임을 찾을 수 없습니다.")

print_keywords_by_name('skincare12_crc_positive_list_df')
# Out:
# skincare12_crc_positive_list_df의 상위 30개 단어:
#      단어   빈도
# 0     잘  326
# 1    어요  260
# 2     있  184
# 3     쓰  179
# 4    사용  143
# 5   ᆸ니다  143
# 6    만족  133
# 7    바르  132
# 8    남자  123
# 9    피부  120
# 10   인원  120
# 11   제품  118
# 12    주  113
# 13   친구  109
# 14    같   90
# 15    되   90
# 16   독도   83
# 17   네요   79
# 18   선물   72
# 19  습니다   69
# 20   로션   69
# 21    보   69
# 22   보습   62
# 23   구매   56
# 24    사   55
# 25   너무   54
# 26    않   52
# 27   흡수   52
# 28   지성   50
# 29   순하   50

# %%
# print_keywords_by_name('skincare36_crc_positive_list_df')

# %% [markdown]
# ## 부정 추출

# %%
import pandas as pd
from collections import Counter

negative_list_dfs = [
    ('skincare12_crc_negative_list_df', skincare12_crc_negative_list_df),
    ('skincare21_crc_negative_list_df', skincare21_crc_negative_list_df),
    ('skincare29_crc_negative_list_df', skincare29_crc_negative_list_df),
    ('skincare31_crc_negative_list_df', skincare31_crc_negative_list_df),
    ('skincare36_crc_negative_list_df', skincare36_crc_negative_list_df),
    ('skincare37_crc_negative_list_df', skincare37_crc_negative_list_df)
]

negative_list_df_results = []

# 각 데이터프레임을 순차적으로 처리합니다.
for name, df in negative_list_dfs:
    # 텍스트 열에서 단어를 추출하여 리스트로 만듭니다.
    words = df['Text'].str.split().sum()
    
    # 단어 빈도 계산
    words_freq = Counter(words)
    
    # 빈도 데이터를 데이터프레임으로 변환하고 정렬합니다.
    words_freq_df = pd.DataFrame(words_freq.items(), columns=['단어', '빈도']).sort_values(by='빈도', ascending=False).reset_index(drop=True)
    
    # 결과를 리스트에 추가합니다.
    negative_list_df_results.append((name, words_freq_df))

# 각 데이터프레임의 결과를 출력합니다. (예를 들어, 상위 10개 단어를 출력)
for name, negative_list_result_df in negative_list_df_results:
    print(f"{name}의 상위 10개 단어:")
    print(negative_list_result_df.head(10))
    print("\n")
# Out:
# skincare12_crc_negative_list_df의 상위 10개 단어:
#    단어  빈도
# 0  어요  50
# 1  부족  44
# 2   쓰  33
# 3  바르  32
# 4  보습  31
# 5  사용  30
# 6   있  30
# 7  없이  28
# 8  부담  27
# 9   향  27
#
#
# skincare21_crc_negative_list_df의 상위 10개 단어:
#    단어  빈도
# 0  어요  31
# 1  부족  20
# 2   있  18
# 3  바르  18
# 4   쓰  17
# 5  부담  16
# 6  사용  16
# 7  피부  14
# 8   같  13
# 9  보습  13
#
#
# skincare29_crc_negative_list_df의 상위 10개 단어:
#    단어  빈도
# 0  어요  50
# 1   쓰  40
# 2  로션  29
# 3  부담  26
# 4  사용  23
# 5  부족  20
# 6   있  20
# 7  없이  20
# 8  순하  19
# 9  지성  18
#
#
# skincare31_crc_negative_list_df의 상위 10개 단어:
#     단어  빈도
# 0   어요  38
# 1    쓰  22
# 2   부담  22
# 3  미스트  20
# 4   뿌리  20
# 5   피부  20
# 6   수분  19
# 7    있  19
# 8   부족  18
# 9   사용  18
#
#
# skincare36_crc_negative_list_df의 상위 10개 단어:
#    단어  빈도
# 0  어요  56
# 1  부족  56
# 2  피부  42
# 3   쓰  42
# 4  수분  41
# 5  지성  35
# 6   있  32
# 7  바르  31
# 8   같  28
# 9  보습  26
#
#
# skincare37_crc_negative_list_df의 상위 10개 단어:
#    단어  빈도
# 0  어요  42
# ...

# %%
# 특정 데이터프레임의 부정 키워드만 보고 싶다면
def print_keywords_by_name(df_name):
    # 결과 리스트에서 특정 데이터프레임의 이름과 결과를 찾습니다.
    for name, result_df in negative_list_df_results:
        if name == df_name:
            print(f"{name}의 상위 30개 단어:")
            print(result_df.head(30))
            break
    else:
        print(f"{df_name} 데이터프레임을 찾을 수 없습니다.")

# 예: 'skincare12_crc_negative_list_df'의 상위 30개 단어 출력
print_keywords_by_name('skincare12_crc_negative_list_df')
# Out:
# skincare12_crc_negative_list_df의 상위 30개 단어:
#      단어  빈도
# 0    어요  50
# 1    부족  44
# 2     쓰  33
# 3    바르  32
# 4    보습  31
# 5    사용  30
# 6     있  30
# 7    없이  28
# 8    부담  27
# 9     향  27
# 10    같  26
# 11   수분  25
# 12    않  25
# 13   지성  24
# 14   피부  23
# 15    없  23
# 16   인원  21
# 17    주  19
# 18   제품  18
# 19   로션  17
# 20   걱정  17
# 21  습니다  16
# 22  ᆸ니다  15
# 23    수  14
# 24    독  14
# 25    때  11
# 26   남자  10
# 27    나  10
# 28   겨울  10
# 29   순하  10

# %%
# 특정 데이터프레임의 부정 키워드만 보고 싶다면
def print_keywords_by_name(df_name):
    # 결과 리스트에서 특정 데이터프레임의 이름과 결과를 찾습니다.
    for name, result_df in negative_list_df_results:
        if name == df_name:
            print(f"{name}의 상위 30개 단어:")
            print(result_df.head(30))
            break
    else:
        print(f"{df_name} 데이터프레임을 찾을 수 없습니다.")

# 예: 'skincare12_crc_negative_list_df'의 상위 30개 단어 출력
print_keywords_by_name('skincare31_crc_negative_list_df')
# Out:
# skincare31_crc_negative_list_df의 상위 30개 단어:
#      단어  빈도
# 0    어요  38
# 1     쓰  22
# 2    부담  22
# 3   미스트  20
# 4    뿌리  20
# 5    피부  20
# 6    수분  19
# 7     있  19
# 8    부족  18
# 9    사용  18
# 10    없  16
# 11    때  15
# 12  ᆸ니다  12
# 13   지성  12
# 14   없이  11
# 15   건조  11
# 16    같  11
# 17    저  11
# 18   분사  10
# 19    보  10
# 20    주   9
# 21    수   8
# 22    시   8
# 23   너무   8
# 24    독   8
# 25    분   7
# 26   제품   7
# 27    되   7
# 28   순하   6
# 29    사   6

# %% [markdown]
# #### 테스트

# %%
# 긍정, 부정, 중립 리스트 생성
positive_list = []
negative_list = []
neutral_list = []

# 각 텍스트에 대해 감정 분석을 수행하고 리스트에 저장
for text in skincare37_crc_list:
    sentiment = analyze_sentiment(text, senti_dict)
    if sentiment == "긍정":
        positive_list.append(text)
    elif sentiment == "부정":
        negative_list.append(text)
    else:
        neutral_list.append(text)

# 각 리스트 출력
print("긍정 리스트:")
print(positive_list)

print("\n부정 리스트:")
print(negative_list)

print("\n중립 리스트:")
print(neutral_list)
# Out:
# 긍정 리스트:
# ...

# %%
# skincare37_crc_positive_list_df = pd.DataFrame({'Text': positive_list})
# skincare37_crc_negative_list_df = pd.DataFrame({'Text': negative_list})
# #crc_neutral_list_df = pd.DataFrame({'Text': neutral_list})
# # 데이터프레임을 엑셀 파일로 저장
# skincare37_crc_positive_list_df.to_excel(r"C:\Users\82104\Downloads\skincare37_crc_positive_list_df.xlsx", index=False)
# skincare37_crc_negative_list_df.to_excel(r"C:\Users\82104\Downloads\skincare37_crc_negative_list_df.xlsx", index=False)
# #crc_negative_list_df.to_excel(r"C:\Users\82104\Downloads\crc_negative_list_df.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[39], line 5
#       2 skincare37_crc_negative_list_df = pd.DataFrame({'Text': negative_list})
#       3 #crc_neutral_list_df = pd.DataFrame({'Text': neutral_list})
#       4 # 데이터프레임을 엑셀 파일로 저장
# ----> 5 skincare37_crc_positive_list_df.to_excel(r"C:\Users\82104\Downloads\skincare37_crc_positive_list_df.xlsx", index=False)
#       6 skincare37_crc_negative_list_df.to_excel(r"C:\Users\82104\Downloads\skincare37_crc_negative_list_df.xlsx", index=False)
#       7 #crc_negative_list_df.to_excel(r"C:\Users\82104\Downloads\crc_negative_list_df.xlsx", index=False)
#
# File c:\Users\82108\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
# ...

# %%
from collections import Counter


# 직접적인 단어 빈도 계산
# 텍스트를 공백 기준으로 분할하여 모든 단어를 리스트로 만듦
skincare37_crc_positive_words = skincare31_crc_negative_list_df['Text'].str.split().sum()
# 단어들의 빈도를 계산
skincare37_crc_positive_words_freq = Counter(skincare37_crc_positive_words)

# 빈도 데이터를 데이터프레임으로 변환하여 정렬
skincare37_crc_positive_words_freq_df = pd.DataFrame(skincare37_crc_positive_words_freq.items(), columns=['단어', '빈도']).sort_values(by='빈도', ascending=False).reset_index(drop=True)
# 상위 10개 단어 출력
skincare37_crc_positive_words_freq_df.head(30)
# Out:
#      단어  빈도
# 0    어요  38
# 1     쓰  22
# 2    부담  22
# 3   미스트  20
# 4    뿌리  20
# 5    피부  20
# 6    수분  19
# 7     있  19
# 8    부족  18
# 9    사용  18
# 10    없  16
# 11    때  15
# 12  ᆸ니다  12
# 13   지성  12
# 14   없이  11
# 15   건조  11
# 16    같  11
# 17    저  11
# 18   분사  10
# 19    보  10
# 20    주   9
# 21    수   8
# 22    시   8
# 23   너무   8
# 24    독   8
# 25    분   7
# 26   제품   7
# 27    되   7
# 28   순하   6
# 29    사   6

# %%
# 각각의 리스트의 개수 계산
positive_count = len(positive_list)
negative_count = len(negative_list)
neutral_count = len(neutral_list)

# 데이터프레임 생성
data = {
    'Sentiment': ['긍정', '부정', '중립'],
    'Count': [positive_count, negative_count, neutral_count]
}

df = pd.DataFrame(data)
df
# Out:
#   Sentiment  Count
# 0        긍정    436
# 1        부정     78
# 2        중립   1921

# %%
from IPython.display import display

# 두 데이터프레임의 첫 30개 행을 나란히 출력
display(skincare37_crc_positive_words_freq_df.head(30))
display(skincare15_crc_positive_words_freq_df.head(30))
# Out:
#      단어  빈도
# 0    어요  38
# 1     쓰  22
# 2    부담  22
# 3   미스트  20
# 4    뿌리  20
# 5    피부  20
# 6    수분  19
# 7     있  19
# 8    부족  18
# 9    사용  18
# 10    없  16
# 11    때  15
# 12  ᆸ니다  12
# 13   지성  12
# 14   없이  11
# 15   건조  11
# 16    같  11
# 17    저  11
# 18   분사  10
# 19    보  10
# 20    주   9
# 21    수   8
# 22    시   8
# 23   너무   8
# 24    독   8
# 25    분   7
# 26   제품   7
# 27    되   7
# 28   순하   6
# 29    사   6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       3 # 두 데이터프레임의 첫 30개 행을 나란히 출력
#       4 display(skincare37_crc_positive_words_freq_df.head(30))
# ----> 5 display(skincare15_crc_positive_words_freq_df.head(30))
#
# NameError: name 'skincare15_crc_positive_words_freq_df' is not defined

# %%
import pandas as pd

# 데이터프레임을 열 방향으로 결합
combined_df = pd.concat([skincare37_crc_positive_words_freq_df.head(30), skincare15_crc_positive_words_freq_df.head(30)], axis=1)

# 결합된 데이터프레임 출력
display(combined_df)
# Out:
#      단어  빈도   단어   빈도
# 0    어요  38    잘  221
# 1     쓰  22   어요  190
# 2    부담  22    쓰  102
# 3   미스트  20   분사   92
# 4    뿌리  20    있   80
# 5    피부  20   뿌리   75
# 6    수분  19  미스트   71
# 7     있  19    되   69
# 8    부족  18    주   58
# 9    사용  18   만족   56
# 10    없  16   사용   54
# 11    때  15    같   53
# 12  ᆸ니다  12  습니다   52
# 13   지성  12  ᆸ니다   51
# 14   없이  11   피부   49
# 15   건조  11   순하   47
# 16    같  11   보습   43
# 17    저  11   구매   41
# 18   분사  10   너무   40
# 19    보  10    사   32
# 20    주   9   건조   30
# 21    수   8   독도   30
# 22    시   8    때   30
# 23   너무   8    보   30
# 24    독   8    않   28
# 25    분   7   제품   27
# 26   제품   7   안개   24
# 27    되   7   친구   24
# 28   순하   6   자극   24
# 29    사   6   화장   23

# %%
import pandas as pd

# 데이터프레임에서 '단어' 컬럼 추출
words_df1 = skincare37_crc_positive_words_freq_df.head(30)['단어']
words_df2 = skincare15_crc_positive_words_freq_df.head(30)['단어']

# 단어 목록을 집합으로 변환
set_words_df1 = set(words_df1)
set_words_df2 = set(words_df2)

# 중복 단어와 유일한 단어 찾기
common_words = set_words_df1.intersection(set_words_df2)
unique_to_df1 = set_words_df1 - set_words_df2
unique_to_df2 = set_words_df2 - set_words_df1

# 결과를 데이터프레임으로 변환
common_words_df = pd.DataFrame(list(common_words), columns=['Common Words'])
unique_to_df1_df = pd.DataFrame(list(unique_to_df1), columns=['Unique to DF1'])
unique_to_df2_df = pd.DataFrame(list(unique_to_df2), columns=['Unique to DF2'])

# 결과 출력
display(common_words_df)
display(unique_to_df1_df)
display(unique_to_df2_df)
# Out:
#    Common Words
# 0            제품
# 1            너무
# 2             사
# 3            사용
# 4            뿌리
# 5            피부
# 6             되
# 7             있
# 8           ᆸ니다
# 9             주
# 10            때
# 11            쓰
# 12            보
# 13           어요
# 14           건조
# 15          미스트
# 16            같
# 17           순하
# 18           분사
#    Unique to DF1
# 0             부족
# 1              없
# 2             수분
# 3              시
# 4              저
# 5             부담
# 6              독
# 7             없이
# 8              수
# 9             지성
# 10             분
#    Unique to DF2
# 0             보습
# 1             구매
# 2              않
# 3            습니다
# 4             화장
# 5             독도
# 6             안개
# 7             만족
# 8             자극
# 9              잘
# 10            친구

# %% [markdown]
# 기획전/단품 키워드 비교는 우선순위 박탈
# 단품 별/ 기획전별 키워드 추출
# 라인별 키워드 추출

# %% [markdown]
# ## 중복제거

# %%
# import pandas as pd

# # 각 스킨케어 데이터프레임의 고유 부정 및 긍정 단어를 저장할 딕셔너리
# skincare_unique_negative_words = {}
# skincare_unique_positive_words = {}

# # negative_list_df_results와 positive_list_df_results가 있다고 가정
# # negative_list_df_results와 positive_list_df_results는 각각 부정, 긍정 단어의 빈도 데이터프레임을 포함하는 리스트입니다.

# # 각 스킨케어 데이터프레임을 순차적으로 처리
# for neg_item, pos_item in zip(negative_list_df_results, positive_list_df_results):
#     neg_name, negative_df = neg_item  # 부정 리스트
#     pos_name, positive_df = pos_item  # 긍정 리스트
    
#     # 부정 및 긍정 프레임의 단어 리스트 추출
#     negative_words = set(negative_df.head(30)['단어'])
#     positive_words = set(positive_df.head(30)['단어'])
    
#     # 중복 단어 필터링 (부정 및 긍정에 공통으로 있는 단어를 제거)
#     common_words = negative_words & positive_words
    
#     # 중복 단어를 제외한 부정/긍정 단어 리스트
#     unique_negative_words = [word for word in negative_words if word not in common_words]
#     unique_positive_words = [word for word in positive_words if word not in common_words]
    
#     # 각 스킨케어 이름에 고유한 부정 및 긍정 단어 리스트를 딕셔너리에 저장
#     skincare_unique_negative_words[neg_name] = unique_negative_words
#     skincare_unique_positive_words[pos_name] = unique_positive_words

# # 예시 출력: 각 스킨케어의 고유 부정 및 긍정 단어 리스트 출력
# for neg_name in skincare_unique_negative_words:
#     print(f"{neg_name}의 고유 부정 단어 리스트:")
#     print(skincare_unique_negative_words[neg_name])
#     print("\n")

# for pos_name in skincare_unique_positive_words:
#     print(f"{pos_name}의 고유 긍정 단어 리스트:")
#     print(skincare_unique_positive_words[pos_name])
#     print("\n")
# Out:
# skincare12_crc_negative_list_df의 고유 부정 단어 리스트:
# ['겨울', '향', '때', '부족', '수분', '걱정', '독', '부담', '나', '없', '없이', '수']
#
#
# skincare21_crc_negative_list_df의 고유 부정 단어 리스트:
# ['겨울', '부족', '지성', '수분', '저', '부담', '느낌', '않', '추천', '없이', '수']
#
#
# skincare29_crc_negative_list_df의 고유 부정 단어 리스트:
# ['다', '여름', '부족', '지성', '수분', '걱정', '독', '부담', '안', '없이', '수']
#
#
# skincare31_crc_negative_list_df의 고유 부정 단어 리스트:
# ['부족', '지성', '수분', '저', '독', '분', '부담', '없', '없이', '수', '시']
#
#
# skincare36_crc_negative_list_df의 고유 부정 단어 리스트:
# ['부족', '건조', '지성', '스포이트', '수분', '걱정', '독', '부담', '불편', '좀', '건성']
#
#
# skincare37_crc_negative_list_df의 고유 부정 단어 리스트:
# ['팩', '때', '부족', '바르', '크', '수분', '용량', '스킨', '부담', '느낌', '않', '수', '물']
#
#
# skincare12_crc_positive_list_df의 고유 긍정 단어 리스트:
# ['만족', '되', '잘', '네요', '사', '친구', '너무', '흡수', '보', '선물', '구매', '독도']
#
#
# skincare21_crc_positive_list_df의 고유 긍정 단어 리스트:
# ['만족', '남자', '귀찮', '되', '잘', '네요', '친구', '주', '안', '선물', '구매']
#
#
# ...

# %%
#이걸로 해야 word clolud 할 수 있다~
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 각 스킨케어 데이터프레임의 고유 부정 및 긍정 단어를 저장할 딕셔너리
skincare_unique_negative_words = {}
skincare_unique_positive_words = {}

# negative_list_df_results와 positive_list_df_results가 있다고 가정
# negative_list_df_results와 positive_list_df_results는 각각 부정, 긍정 단어의 빈도 데이터프레임을 포함하는 리스트입니다.

# 각 스킨케어 데이터프레임을 순차적으로 처리
for neg_item, pos_item in zip(negative_list_df_results, positive_list_df_results):
    neg_name, negative_df = neg_item  # 부정 리스트
    pos_name, positive_df = pos_item  # 긍정 리스트
    
    # 부정 및 긍정 프레임의 단어 리스트 추출
    negative_words = set(negative_df.head(30)['단어'])
    positive_words = set(positive_df.head(30)['단어'])
    
    # 중복 단어 필터링 (부정 및 긍정에 공통으로 있는 단어를 제거)
    common_words = negative_words & positive_words
    
    # 중복 단어를 제외한 부정/긍정 단어 리스트와 빈도 값 추출
    unique_negative_df = negative_df[negative_df['단어'].isin(negative_words - common_words)]
    unique_positive_df = positive_df[positive_df['단어'].isin(positive_words - common_words)]
    
    # 고유 단어와 빈도를 딕셔너리에 저장 (워드클라우드용 데이터 생성)
    skincare_unique_negative_words[neg_name] = dict(zip(unique_negative_df['단어'], unique_negative_df['빈도']))
    skincare_unique_positive_words[pos_name] = dict(zip(unique_positive_df['단어'], unique_positive_df['빈도']))

# 예시 출력: 각 스킨케어의 고유 부정 및 긍정 단어 리스트 출력
for neg_name in skincare_unique_negative_words:
    print(f"{neg_name}의 고유 부정 단어 리스트:")
    print(skincare_unique_negative_words[neg_name])
    print("\n")

for pos_name in skincare_unique_positive_words:
    print(f"{pos_name}의 고유 긍정 단어 리스트:")
    print(skincare_unique_positive_words[pos_name])
    print("\n")
# Out:
# skincare12_crc_negative_list_df의 고유 부정 단어 리스트:
# {'부족': 44, '없이': 28, '부담': 27, '향': 27, '수분': 25, '없': 23, '걱정': 17, '수': 14, '독': 14, '때': 11, '나': 10, '겨울': 10}
#
#
# skincare21_crc_negative_list_df의 고유 부정 단어 리스트:
# {'부족': 20, '부담': 16, '않': 12, '없이': 11, '지성': 10, '수분': 9, '느낌': 7, '추천': 7, '수': 7, '저': 7, '겨울': 5}
#
#
# skincare29_crc_negative_list_df의 고유 부정 단어 리스트:
# {'부담': 26, '부족': 20, '없이': 20, '지성': 18, '수분': 14, '안': 12, '여름': 11, '다': 10, '수': 8, '독': 8, '걱정': 8}
#
#
# skincare31_crc_negative_list_df의 고유 부정 단어 리스트:
# {'부담': 22, '수분': 19, '부족': 18, '없': 16, '지성': 12, '없이': 11, '저': 11, '수': 8, '시': 8, '독': 8, '분': 7}
#
#
# skincare36_crc_negative_list_df의 고유 부정 단어 리스트:
# {'부족': 56, '수분': 41, '지성': 35, '건성': 23, '부담': 19, '건조': 16, '불편': 16, '독': 14, '스포이트': 13, '좀': 12, '걱정': 12}
#
#
# skincare37_crc_negative_list_df의 고유 부정 단어 리스트:
# {'부담': 27, '않': 13, '바르': 12, '수': 11, '수분': 10, '부족': 9, '용량': 9, '때': 8, '스킨': 7, '느낌': 7, '물': 7, '팩': 7, '크': 6}
#
#
# ...

# %% [markdown]
# # word cloud

# %%
#부정 단어 딕셔너리들
# skincare_unique_negative_words
#긍정 단어 딕셔너리들
# skincare_unique_positive_words

#병합: 단어와 빈도를 합치고, 같은 단어가 여러 스킨케어 제품에 등장할 경우 빈도를 누적하여 더함


# 부정 단어 리스트 병합
combined_negative_words = {}
for word_dict in skincare_unique_negative_words.values():
    for word, freq in word_dict.items():
        if word in combined_negative_words:
            combined_negative_words[word] += freq
        else:
            combined_negative_words[word] = freq

# 긍정 단어 리스트 병합
combined_positive_words = {}
for word_dict in skincare_unique_positive_words.values():
    for word, freq in word_dict.items():
        if word in combined_positive_words:
            combined_positive_words[word] += freq
        else:
            combined_positive_words[word] = freq

# 결과 출력
print("부정 단어 리스트:")
print(combined_negative_words)

print("\n긍정 단어 리스트:")
print(combined_positive_words)
# Out:
# 부정 단어 리스트:
# {'부족': 167, '없이': 70, '부담': 137, '향': 27, '수분': 118, '없': 39, '걱정': 37, '수': 48, '독': 44, '때': 19, '나': 10, '겨울': 15, '않': 25, '지성': 75, '느낌': 14, '추천': 7, '저': 18, '안': 12, '여름': 11, '다': 10, '시': 8, '분': 7, '건성': 23, '건조': 16, '불편': 16, '스포이트': 13, '좀': 12, '바르': 12, '용량': 9, '스킨': 7, '물': 7, '팩': 7, '크': 6}
#
# 긍정 단어 리스트:
# {'잘': 1345, '만족': 440, '친구': 344, '되': 215, '독도': 149, '네요': 147, '선물': 138, '보': 101, '구매': 266, '사': 88, '너무': 131, '흡수': 109, '남자': 147, '주': 199, '안': 30, '귀찮': 27, '습니다': 106, '최고': 72, '맞': 106, '보습': 88, '않': 28, '안개': 24, '자극': 105, '화장': 47, '순하': 73, '꾸준히': 64, '다': 32, '저': 31}

# %%
unique_negative_df_sorted = pd.DataFrame(list(combined_negative_words.items()), columns=['단어','빈도'])
unique_positive_df_sorted = pd.DataFrame(list(combined_positive_words.items()), columns=['단어','빈도'])

unique_negative_df_sorted
# Out:
#       단어   빈도
# 0     부족  167
# 1     없이   70
# 2     부담  137
# 3      향   27
# 4     수분  118
# 5      없   39
# 6     걱정   37
# 7      수   48
# 8      독   44
# 9      때   19
# 10     나   10
# 11    겨울   15
# 12     않   25
# 13    지성   75
# 14    느낌   14
# 15    추천    7
# 16     저   18
# 17     안   12
# 18    여름   11
# 19     다   10
# 20     시    8
# 21     분    7
# 22    건성   23
# 23    건조   16
# 24    불편   16
# 25  스포이트   13
# 26     좀   12
# 27    바르   12
# 28    용량    9
# 29    스킨    7
# 30     물    7
# 31     팩    7
# 32     크    6

# %% [markdown]
# ## 부정

# %%
#부정
#불필요한 글자 제거
df_word = unique_negative_df_sorted.drop(index=[1,5,7,8,9,10,12,16,17,19,20,21,26,27,30,31,32])
df_word
# Out:
#       단어   빈도
# 0     부족  167
# 2     부담  137
# 3      향   27
# 4     수분  118
# 6     걱정   37
# 11    겨울   15
# 13    지성   75
# 14    느낌   14
# 15    추천    7
# 18    여름   11
# 22    건성   23
# 23    건조   16
# 24    불편   16
# 25  스포이트   13
# 28    용량    9
# 29    스킨    7

# %%
# DataFrame -> Dictionary
dic_word = df_word.set_index('단어').to_dict()['빈도']
dic_word
# Out:
# {'부족': 167,
#  '부담': 137,
#  '향': 27,
#  '수분': 118,
#  '걱정': 37,
#  '겨울': 15,
#  '지성': 75,
#  '느낌': 14,
#  '추천': 7,
#  '여름': 11,
#  '건성': 23,
#  '건조': 16,
#  '불편': 16,
#  '스포이트': 13,
#  '용량': 9,
#  '스킨': 7}

# %%
# 채택!!
import numpy as np
from wordcloud import WordCloud #워드클라우드 제작 라이브러리
import matplotlib.pyplot as plt  #워드클라우드 시각화 라이브러리

# 워드클라우드에서 각 단어에 적용할 색상을 결정하는 함수
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    # 색조(hue) 지정
    hue_choices = [206,203]    #np.random.randint(50, 100)   # 색상의 기본 톤 hsl(206, 9%, 85%)  hsl(203, 50%, 80%)
    hue = np.random.choice(hue_choices)
    # 채도(saturation)을 31, 50으로 지정
    saturation_choices = [9,50]
    saturation = np.random.choice(saturation_choices)
    
    # 밝기는 랜덤 범위로 설정
    lightness = np.random.randint(80, 85)   # 50%에서 80% 사이의 랜덤 밝기
    
    # hsl 형식으로 색상 값을 반환
    return f"hsl({hue}, {saturation}%, {lightness}%)"

font_path=r"C:\대학교\학생성장지원시스템\(탈잉)실무에 가장 많이 쓰는 PPT 디자인\Jalnan.ttf"

#wordcloud 함수 사용
wc = WordCloud(random_state=42,font_path= font_path , width = 400,
               height = 400, background_color = 'white', color_func = color_func )
img_wordcloud = wc.generate_from_frequencies(dic_word)

plt.figure(figsize = (10, 10)) #크기 지정하기
plt.axis('off') #축 없애기
plt.imshow(img_wordcloud) #결과 보여주기
plt.savefig('Skincare_D_negative_wordcloud') #파일 저장

# %% [markdown]
# ## 긍정

# %%
unique_positive_df_sorted
# Out:
#      단어    빈도
# 0     잘  1345
# 1    만족   440
# 2    친구   344
# 3     되   215
# 4    독도   149
# 5    네요   147
# 6    선물   138
# 7     보   101
# 8    구매   266
# 9     사    88
# 10   너무   131
# 11   흡수   109
# 12   남자   147
# 13    주   199
# 14    안    30
# 15   귀찮    27
# 16  습니다   106
# 17   최고    72
# 18    맞   106
# 19   보습    88
# 20    않    28
# 21   안개    24
# 22   자극   105
# 23   화장    47
# 24   순하    73
# 25  꾸준히    64
# 26    다    32
# 27    저    31

# %%
#부정
#불필요한 글자 제거
df_word2 = unique_positive_df_sorted.drop(index=[0,3,5,7,9,10,13,14,16,18,20,26,27])
df_word2
# Out:
#      단어   빈도
# 1    만족  440
# 2    친구  344
# 4    독도  149
# 6    선물  138
# 8    구매  266
# 11   흡수  109
# 12   남자  147
# 15   귀찮   27
# 17   최고   72
# 19   보습   88
# 21   안개   24
# 22   자극  105
# 23   화장   47
# 24   순하   73
# 25  꾸준히   64

# %%
# DataFrame -> Dictionary
dic_word2 = df_word2.set_index('단어').to_dict()['빈도']
dic_word2
# Out:
# {'만족': 440,
#  '친구': 344,
#  '독도': 149,
#  '선물': 138,
#  '구매': 266,
#  '흡수': 109,
#  '남자': 147,
#  '귀찮': 27,
#  '최고': 72,
#  '보습': 88,
#  '안개': 24,
#  '자극': 105,
#  '화장': 47,
#  '순하': 73,
#  '꾸준히': 64}

# %%
# 채택!!
import numpy as np
from wordcloud import WordCloud #워드클라우드 제작 라이브러리
import matplotlib.pyplot as plt  #워드클라우드 시각화 라이브러리

# 워드클라우드에서 각 단어에 적용할 색상을 결정하는 함수
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    # 색조(hue) 지정
    hue_choices = [206,203]    #np.random.randint(50, 100)   # 색상의 기본 톤 hsl(206, 9%, 85%)  hsl(203, 50%, 80%)
    hue = np.random.choice(hue_choices)
    # 채도(saturation) 지정
    saturation_choices = [9,50]
    saturation = np.random.choice(saturation_choices)
    
    # 밝기는 랜덤 범위로 설정
    lightness = np.random.randint(80, 85)   # 사이의 랜덤 밝기
    
    # hsl 형식으로 색상 값을 반환
    return f"hsl({hue}, {saturation}%, {lightness}%)"

font_path=r"C:\대학교\학생성장지원시스템\(탈잉)실무에 가장 많이 쓰는 PPT 디자인\Jalnan.ttf"

#wordcloud 함수 사용
wc = WordCloud(random_state=42,font_path= font_path , width = 400,
               height = 400, background_color = 'white', color_func = color_func )
img_wordcloud = wc.generate_from_frequencies(dic_word2)

plt.figure(figsize = (10, 10)) #크기 지정하기
plt.axis('off') #축 없애기
plt.imshow(img_wordcloud) #결과 보여주기
plt.savefig('Skincare_D_positive_wordcloud') #파일 저장
