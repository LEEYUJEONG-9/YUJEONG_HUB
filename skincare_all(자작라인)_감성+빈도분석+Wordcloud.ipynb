# %% [markdown]
# # 자작라인
#  - skincare26	포맨 크림
#     skincare27	포맨 로션
#     skincare28	포맨 토너
#     skincare32	토너

# %% [markdown]
# ##  자작라인 파일불러오기

# %% [markdown]
# #### 단품

# %%
#skincare26 포맨 수분크림
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare26_crc.xlsx"
skincare26_crc_df = pd.read_excel(file_path)
print(skincare26_crc_df)
# Out:
#                                  0
# 0             저거 아빠 쓰 있 너무 잘 쓰 있 음
# 1                            순하 대요
# 2         자작나무 라인 전체 순하 부담 없이 쓰 어요
# 3                여드름 피부 잘 사용 있 습니다
# 4                               그거
# ...                            ...
# 1392  관리 느낌 팡팡 모공 관리 되 피부 좀 거듭나 네요
# 1393                            추천
# 1394                  가성비 보습 크림 네요
# 1395          보습 만족 순하 같 더욱 만족 ᆸ니다
# 1396  이거 오빠 사용 데 너무 너무 다음 또 살 더라고요
#
# [1397 rows x 1 columns]

# %%
#skincare27 포맨 수분 로션
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare27_crc.xlsx"
skincare27_crc_df = pd.read_excel(file_path)
print(skincare27_crc_df)
# Out:
#                                 0
# 0     남자 친구 항상 사용 로션 에요 가성비 순하 어요
# 1         많 분 추천 추천 아이템 무난 걸 같 어요
# 2                 남친 데일리 로션 구매 어요
# 3               라운드 랩 순하 항상 구매 어요
# 4                          사용 달 차
# ...                           ...
# 2319          남자 친구 사 주 잘 쓰 다니 어요
# 2320                 촉촉하 겨울 딱 이메일
# 2321                        순하 어요
# 2322         보습 기본 아이템 강력히 추천 ᆸ니다
# 2323                            굿
#
# [2324 rows x 1 columns]

# %%
#skincare28 포맨 수분 토너
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare28_crc.xlsx"
skincare28_crc_df = pd.read_excel(file_path)
print(skincare28_crc_df)
# Out:
#                                     0
# 0                        제품 구매 사용 달 차
# 1     사계절 내내 사용 같 산뜻 적당 건성 복합 사용 같 어요
# 2                      자극 없이 순하 촉촉 어요
# 3                         구매 의사 있 습니다
# 4                 지금 얼마 남 않 또 구매 가 어요
# ...                               ...
# 2310                  자작나무 세트 구매 보 어요
# 2311                유명 만큼 효과 있 바라 ᆸ니다
# 2312                         촉촉하 같 어요
# 2313    남자 친구 스킨 로션 선물 사 주 잘 사용 있 더라고
# 2314                  화 보 성분 괜찮 보이 어요
#
# [2315 rows x 1 columns]

# %%
#skincare32 스킨
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare32_crc.xlsx"
skincare32_crc_df = pd.read_excel(file_path)
print(skincare32_crc_df)
# Out:
#                                           0
# 0            제품 봄 가을 겨울 수분 많이 필요 때 쓰 딱 같 어요
# 1                 여름 때 이거 말 소나무 토너 추천 드리 어요
# 2        물 토너 약간 에센스 제형 저 지금 안 쓰 겨울 쓰 예정 에요
# 3     여름 저 수분 부족 지성 타입 바뀌 지금 쓰 오히려 좁쌀 나 더라고
# 4                       겨울 건성 되 그때 딱 맞 같 어요
# ...                                     ...
# 2362                          라운드 랩 상품 다 어요
# 2363                             자극 없 진정 어요
# 2364                                마스크 팩 음
# 2365                   너무 순하 보습 감 가득 토너 ᆸ니다
# 2366                                 추천 ᆸ니다
#
# [2367 rows x 1 columns]

# %%
import pandas as pd

# 데이터프레임을 리스트에 저장(단품)
dataframes_list1 = [
    skincare26_crc_df,
    skincare27_crc_df,
    skincare28_crc_df,
    skincare32_crc_df
]

dataframes_list1
# Out:
# [                                 0
#  0             저거 아빠 쓰 있 너무 잘 쓰 있 음
#  1                            순하 대요
#  2         자작나무 라인 전체 순하 부담 없이 쓰 어요
#  3                여드름 피부 잘 사용 있 습니다
#  4                               그거
#  ...                            ...
#  1392  관리 느낌 팡팡 모공 관리 되 피부 좀 거듭나 네요
#  1393                            추천
#  1394                  가성비 보습 크림 네요
#  1395          보습 만족 순하 같 더욱 만족 ᆸ니다
#  1396  이거 오빠 사용 데 너무 너무 다음 또 살 더라고요
#
#  [1397 rows x 1 columns],
#                                  0
#  0     남자 친구 항상 사용 로션 에요 가성비 순하 어요
#  1         많 분 추천 추천 아이템 무난 걸 같 어요
#  2                 남친 데일리 로션 구매 어요
#  3               라운드 랩 순하 항상 구매 어요
#  4                          사용 달 차
#  ...                           ...
#  2319          남자 친구 사 주 잘 쓰 다니 어요
#  2320                 촉촉하 겨울 딱 이메일
#  2321                        순하 어요
#  2322         보습 기본 아이템 강력히 추천 ᆸ니다
#  2323                            굿
#
#  [2324 rows x 1 columns],
#                                      0
#  0                        제품 구매 사용 달 차
#  1     사계절 내내 사용 같 산뜻 적당 건성 복합 사용 같 어요
#  2                      자극 없이 순하 촉촉 어요
#  3                         구매 의사 있 습니다
#  4                 지금 얼마 남 않 또 구매 가 어요
#  ...                               ...
#  2310                  자작나무 세트 구매 보 어요
#  2311                유명 만큼 효과 있 바라 ᆸ니다
#  2312                         촉촉하 같 어요
#  2313    남자 친구 스킨 로션 선물 사 주 잘 사용 있 더라고
#  2314                  화 보 성분 괜찮 보이 어요
#
#  [2315 rows x 1 columns],
#                                            0
#  0            제품 봄 가을 겨울 수분 많이 필요 때 쓰 딱 같 어요
#  1                 여름 때 이거 말 소나무 토너 추천 드리 어요
#  2        물 토너 약간 에센스 제형 저 지금 안 쓰 겨울 쓰 예정 에요
#  3     여름 저 수분 부족 지성 타입 바뀌 지금 쓰 오히려 좁쌀 나 더라고
#  4                       겨울 건성 되 그때 딱 맞 같 어요
#  ...                                     ...
#  2362                          라운드 랩 상품 다 어요
#  2363                             자극 없 진정 어요
#  2364                                마스크 팩 음
#  2365                   너무 순하 보습 감 가득 토너 ᆸ니다
#  2366                                 추천 ᆸ니다
#
#  [2367 rows x 1 columns]]

# %% [markdown]
# #### 기획

# %%
# #skincare11 젤로션 기획
# import pandas as pd
# file_path = r"C:\Users\82104\Downloads\제품리뷰전처리\skincare11_crc.xlsx"
# skincare11_crc_df = pd.read_excel(file_path)
# print(skincare11_crc_df)

# %%
# #skincare22 플루이드 기획
# import pandas as pd
# file_path = r"C:\Users\82104\Downloads\제품리뷰전처리\skincare22_crc.xlsx"
# skincare22_crc_df = pd.read_excel(file_path)
# print(skincare22_crc_df)

# %%
# #skincare34 로션 기획
# import pandas as pd
# file_path = r"C:\Users\82104\Downloads\제품리뷰전처리\skincare34_crc.xlsx"
# skincare34_crc_df = pd.read_excel(file_path)
# print(skincare34_crc_df)

# %%
# #skincare15 토너 대용량 기획
# import pandas as pd
# file_path = r"C:\Users\82104\Downloads\제품리뷰전처리\skincare15_crc.xlsx"
# skincare15_crc_df = pd.read_excel(file_path)
# print(skincare15_crc_df)

# %%
# #skincare35 크림 기획
# import pandas as pd
# file_path = r"C:\Users\82104\Downloads\제품리뷰전처리\skincare35_crc.xlsx"
# skincare35_crc_df = pd.read_excel(file_path)
# print(skincare35_crc_df)

# %%
# #skincare38 토너 + 로션 기획
# import pandas as pd
# file_path = r"C:\Users\82104\Downloads\제품리뷰전처리\skincare38_crc.xlsx"
# skincare38_crc_df = pd.read_excel(file_path)
# print(skincare38_crc_df)

# %% [markdown]
# # 자작라인 감성분석

# %%
# 형태소 분석기
from konlpy.tag import Okt
okt = Okt()

# SentiWord_Dict.txt 감성사전 불러오기
def load_senti_dict(file_path):
    senti_dict = {}
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split()  # 공백으로 분리
            if len(parts) > 1:
                word = ' '.join(parts[:-1])  # 마지막 항목을 제외한 나머지를 단어로 결합
                score = int(parts[-1])  # 마지막 항목을 점수로 처리
                senti_dict[word] = score
            else:
                print(f"해당 줄을 무시합니다: {line}")
    return senti_dict

# 감성 사전 로드
senti_dict = load_senti_dict(r"C:\Users\82108\Downloads\KnuSentiLex-master(1)\KnuSentiLex-master\SentiWord_Dict.txt")

# 감성 분석 함수 
def analyze_sentiment(text, senti_dict):
    # 형태소 분석
    morphs = okt.morphs(text)
    
    # 감정 점수 계산
    sentiment_score = 0
    for word in morphs:
        if word in senti_dict:  # 단어가 사전에 있는 경우
            sentiment_score += senti_dict[word]
    
    # 점수에 따라 감정 판단
    if sentiment_score > 0:
        return "긍정"
    elif sentiment_score < 0:
        return "부정"
    else:
        return "중립"

# %% [markdown]
# ## 긍정/중립/부정

# %% [markdown]
# #### 단품(리스트)

# %%
#단품 리스트
# 데이터프레임과 이름을 튜플로 저장
dataframes = [
    ("skincare26_crc_df", skincare26_crc_df),
    ("skincare27_crc_df", skincare27_crc_df),
    ("skincare28_crc_df", skincare28_crc_df),
    ("skincare32_crc_df", skincare32_crc_df)
]

results_list = []

# 각 데이터프레임 처리 및 결과 출력
for name, df in dataframes:
    print(f"Processing DataFrame: {name}")
    
    # 텍스트를 리스트로 변환
    skincare_text_list1 = df.iloc[:, 0].astype(str).tolist()
    
    # 감성 분석 수행
    skincare_results1 = [(text, analyze_sentiment(text, senti_dict)) for text in skincare_text_list1]
    
    # 결과 데이터프레임 생성
    skincare_results1_df = pd.DataFrame(skincare_results1, columns=['Text', 'Sentiment'])
    
    # 결과를 리스트에 저장
    results_list.append((name, skincare_results1_df))
    
    # 결과 출력
    print(skincare_results1_df)
    print("\n")  # 각 데이터프레임 결과 사이에 공백 추가
# Out:
# Processing DataFrame: skincare26_crc_df
#                               Text Sentiment
# 0             저거 아빠 쓰 있 너무 잘 쓰 있 음        긍정
# 1                            순하 대요        중립
# 2         자작나무 라인 전체 순하 부담 없이 쓰 어요        부정
# 3                여드름 피부 잘 사용 있 습니다        긍정
# 4                               그거        중립
# ...                            ...       ...
# 1392  관리 느낌 팡팡 모공 관리 되 피부 좀 거듭나 네요        중립
# 1393                            추천        중립
# 1394                  가성비 보습 크림 네요        중립
# 1395          보습 만족 순하 같 더욱 만족 ᆸ니다        긍정
# 1396  이거 오빠 사용 데 너무 너무 다음 또 살 더라고요        중립
#
# [1397 rows x 2 columns]
#
#
# Processing DataFrame: skincare27_crc_df
#                              Text Sentiment
# 0     남자 친구 항상 사용 로션 에요 가성비 순하 어요        긍정
# 1         많 분 추천 추천 아이템 무난 걸 같 어요        중립
# 2                 남친 데일리 로션 구매 어요        중립
# 3               라운드 랩 순하 항상 구매 어요        중립
# 4                          사용 달 차        중립
# ...                           ...       ...
# 2319          남자 친구 사 주 잘 쓰 다니 어요        긍정
# 2320                 촉촉하 겨울 딱 이메일        중립
# 2321                        순하 어요        중립
# 2322         보습 기본 아이템 강력히 추천 ᆸ니다        중립
# 2323                            굿        중립
#
# [2324 rows x 2 columns]
#
#
# Processing DataFrame: skincare28_crc_df
#                                  Text Sentiment
# 0                        제품 구매 사용 달 차        중립
# 1     사계절 내내 사용 같 산뜻 적당 건성 복합 사용 같 어요        중립
# 2                      자극 없이 순하 촉촉 어요        중립
# 3                         구매 의사 있 습니다        중립
# 4                 지금 얼마 남 않 또 구매 가 어요        중립
# ...                               ...       ...
# 2310                  자작나무 세트 구매 보 어요        중립
# 2311                유명 만큼 효과 있 바라 ᆸ니다        중립
# 2312                         촉촉하 같 어요        중립
# 2313    남자 친구 스킨 로션 선물 사 주 잘 사용 있 더라고        긍정
# 2314                  화 보 성분 괜찮 보이 어요        부정
#
# [2315 rows x 2 columns]
#
#
# Processing DataFrame: skincare32_crc_df
#                                        Text Sentiment
# 0            제품 봄 가을 겨울 수분 많이 필요 때 쓰 딱 같 어요        중립
# 1                 여름 때 이거 말 소나무 토너 추천 드리 어요        중립
# 2        물 토너 약간 에센스 제형 저 지금 안 쓰 겨울 쓰 예정 에요        중립
# 3     여름 저 수분 부족 지성 타입 바뀌 지금 쓰 오히려 좁쌀 나 더라고        부정
# 4                       겨울 건성 되 그때 딱 맞 같 어요        중립
# ...                                     ...       ...
# 2362                          라운드 랩 상품 다 어요        중립
# 2363                             자극 없 진정 어요        중립
# 2364                                마스크 팩 음        중립
# 2365                   너무 순하 보습 감 가득 토너 ᆸ니다        중립
# 2366                                 추천 ᆸ니다        중립
#
# [2367 rows x 2 columns]

# %%
#skincare26
# 특정 데이터프레임의 결과를 선택하여 출력
def view_results(results_list, name):
    for df_name, df in results_list:
        if df_name == name:
            print(f"Results for DataFrame: {name}")
            print(df)
            break

# 예시: 특정 데이터프레임의 결과 보기
view_results(results_list, "skincare26_crc_df")
# Out:
# Results for DataFrame: skincare26_crc_df
#                               Text Sentiment
# 0             저거 아빠 쓰 있 너무 잘 쓰 있 음        긍정
# 1                            순하 대요        중립
# 2         자작나무 라인 전체 순하 부담 없이 쓰 어요        부정
# 3                여드름 피부 잘 사용 있 습니다        긍정
# 4                               그거        중립
# ...                            ...       ...
# 1392  관리 느낌 팡팡 모공 관리 되 피부 좀 거듭나 네요        중립
# 1393                            추천        중립
# 1394                  가성비 보습 크림 네요        중립
# 1395          보습 만족 순하 같 더욱 만족 ᆸ니다        긍정
# 1396  이거 오빠 사용 데 너무 너무 다음 또 살 더라고요        중립
#
# [1397 rows x 2 columns]

# %%
#skincare32
# 특정 데이터프레임의 결과를 선택하여 출력
def view_results(results_list, name):
    for df_name, df in results_list:
        if df_name == name:
            print(f"Results for DataFrame: {name}")
            print(df)
            break

# 예시: 특정 데이터프레임의 결과 보기
view_results(results_list, "skincare32_crc_df")
# Out:
# Results for DataFrame: skincare32_crc_df
#                                        Text Sentiment
# 0            제품 봄 가을 겨울 수분 많이 필요 때 쓰 딱 같 어요        중립
# 1                 여름 때 이거 말 소나무 토너 추천 드리 어요        중립
# 2        물 토너 약간 에센스 제형 저 지금 안 쓰 겨울 쓰 예정 에요        중립
# 3     여름 저 수분 부족 지성 타입 바뀌 지금 쓰 오히려 좁쌀 나 더라고        부정
# 4                       겨울 건성 되 그때 딱 맞 같 어요        중립
# ...                                     ...       ...
# 2362                          라운드 랩 상품 다 어요        중립
# 2363                             자극 없 진정 어요        중립
# 2364                                마스크 팩 음        중립
# 2365                   너무 순하 보습 감 가득 토너 ᆸ니다        중립
# 2366                                 추천 ᆸ니다        중립
#
# [2367 rows x 2 columns]

# %% [markdown]
# #### 단품 하나씩(결과)

# %%
# #skincare26 젤로션
# skincare26_crc_list = skincare26_crc_df.iloc[:, 0].astype(str).tolist()
# skincare26_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare26_crc_list]

# # 결과 출력
# skincare26_crc_results_df = pd.DataFrame(skincare26_crc_results, columns=['Text', 'Sentiment'])
# print(skincare26_crc_results_df)

# %%
# #skincare27 풀루이드
# skincare27_crc_list = skincare27_crc_df.iloc[:, 0].astype(str).tolist()
# skincare27_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare27_crc_list]

# # 결과 출력
# skincare27_crc_results_df = pd.DataFrame(skincare27_crc_results, columns=['Text', 'Sentiment'])
# print(skincare27_crc_results_df)

# %%
# #skincare28 로션
# skincare28_crc_list = skincare28_crc_df.iloc[:, 0].astype(str).tolist()
# skincare28_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare28_crc_list]

# # 결과 출력
# skincare28_crc_results_df = pd.DataFrame(skincare28_crc_results, columns=['Text', 'Sentiment'])
# print(skincare28_crc_results_df)

# %%
# #skincare32 미스트
# skincare32_crc_list = skincare32_crc_df.iloc[:, 0].astype(str).tolist()
# skincare32_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare32_crc_list]

# # 결과 출력
# skincare32_crc_results_df = pd.DataFrame(skincare32_crc_results, columns=['Text', 'Sentiment'])
# print(skincare32_crc_results_df)

# %% [markdown]
# #### 기획전

# %%
# #skincare11 젤로션 기획
# skincare11_crc_list = skincare11_crc_df.iloc[:, 0].astype(str).tolist()
# skincare11_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare11_crc_list]

# # 결과 출력
# skincare11_crc_results_df = pd.DataFrame(skincare11_crc_results, columns=['Text', 'Sentiment'])
# print(skincare11_crc_results_df)

# %%
# #skincare22 플루이드 기획
# skincare22_crc_list = skincare22_crc_df.iloc[:, 0].astype(str).tolist()
# skincare22_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare22_crc_list]

# # 결과 출력
# skincare22_crc_results_df = pd.DataFrame(skincare22_crc_results, columns=['Text', 'Sentiment'])
# print(skincare22_crc_results_df)

# %%
# #skincare34 로션 기획
# skincare34_crc_list = skincare34_crc_df.iloc[:, 0].astype(str).tolist()
# skincare34_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare34_crc_list]

# # 결과 출력
# skincare34_crc_results_df = pd.DataFrame(skincare34_crc_results, columns=['Text', 'Sentiment'])
# print(skincare34_crc_results_df)

# %%
# #skincare15 토녀 대용량 기획
# skincare15_crc_list = skincare15_crc_df.iloc[:, 0].astype(str).tolist()
# skincare15_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare15_crc_list]

# # 결과 출력
# skincare15_crc_results_df = pd.DataFrame(skincare15_crc_results, columns=['Text', 'Sentiment'])
# print(skincare15_crc_results_df)

# %%
# #skincare35 크림 기획
# skincare35_crc_list = skincare35_crc_df.iloc[:, 0].astype(str).tolist()
# skincare35_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare35_crc_list]

# # 결과 출력
# skincare35_crc_results_df = pd.DataFrame(skincare35_crc_results, columns=['Text', 'Sentiment'])
# print(skincare35_crc_results_df)

# %%
# #skincare38 토너 + 로션 기획
# skincare38_crc_list = skincare38_crc_df.iloc[:, 0].astype(str).tolist()
# skincare38_crc_results = [(text, analyze_sentiment(text, senti_dict)) for text in skincare38_crc_list]

# # 결과 출력
# skincare38_crc_results_df = pd.DataFrame(skincare38_crc_results, columns=['Text', 'Sentiment'])
# print(skincare38_crc_results_df)

# %% [markdown]
# # 긍정/부정/중립 리스트 만들기

# %% [markdown]
# #### 단품(리스트)

# %%
import pandas as pd
from konlpy.tag import Okt

# 형태소 분석기 초기화
okt = Okt()

# 감성 분석 함수 정의
def analyze_sentiment(text, senti_dict):
    # 형태소 분석
    morphs = okt.morphs(text)
    
    # 감정 점수 계산
    sentiment_score = 0
    for word in morphs:
        if word in senti_dict:  # 단어가 사전에 있는 경우
            sentiment_score += senti_dict[word]
    
    # 점수에 따라 감정 판단
    if sentiment_score > 0:
        return "긍정"
    elif sentiment_score < 0:
        return "부정"
    else:
        return "중립"


# 데이터프레임과 이름을 튜플로 저장
dataframes = [
    ("skincare26_crc_df", skincare26_crc_df),
    ("skincare27_crc_df", skincare27_crc_df),
    ("skincare28_crc_df", skincare28_crc_df),
    ("skincare32_crc_df", skincare32_crc_df)
]

# 결과를 저장할 딕셔너리 (각 데이터프레임별로)
results_dict = {}

# 각 데이터프레임 처리 및 감정 분석 수행
for name, df in dataframes:
    print(f"Processing DataFrame: {name}")
    
    # 텍스트를 리스트로 변환
    text_list = df.iloc[:, 0].astype(str).tolist()
    
    # 긍정, 부정, 중립 리스트 초기화
    positive_list = []
    negative_list = []
    neutral_list = []
    
    # 감성 분석 수행 및 리스트에 저장
    for text in text_list:
        sentiment = analyze_sentiment(text, senti_dict)
        if sentiment == "긍정":
            positive_list.append(text)
        elif sentiment == "부정":
            negative_list.append(text)
        else:
            neutral_list.append(text)
    
    # 결과를 각 데이터프레임 이름별로 저장
    results_dict[name] = {
        "긍정": positive_list,
        "부정": negative_list,
        "중립": neutral_list
    }
# Out:
# Processing DataFrame: skincare26_crc_df
# Processing DataFrame: skincare27_crc_df
# Processing DataFrame: skincare28_crc_df
# Processing DataFrame: skincare32_crc_df

# %%
# results_dict['skincare26_crc_df']

# %%
#결과 수 확인
df_name = 'skincare26_crc_df'

if df_name in results_dict:
    # 긍정 항목의 수 출력
    positive_count = len(results_dict[df_name]['긍정'])
    print(f"긍정 항목의 수 for {df_name}: {positive_count}")

    # 부정 항목의 수 출력
    negative_count = len(results_dict[df_name]['부정'])
    print(f"부정 항목의 수 for {df_name}: {negative_count}")

    # 중립 항목의 수 출력
    neutral_count = len(results_dict[df_name]['중립'])
    print(f"중립 항목의 수 for {df_name}: {neutral_count}")

    # 전체 항목의 수 계산 및 출력
    total_count = positive_count + negative_count + neutral_count
    print(f"\n전체 항목의 수 for {df_name}: {total_count}")
else:
    print(f"No results found for {df_name}")
# Out:
# 긍정 항목의 수 for skincare26_crc_df: 376
# 부정 항목의 수 for skincare26_crc_df: 38
# 중립 항목의 수 for skincare26_crc_df: 983
#
# 전체 항목의 수 for skincare26_crc_df: 1397

# %%
# 긍정
# 특정 데이터프레임의 긍정, 부정, 중립 결과를 한 번에 출력하는 코드
df_name = 'skincare26_crc_df'

if df_name in results_dict:
    print(f"긍정 리스트 for {df_name}:")
    for item in results_dict[df_name]['긍정']:
        print(f"- {item}")
    
    # print("\n부정 리스트:")
    # for item in results_dict[df_name]['부정']:
    #     print(f"- {item}")

    # print("\n중립 리스트:")
    # for item in results_dict[df_name]['중립']:
    #     print(f"- {item}")
else:
    print(f"No results found for {df_name}")
# Out:
# 긍정 리스트 for skincare26_crc_df:
# - 저거 아빠 쓰 있 너무 잘 쓰 있 음
# - 여드름 피부 잘 사용 있 습니다
# - 자 전 듬뿍 바르 사용 편안 어요
# - 보습 바르 동안 피부 상태 개선 같 어요
# - 튜브 사용 편리 네요
# - 우리 아빠 얼굴 너무 상하 나 돈 주 사 잘 바르 잘 챙기 바르 시 ᆫ다
# - 신랑 보습 크림 사 아주 잘 쓰 있 어요
# - 남자 친구 필요 석 사 매일 잘 바르 더라고요
# - 하나 잘 바르 어요
# - 민감 피부 사용 수 있 믿음 가 ᆸ니다
# - 선물 사 잘 쓰 네요
# - 피부 관리 열심히
# - 상품 조금 달라 트러블 민감 않 거부 반응 없 흡수 잘 되 같 바르 같 어요
# - 또 저 개인 원통 생기 보통 손가락 그냥 사용 되 나중 되 위생 좀 안 다
# - 흡수 잘 흡수 나 후 끈적거리 너무 싫 이거 바르 나 다음 바르 까먹 정도 나름 산뜻 보습 또 괜찮 잔잔히 오래가 습니다
# - 뚜껑 좀 헐렁하 듯 잘 안 허접 느끼 ᆸ니다
# - 피부 잘 맞 습니다
# - 일반 보습 크림 남성 보습 크림 차이 잘 모르 그냥저냥 무난하 쓰 습니다
# - 자작나무 수분 라인 제품 가지 사용 보 다 잘 맞 어
# - 자극 없이 순하 무 향 사 더욱 잘 쓰 ᆸ니다
# - 항상 인원 용기 타입 사 드리 이번 튜브 타입 원 만큼 짤 수 있 으시
# - 촉촉하 발림 성 흡수 잘 되 산뜻 st ᆸ니다
# - 라운드 랩 항상 성분 보습 감 위주 제품 많 저 자주 쓰 자작나무 포맨 라인 모공 관리 피지 조절 성분 들 있 남자 친구 사 주 어요
# - 단점 할인 살짝 비싸 느낌 ᆫ데 쿠폰 사용 만 원 중반 나름 괜찮 같 어요
# - 라운드 랩 항상 성분 보습 감 위주 제품 많 저 자주 쓰 자작나무 포맨 라인 모공 관리 피지 조절 성분 들 있 남자 친구 사 주 어요
# - 자작 수분 라인 저 잘 쓰 만족 포맨 사 주 보 역시 믿쓰템 미드 라인 남친 왈 제형 산뜻 쾌적 무엇 촉촉 듯 ᆸ니다
# - 보습 만족 순하 같 더욱 만족 ᆸ니다

# %%
# 부정
# 특정 데이터프레임의 긍정, 부정, 중립 결과를 한 번에 출력하는 코드
df_name = 'skincare26_crc_df'

if df_name in results_dict:
    #print(f"긍정 리스트 for {df_name}:")
    #for item in results_dict[df_name]['긍정']:
        #print(f"- {item}")
    
    print("\n부정 리스트:")
    for item in results_dict[df_name]['부정']:
        print(f"- {item}")

    #print("\n중립 리스트:")
    #for item in results_dict[df_name]['중립']:
        #print(f"- {item}")
else:
    print(f"No results found for {df_name}")
# Out:
# 부정 리스트:
# - 자작나무 라인 전체 순하 부담 없이 쓰 어요
# - 저 포맨 쓰 보습 살짝 부족 그냥 자작나무 보습 크림 쓰 다 보습 조금 더 원 포맨 쓰 세요
# - 포맨 잘못 사 동생 주 포맨 알아차리 전 쓰 저 말 포맨 자극 없이 순하 크림 어요
# - 보습 감 제품 비교 때 괜찮 유분 상당 저 또 구매 힘들 같 습니다
# - 남자 친구 화장품 잘못 쓰 바로 트러블 나 쓰 쓰 더라고
# - 약간 복합 건조 기름 같이 느끼 피부 사용 건조 잘 잡히 유분 좀 많이 느끼 사용 때 흡수 다 되 때 유분 있 상태 계속 있 불편 어요
# - 하나 부족 때 덧바르
# - 남성 건조 피부 순하 자극 않 부담 없이 사용 어요
# - 자작나무 포맨 토너 로션 부족 부분 채우 주 끈적거리 않 어요
# - 남자 부담 없이 간편하 사용 같 어요
# - 겨울 조금 부족 네요
# - 꾸덕꾸덕 엄청나 보습 가지 제품 잘 발리 중상 정도 보습 순하 ᆷ
# - 수분 부족 지성 꾸덕꾸덕 바르 무조건 여드름 나
# - 속 당김 심 수분 부족 지성 기초 화장품 정착 ᆸ니다
# - 다만 펌프 형식 짜 쓰 방식 양 조절 힘들 쥐어짜 나오 튜브 위생 상 별로 별 하나 빼 ᆸ니다
# - 겨울 보습 부족 수 있 나머지 두루두루 쓰 어요
# - 순하 제품 더욱 더 크 탈 없이 수분 충전
# - 무난 겨울 좀 보습 부족 느낌 라네
# - 독 클렌징 폼 같이 쓰 데 효과 어요
# - 남자 부담 없이 편하 쓰 같 어요
# - 특별 불만 사항 없 습니다
# - 산성 제품 때문 피부 부담 없이 막 쓰 괜찮 어요
# - 에센스 너무 충동 사 후회 없 습니다
# - 아빠 사용 계시 데 크 불편 자극 없이 잘 사용 계시 더라고요
# - 남자 피부 관리 제품 순하 않 편견 있 순하 어요
# - 구매 의사 없 사 후회 정도 무난 제품 ᆸ니다
# - 아빠 사용 시 순하 제품 부담 없이 사용 촉촉 느낌 듯하 시 더라고
# - 그냥 알갱이 불편 자작나무 보습 크림 쓰 네요
# - 매장 가 김 직접 손등 테스트 보 남성 너무 화 않 겨울 쓰 나쁘 않 같 더라고요
# - 개인 이거 여름 사용 부담 생각 ᆸ니다
# - 운전 시 햇빛 늘 노출 서 크림 안 바르 걱정 맨날 선 스틱 같 사 드리 라운드 랩 포 제품 처음 사 보 네요
# - 남편 피부 유형 수분 부족 지성 낮 어쩌 수 없이 회사 세수 번 크림 바르 속 덜 건조 얼굴 덜 번들거리 더라고요
# - 자극 없이 순하 향 없 부담 없이 바르 튜브 형태 위생 음
# - 촉촉 산뜻 보습 남 요즘 같 환절기 건조 겨울 이것 건성 부족 같 어요
# - 나쁘 않 순하 순하 보습 있 크림 생각 구매 좀 실망 만 달까
# - 촉촉하 보습 남녀노소 부담 없이 사용 같 어요
# - 그런데 이거 엄청 해 많이 보 날 고생 날
# - BB 향 없 으시 데요 강하 향 매우 극 혐오 시 타입

# %% [markdown]
# #### 단품(테스트)

# %%
# # 긍정, 부정, 중립 리스트 생성
# positive_list = []
# negative_list = []
# neutral_list = []

# # 각 텍스트에 대해 감정 분석을 수행하고 리스트에 저장
# for text in skincare26_crc_list:
#     sentiment = analyze_sentiment(text, senti_dict)
#     if sentiment == "긍정":
#         positive_list.append(text)
#     elif sentiment == "부정":
#         negative_list.append(text)
#     else:
#         neutral_list.append(text)

# # 각 리스트 출력
# print("긍정 리스트:")
# print(positive_list)

# print("\n부정 리스트:")
# print(negative_list)

# print("\n중립 리스트:")
# print(neutral_list)

# %%
# # 긍정, 부정, 중립 리스트 생성
# positive_list = []
# negative_list = []
# neutral_list = []

# # 각 텍스트에 대해 감정 분석을 수행하고 리스트에 저장
# for text in skincare26_crc_list:
#     sentiment = analyze_sentiment(text, senti_dict)
#     if sentiment == "긍정":
#         positive_list.append(text)
#     elif sentiment == "부정":
#         negative_list.append(text)
#     else:
#         neutral_list.append(text)

# # 각 리스트 출력
# print("긍정 리스트:")
# print(positive_list)

# print("\n부정 리스트:")
# print(negative_list)

# print("\n중립 리스트:")
# print(neutral_list)

# %% [markdown]
# #### 엑셀로 저장

# %%
#단품 리스트
import pandas as pd

# 결과를 저장할 경로 설정
output_dir = r"C:\Users\82108\Downloads"

# 각 데이터프레임 처리 및 엑셀 파일로 저장
for df_name in results_dict:
    # 긍정 리스트를 데이터프레임으로 변환 및 저장
    skincare_positive_df = pd.DataFrame({'Text': results_dict[df_name]['긍정']})
    skincare_positive_df.to_excel(f"{output_dir}\{df_name}_positive_list_J.xlsx", index=False)

    # 부정 리스트를 데이터프레임으로 변환 및 저장
    skincare_negative_df = pd.DataFrame({'Text': results_dict[df_name]['부정']})
    skincare_negative_df.to_excel(f"{output_dir}\{df_name}_negative_list_J.xlsx", index=False)

    # 중립 리스트를 데이터프레임으로 변환 및 저장
    #skincare_neutral_df = pd.DataFrame({'Text': results_dict[df_name]['중립']})
    #skincare_neutral_df.to_excel(f"{output_dir}\{df_name}_neutral_list.xlsx", index=False)

    print(f"{df_name} 데이터프레임의 긍정, 부정, 중립 리스트가 각각 엑셀 파일로 저장되었습니다.")
# Out:
# skincare26_crc_df 데이터프레임의 긍정, 부정, 중립 리스트가 각각 엑셀 파일로 저장되었습니다.
# skincare27_crc_df 데이터프레임의 긍정, 부정, 중립 리스트가 각각 엑셀 파일로 저장되었습니다.
# skincare28_crc_df 데이터프레임의 긍정, 부정, 중립 리스트가 각각 엑셀 파일로 저장되었습니다.
# skincare32_crc_df 데이터프레임의 긍정, 부정, 중립 리스트가 각각 엑셀 파일로 저장되었습니다.

# %% [markdown]
# # 자작라인 빈도분석

# %% [markdown]
# ## 엑셀파일 불러오기

# %%
import pandas as pd

# 불러올 파일 경로 설정
output_dir = "C:/Users/82108/Downloads"

# 불러올 데이터프레임 목록 (변수들이 문자열로 되어 있어야 함)
df_names = [
    "skincare26_crc_df",
    "skincare27_crc_df",
    "skincare28_crc_df",
    "skincare32_crc_df"
]

# 각 데이터프레임 이름별로 데이터를 불러와 개별 변수에 저장
for df_name in df_names:
    # 각 파일 이름을 출력해 확인
    print(f"df_name: {df_name}")
    
    # 긍정 리스트 엑셀 파일 불러오기
    positive_df = pd.read_excel(f"{output_dir}/{df_name}_positive_list.xlsx")
    positive_var_name = f"{df_name.replace('_df', '')}_positive_list_J_df"
    globals()[positive_var_name] = positive_df

    # 부정 리스트 엑셀 파일 불러오기
    negative_df = pd.read_excel(f"{output_dir}/{df_name}_negative_list.xlsx")
    negative_var_name = f"{df_name.replace('_df', '')}_negative_list_J_df"
    globals()[negative_var_name] = negative_df

    # 중립 리스트 엑셀 파일 불러오기 (필요한 경우)
    # neutral_df = pd.read_excel(f"{output_dir}/{df_name}_neutral_list.xlsx")
    # neutral_var_name = f"{df_name.replace('_df', '')}_neutral_list_df"
    # globals()[neutral_var_name] = neutral_df

# 예시: skincare26_crc_positive_list_df 출력해보기
print(skincare26_crc_positive_list_df.head())
print(skincare26_crc_negative_list_df.head())
# Out:
# df_name: skincare26_crc_df
# df_name: skincare27_crc_df
# df_name: skincare28_crc_df
# df_name: skincare32_crc_df
#                      Text
# 0    저거 아빠 쓰 있 너무 잘 쓰 있 음
# 1       여드름 피부 잘 사용 있 습니다
# 2      자 전 듬뿍 바르 사용 편안 어요
# 3  보습 바르 동안 피부 상태 개선 같 어요
# 4             튜브 사용 편리 네요
#                                                 Text
# 0                           자작나무 라인 전체 순하 부담 없이 쓰 어요
# 1  저 포맨 쓰 보습 살짝 부족 그냥 자작나무 보습 크림 쓰 다 보습 조금 더 원 포맨...
# 2     포맨 잘못 사 동생 주 포맨 알아차리 전 쓰 저 말 포맨 자극 없이 순하 크림 어요
# 3              보습 감 제품 비교 때 괜찮 유분 상당 저 또 구매 힘들 같 습니다
# 4                    남자 친구 화장품 잘못 쓰 바로 트러블 나 쓰 쓰 더라고

# %%
print(skincare32_crc_positive_list_df.head())
print(skincare32_crc_negative_list_df.head())
# Out:
#                            Text
# 0          자극 없 순하 너무 너무 만족 ᆸ니다
# 1          자작나무 상품 다 만족 사용 있 어요
# 2      건조 주 그거 정말 조금 주 럼 필수 ᆸ니다
# 3  거의 년 넘 구매 중 촉촉하 잘 스며들 추천 ᆸ니다
# 4               순하 진정 효과 뛰어나 어요
#                                        Text
# 0     여름 저 수분 부족 지성 타입 바뀌 지금 쓰 오히려 좁쌀 나 더라고
# 1  수분 부족 지성인 분 번 정도 흡수 피부 속 촉촉하 느끼 시 수 있 예요
# 2      지성 수분 부족 지성 다 쓰 괜찮 같 지성인 분 좀 더 추천 드리
# 3                   자극 없이 순하 부담 없이 사용 있 습니다
# 4                     지성 수분 부족 지성 복합 추천 ᆸ니다

# %%
#긍정리스트
positive_list_dfs = [skincare26_crc_positive_list_df, skincare27_crc_positive_list_df, skincare28_crc_positive_list_df, skincare32_crc_positive_list_df]
positive_list_dfs
# Out:
# [                                                  Text
#  0                                 저거 아빠 쓰 있 너무 잘 쓰 있 음
#  1                                    여드름 피부 잘 사용 있 습니다
#  2                                   자 전 듬뿍 바르 사용 편안 어요
#  3                               보습 바르 동안 피부 상태 개선 같 어요
#  4                                          튜브 사용 편리 네요
#  ..                                                 ...
#  371  라운드 랩 항상 성분 보습 감 위주 제품 많 저 자주 쓰 자작나무 포맨 라인 모공 ...
#  372          단점 할인 살짝 비싸 느낌 ᆫ데 쿠폰 사용 만 원 중반 나름 괜찮 같 어요
#  373  라운드 랩 항상 성분 보습 감 위주 제품 많 저 자주 쓰 자작나무 포맨 라인 모공 ...
#  374  자작 수분 라인 저 잘 쓰 만족 포맨 사 주 보 역시 믿쓰템 미드 라인 남친 왈 제...
#  375                               보습 만족 순하 같 더욱 만족 ᆸ니다
#
#  [376 rows x 1 columns],
#                              Text
#  0    남자 친구 항상 사용 로션 에요 가성비 순하 어요
#  1      크림 잘 발리 보습 효과 피부 아주 같 습니다
#  2                        저 만족 어요
#  3      지성 동생 위하 사 주 너무 잘 쓰 있 습니다
#  4            끈적거리 않 손 더 잘 가 같 어요
#  ..                           ...
#  555        뾰루지 안 나 잘 쓰 보 괜찮 같 어요
#  556                 남자 피부 잘 맞 어요
#  557          친구 선물 주 잘 모르 구매 습니다
#  558                선물 드리 만족 시 네요
#  559          남자 친구 사 주 잘 쓰 다니 어요
#
#  [560 rows x 1 columns],
#                                                   Text
#  0    아빠 쓰 향 너무 싫 무 향 제품 찾 번 사 보 향 아예 없 않 은은 잘 안 느끼 어요
#  1                                           신랑 잘 쓰 네요
#  2           뭐 특별 효과 효능 있 딱 기본 수분 채우 주 기본 굉장히 잘 제품 ᆸ니다
#  3                              기대 안 막 사 생각 너무 깜짝 놀라 어
#  4                                    남자 친구 쓰 자작 토너 에요
#  ..                                                ...
#  567                                     우선 만족 쓰 있 습니다
#  568                                            감사 ᆸ니다
#  569                          할인 가격 잘 살 같 아주 만족 만족 ᆸ니다
#  570                                달 쓰 보 결과 매우 만족 ᆸ니다
#  571                     남자 친구 스킨 로션 선물 사 주 잘 사용 있 더라고
#
#  [572 rows x 1 columns],
#                                                    Text
#  0                                 자극 없 순하 너무 너무 만족 ᆸ니다
#  1                                 자작나무 상품 다 만족 사용 있 어요
#  2                             건조 주 그거 정말 조금 주 럼 필수 ᆸ니다
#  3                         거의 년 넘 구매 중 촉촉하 잘 스며들 추천 ᆸ니다
#  4                                      순하 진정 효과 뛰어나 어요
#  ..                                                 ...
#  387                                            잘 쓰 습니다
#  388  구매 동기 라운드 랩 제품 독도 패드 토너 사용 보 자작나무 마스크 팩 잘 맞 자주...
#  389                        쑥 자작나무 쌀 등 성분 기초 화장품 잘 맞 어요
#  390          화장 솜 닦 터 독도 토너 화장 솜 바로 흡수 제품 좀 더 시간 걸리 장점
#  391                       꾸준히 쓰 보 확실히 독도 토너 보습 더 느끼 어요
#
#  [392 rows x 1 columns]]

# %%
#부정리스트
negative_list_dfs = [skincare26_crc_negative_list_df, skincare27_crc_negative_list_df, skincare28_crc_negative_list_df, skincare32_crc_negative_list_df]
negative_list_dfs
# Out:
# [                                                 Text
#  0                            자작나무 라인 전체 순하 부담 없이 쓰 어요
#  1   저 포맨 쓰 보습 살짝 부족 그냥 자작나무 보습 크림 쓰 다 보습 조금 더 원 포맨...
#  2      포맨 잘못 사 동생 주 포맨 알아차리 전 쓰 저 말 포맨 자극 없이 순하 크림 어요
#  3               보습 감 제품 비교 때 괜찮 유분 상당 저 또 구매 힘들 같 습니다
#  4                     남자 친구 화장품 잘못 쓰 바로 트러블 나 쓰 쓰 더라고
#  5   약간 복합 건조 기름 같이 느끼 피부 사용 건조 잘 잡히 유분 좀 많이 느끼 사용 ...
#  6                                         하나 부족 때 덧바르
#  7                        남성 건조 피부 순하 자극 않 부담 없이 사용 어요
#  8                  자작나무 포맨 토너 로션 부족 부분 채우 주 끈적거리 않 어요
#  9                                남자 부담 없이 간편하 사용 같 어요
#  10                                        겨울 조금 부족 네요
#  11               꾸덕꾸덕 엄청나 보습 가지 제품 잘 발리 중상 정도 보습 순하 ᆷ
#  12                         수분 부족 지성 꾸덕꾸덕 바르 무조건 여드름 나
#  52  라운드 랩 독 쓰 보 너무 이거 동생 사 주 브랜드 자체 성분 신경 많이 쓰 전체 ...
#  53                                    화 보 성분 괜찮 보이 어요,
#                                                    Text
#  0                여름 저 수분 부족 지성 타입 바뀌 지금 쓰 오히려 좁쌀 나 더라고
#  1             수분 부족 지성인 분 번 정도 흡수 피부 속 촉촉하 느끼 시 수 있 예요
#  2                 지성 수분 부족 지성 다 쓰 괜찮 같 지성인 분 좀 더 추천 드리
#  3                              자극 없이 순하 부담 없이 사용 있 습니다
#  4                                지성 수분 부족 지성 복합 추천 ᆸ니다
#  ..                                                 ...
#  121               같 라인 쓰 더 효과 수분 부족 지성 건성 분 강력히 추천 ᆸ니다
#  122                  처음 때 투명 병 보이 느낌 보통 스킨 짙 확인 수 있 어요
#  123  병 디자인 토너 종류 보 수 있 형태 같 쓰 딱히 불편 점 없 들 있 양 비 공간 ...
#  124  환절기 스트레스 때 피부염 올라오 민감 피부 가끔 크 트러블 나 약간 좁쌀 여드름 ...
#  125                      독도 라인 유명 토너 다 쓰 독 토너 쓰 보 싶 어요
#
#  [126 rows x 1 columns]]

# %% [markdown]
# ## 긍정(30개 추출)

# %%
import pandas as pd
from collections import Counter

positive_list_dfs = [
    ('skincare26_crc_positive_list_df', skincare26_crc_positive_list_df),
    ('skincare27_crc_positive_list_df', skincare27_crc_positive_list_df),
    ('skincare28_crc_positive_list_df', skincare28_crc_positive_list_df),
    ('skincare32_crc_positive_list_df', skincare32_crc_positive_list_df)
]

positive_list_df_results = []

# 각 데이터프레임을 순차적으로 처리합니다.
for name, df in positive_list_dfs:
    # 텍스트 열에서 단어를 추출하여 리스트로 만듭니다.
    words = df['Text'].str.split().sum()
    
    # 단어 빈도 계산
    words_freq = Counter(words)
    
    # 빈도 데이터를 데이터프레임으로 변환하고 정렬합니다.
    words_freq_df = pd.DataFrame(words_freq.items(), columns=['단어', '빈도']).sort_values(by='빈도', ascending=False).reset_index(drop=True)
    
    # 결과를 리스트에 추가합니다.
    positive_list_df_results.append((name, words_freq_df))

# 각 데이터프레임의 결과를 출력합니다. (예를 들어, 상위 10개 단어를 출력)
for name, positive_list_result_df in positive_list_df_results:
    print(f"{name}의 상위 10개 단어:")
    print(positive_list_result_df.head(10))
    print("\n")
# Out:
# skincare26_crc_positive_list_df의 상위 10개 단어:
#    단어   빈도
# 0   잘  199
# 1  어요  146
# 2   쓰  116
# 3   있   92
# 4  친구   85
# 5  남자   81
# 6  사용   72
# 7  보습   70
# 8   주   64
# 9   같   60
#
#
# skincare27_crc_positive_list_df의 상위 10개 단어:
#     단어   빈도
# 0    잘  284
# 1   어요  204
# 2    쓰  163
# 3    있  128
# 4  ᆸ니다  116
# 5   사용  108
# 6   친구  102
# 7   만족   96
# 8    주   89
# 9   남자   86
#
#
# skincare28_crc_positive_list_df의 상위 10개 단어:
#    단어   빈도
# 0   잘  282
# 1  어요  207
# 2   쓰  202
# 3   있  157
# 4  친구  137
# 5  남자  129
# 6  만족  117
# 7  사용  117
# 8   주  113
# 9   같   99
#
#
# skincare32_crc_positive_list_df의 상위 10개 단어:
#    단어   빈도
# 0   잘  193
# 1  어요  157
# 2  사용  118
# 3   있  115
# 4   쓰  110
# 5  토너  108
# 6   같   88
# 7   보   85
# 8  피부   85
# 9  만족   80

# %%
# 특정 데이터프레임의 긍정 키워드만 보고 싶다면
def print_keywords_by_name(df_name):
    # 결과 리스트에서 특정 데이터프레임의 이름과 결과를 찾습니다.
    for name, result_df in positive_list_df_results:
        if name == df_name:
            print(f"{name}의 상위 30개 단어:")
            print(result_df.head(30))
            break
    else:
        print(f"{df_name} 데이터프레임을 찾을 수 없습니다.")

print_keywords_by_name('skincare26_crc_positive_list_df')
# Out:
# skincare26_crc_positive_list_df의 상위 30개 단어:
#      단어   빈도
# 0     잘  199
# 1    어요  146
# 2     쓰  116
# 3     있   92
# 4    친구   85
# 5    남자   81
# 6    사용   72
# 7    보습   70
# 8     주   64
# 9     같   60
# 10    사   57
# 11   피부   55
# 12  습니다   54
# 13   제품   53
# 14   바르   52
# 15   만족   50
# 16    되   49
# 17   크림   48
# 18  ᆸ니다   47
# 19    보   44
# 20   순하   43
# 21   구매   39
# 22   너무   36
# 23   선물   35
# 24   흡수   33
# 25    않   32
# 26   네요   30
# 27    저   29
# 28   자극   23
# 29    맞   23

# %%
print_keywords_by_name('skincare32_crc_positive_list_df')
# Out:
# skincare32_crc_positive_list_df의 상위 30개 단어:
#       단어   빈도
# 0      잘  193
# 1     어요  157
# 2     사용  118
# 3      있  115
# 4      쓰  110
# 5     토너  108
# 6      같   88
# 7      보   85
# 8     피부   85
# 9     만족   80
# 10     되   73
# 11   습니다   73
# 12    제품   66
# 13   ᆸ니다   66
# 14    수분   55
# 15    순하   50
# 16     저   50
# 17  자작나무   49
# 18    보습   45
# 19     주   44
# 20     맞   43
# 21    너무   40
# 22    구매   39
# 23    독도   38
# 24    흡수   30
# 25     않   29
# 26     없   28
# 27     랩   27
# 28    느낌   27
# 29     수   27

# %% [markdown]
# ## 부정 추출

# %%
import pandas as pd
from collections import Counter

negative_list_dfs = [
    ('skincare26_crc_negative_list_df', skincare26_crc_negative_list_df),
    ('skincare27_crc_negative_list_df', skincare27_crc_negative_list_df),
    ('skincare28_crc_negative_list_df', skincare28_crc_negative_list_df),
    ('skincare32_crc_negative_list_df', skincare32_crc_negative_list_df)
]

negative_list_df_results = []

# 각 데이터프레임을 순차적으로 처리합니다.
for name, df in negative_list_dfs:
    # 텍스트 열에서 단어를 추출하여 리스트로 만듭니다.
    words = df['Text'].str.split().sum()
    
    # 단어 빈도 계산
    words_freq = Counter(words)
    
    # 빈도 데이터를 데이터프레임으로 변환하고 정렬합니다.
    words_freq_df = pd.DataFrame(words_freq.items(), columns=['단어', '빈도']).sort_values(by='빈도', ascending=False).reset_index(drop=True)
    
    # 결과를 리스트에 추가합니다.
    negative_list_df_results.append((name, words_freq_df))

# 각 데이터프레임의 결과를 출력합니다. (예를 들어, 상위 10개 단어를 출력)
for name, negative_list_result_df in negative_list_df_results:
    print(f"{name}의 상위 10개 단어:")
    print(negative_list_result_df.head(10))
    print("\n")
# Out:
# skincare26_crc_negative_list_df의 상위 10개 단어:
#    단어  빈도
# 0   쓰  15
# 1  없이  13
# 2  어요  13
# 3  보습  12
# 4  순하  11
# 5  부족  10
# 6  사용  10
# 7  부담   9
# 8  제품   8
# 9   같   8
#
#
# skincare27_crc_negative_list_df의 상위 10개 단어:
#     단어  빈도
# 0    쓰  19
# 1   어요  17
# 2   부족  17
# 3   사용  15
# 4   없이  14
# 5   지성  14
# 6   수분  13
# 7   부담  13
# 8    있  11
# 9  습니다  10
#
#
# skincare28_crc_negative_list_df의 상위 10개 단어:
#    단어  빈도
# 0  어요  22
# 1  없이  16
# 2  부담  14
# 3   쓰  13
# 4  수분  13
# 5  피부  13
# 6  부족  12
# 7   같  12
# 8  너무  12
# 9  순하  11
#
#
# skincare32_crc_negative_list_df의 상위 10개 단어:
#    단어  빈도
# 0  수분  55
# 1  부족  50
# 2  피부  49
# 3   있  45
# 4  지성  42
# 5  어요  40
# 6  사용  35
# 7   같  34
# 8  토너  33
# 9   쓰  31

# %%
# negative_list_df_results

# %%
# # 특정 데이터프레임의 부정 키워드만 보고 싶다면
# def print_keywords_by_name(df_name):
#     # 결과 리스트에서 특정 데이터프레임의 이름과 결과를 찾습니다.
#     for name, result_df in negative_list_df_results:
#         if name == df_name:
#             print(f"{name}의 상위 30개 단어:")
#             print(result_df.head(30))
#             break
#     else:
#         print(f"{df_name} 데이터프레임을 찾을 수 없습니다.")

# # 예: 'skincare26_crc_negative_list_df'의 상위 30개 단어 출력
# print_keywords_by_name('skincare26_crc_negative_list_df')

# %%
# # 특정 데이터프레임의 부정 키워드만 보고 싶다면
# def print_keywords_by_name(df_name):
#     # 결과 리스트에서 특정 데이터프레임의 이름과 결과를 찾습니다.
#     for name, result_df in negative_list_df_results:
#         if name == df_name:
#             print(f"{name}의 상위 30개 단어:")
#             print(result_df.head(30))
#             break
#     else:
#         print(f"{df_name} 데이터프레임을 찾을 수 없습니다.")

# # 예: 'skincare32_crc_negative_list_df'의 상위 30개 단어 출력
# print_keywords_by_name('skincare32_crc_negative_list_df')

# %% [markdown]
# #### 테스트

# %%
# # 긍정, 부정, 중립 리스트 생성
# positive_list = []
# negative_list = []
# neutral_list = []

# # 각 텍스트에 대해 감정 분석을 수행하고 리스트에 저장
# for text in skincare32_crc_list:
#     sentiment = analyze_sentiment(text, senti_dict)
#     if sentiment == "긍정":
#         positive_list.append(text)
#     elif sentiment == "부정":
#         negative_list.append(text)
#     else:
#         neutral_list.append(text)

# # 각 리스트 출력
# print("긍정 리스트:")
# print(positive_list)

# print("\n부정 리스트:")
# print(negative_list)

# print("\n중립 리스트:")
# print(neutral_list)

# %%
# skincare32_crc_positive_list_df = pd.DataFrame({'Text': positive_list})
# skincare32_crc_negative_list_df = pd.DataFrame({'Text': negative_list})
# #crc_neutral_list_df = pd.DataFrame({'Text': neutral_list})

# # 데이터프레임을 엑셀 파일로 저장
# skincare32_crc_positive_list_df.to_excel(r"C:\Users\82108\Downloads\skincare32_crc_positive_list_df.xlsx", index=False)
# skincare32_crc_negative_list_df.to_excel(r"C:\Users\82108\Downloads\skincare32_crc_negative_list_df.xlsx", index=False)
# #crc_negative_list_df.to_excel(r"C:\Users\82108\Downloads\crc_negative_list_df.xlsx", index=False)

# %%
# from collections import Counter


# # 직접적인 단어 빈도 계산
# # 텍스트를 공백 기준으로 분할하여 모든 단어를 리스트로 만듦
# skincare32_crc_positive_words = skincare32_crc_negative_list_df['Text'].str.split().sum()
# # 단어들의 빈도를 계산
# skincare32_crc_positive_words_freq = Counter(skincare32_crc_positive_words)

# # 빈도 데이터를 데이터프레임으로 변환하여 정렬
# skincare32_crc_positive_words_freq_df = pd.DataFrame(skincare32_crc_positive_words_freq.items(), columns=['단어', '빈도']).sort_values(by='빈도', ascending=False).reset_index(drop=True)
# # 상위 10개 단어 출력
# skincare32_crc_positive_words_freq_df.head(30)

# %%
# # 각각의 리스트의 개수 계산
# positive_count = len(positive_list)
# negative_count = len(negative_list)
# neutral_count = len(neutral_list)

# # 데이터프레임 생성
# data = {
#     'Sentiment': ['긍정', '부정', '중립'],
#     'Count': [positive_count, negative_count, neutral_count]
# }

# df = pd.DataFrame(data)
# df

# %%
# from IPython.display import display

# # 두 데이터프레임의 첫 30개 행을 나란히 출력
# display(skincare32_crc_positive_words_freq_df.head(30))
# display(skincare26_crc_positive_words_freq_df.head(30))

# %%
# import pandas as pd

# # 데이터프레임을 열 방향으로 결합
# combined_df = pd.concat([skincare37_crc_positive_words_freq_df.head(30), skincare15_crc_positive_words_freq_df.head(30)], axis=1)

# # 결합된 데이터프레임 출력
# display(combined_df)

# %%
# import pandas as pd

# # 데이터프레임에서 '단어' 컬럼 추출
# words_df1 = skincare37_crc_positive_words_freq_df.head(30)['단어']
# words_df2 = skincare15_crc_positive_words_freq_df.head(30)['단어']

# # 단어 목록을 집합으로 변환
# set_words_df1 = set(words_df1)
# set_words_df2 = set(words_df2)

# # 중복 단어와 유일한 단어 찾기
# common_words = set_words_df1.intersection(set_words_df2)
# unique_to_df1 = set_words_df1 - set_words_df2
# unique_to_df2 = set_words_df2 - set_words_df1

# # 결과를 데이터프레임으로 변환
# common_words_df = pd.DataFrame(list(common_words), columns=['Common Words'])
# unique_to_df1_df = pd.DataFrame(list(unique_to_df1), columns=['Unique to DF1'])
# unique_to_df2_df = pd.DataFrame(list(unique_to_df2), columns=['Unique to DF2'])

# # 결과 출력
# display(common_words_df)
# display(unique_to_df1_df)
# display(unique_to_df2_df)

# %% [markdown]
# 기획전/단품 키워드 비교는 우선순위 박탈
# 단품 별/ 기획전별 키워드 추출
# 라인별 키워드 추출

# %% [markdown]
# ## 중복제거

# %%
# import pandas as pd

# # 각 스킨케어 데이터프레임의 고유 부정 및 긍정 단어를 저장할 딕셔너리
# skincare_unique_negative_words = {}
# skincare_unique_positive_words = {}

# # negative_list_df_results와 positive_list_df_results가 있다고 가정
# # negative_list_df_results와 positive_list_df_results는 각각 부정, 긍정 단어의 빈도 데이터프레임을 포함하는 리스트입니다.

# # 각 스킨케어 데이터프레임을 순차적으로 처리
# for neg_item, pos_item in zip(negative_list_df_results, positive_list_df_results):
#     neg_name, negative_df = neg_item  # 부정 리스트
#     pos_name, positive_df = pos_item  # 긍정 리스트
    
#     # 부정 및 긍정 프레임의 단어 리스트 추출
#     negative_words = set(negative_df.head(30)['단어'])
#     positive_words = set(positive_df.head(30)['단어'])
    
#     # 중복 단어 필터링 (부정 및 긍정에 공통으로 있는 단어를 제거)
#     common_words = negative_words & positive_words
    
#     # 중복 단어를 제외한 부정 단어 리스트
#     unique_negative_words = [word for word in negative_words if word not in common_words]
    
#     # 중복 단어를 제외한 긍정 단어 리스트
#     unique_positive_words = [word for word in positive_words if word not in common_words]
    
#     # 각 스킨케어 이름에 고유한 부정 및 긍정 단어 리스트를 딕셔너리에 저장
#     skincare_unique_negative_words[neg_name] = unique_negative_words
#     skincare_unique_positive_words[pos_name] = unique_positive_words

# # 예시 출력: 각 스킨케어의 고유 부정 및 긍정 단어 리스트 출력
# for neg_name in skincare_unique_negative_words:
#     print(f"{neg_name}의 고유 부정 단어 리스트:")
#     print(skincare_unique_negative_words[neg_name])
#     print("\n")

# for pos_name in skincare_unique_positive_words:
#     print(f"{pos_name}의 고유 긍정 단어 리스트:")
#     print(skincare_unique_positive_words[pos_name])
#     print("\n")

# %%
#이걸로 해야 word clolud 할 수 있다~
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 각 스킨케어 데이터프레임의 고유 부정 및 긍정 단어를 저장할 딕셔너리
skincare_unique_negative_words = {}
skincare_unique_positive_words = {}

# negative_list_df_results와 positive_list_df_results가 있다고 가정
# negative_list_df_results와 positive_list_df_results는 각각 부정, 긍정 단어의 빈도 데이터프레임을 포함하는 리스트입니다.

# 각 스킨케어 데이터프레임을 순차적으로 처리
for neg_item, pos_item in zip(negative_list_df_results, positive_list_df_results):
    neg_name, negative_df = neg_item  # 부정 리스트
    pos_name, positive_df = pos_item  # 긍정 리스트
    
    # 부정 및 긍정 프레임의 단어 리스트 추출
    negative_words = set(negative_df.head(30)['단어'])
    positive_words = set(positive_df.head(30)['단어'])
    
    # 중복 단어 필터링 (부정 및 긍정에 공통으로 있는 단어를 제거)
    common_words = negative_words & positive_words
    
    # 중복 단어를 제외한 부정/긍정 단어 리스트와 빈도 값 추출
    unique_negative_df = negative_df[negative_df['단어'].isin(negative_words - common_words)]
    unique_positive_df = positive_df[positive_df['단어'].isin(positive_words - common_words)]
    
    # 고유 단어와 빈도를 딕셔너리에 저장 (워드클라우드용 데이터 생성)
    skincare_unique_negative_words[neg_name] = dict(zip(unique_negative_df['단어'], unique_negative_df['빈도']))
    skincare_unique_positive_words[pos_name] = dict(zip(unique_positive_df['단어'], unique_positive_df['빈도']))

# 예시 출력: 각 스킨케어의 고유 부정 및 긍정 단어 리스트 출력
for neg_name in skincare_unique_negative_words:
    print(f"{neg_name}의 고유 부정 단어 리스트:")
    print(skincare_unique_negative_words[neg_name])
    print("\n")

for pos_name in skincare_unique_positive_words:
    print(f"{pos_name}의 고유 긍정 단어 리스트:")
    print(skincare_unique_positive_words[pos_name])
    print("\n")
# Out:
# skincare26_crc_negative_list_df의 고유 부정 단어 리스트:
# {'없이': 13, '부족': 10, '부담': 9, '포맨': 6, '겨울': 5, '건조': 5, '없': 5, '수분': 4, '시': 4, '때': 4, '자작나무': 4, '좀': 3, '불편': 3}
#
#
# skincare27_crc_negative_list_df의 고유 부정 단어 리스트:
# {'부족': 17, '없이': 14, '지성': 14, '수분': 13, '부담': 13, '분': 7, '수': 7, '겨울': 5, '때': 5, '저': 4, '화장품': 4, '편': 4, '시': 4}
#
#
# skincare28_crc_negative_list_df의 고유 부정 단어 리스트:
# {'없이': 16, '부담': 14, '수분': 13, '부족': 12, '바르': 9, '지성': 8, '트러블': 8, '수': 6, '않': 5, '나': 5, '화': 5, '좀': 5, '올라오': 5, '이거': 5}
#
#
# skincare32_crc_negative_list_df의 고유 부정 단어 리스트:
# {'부족': 50, '지성': 42, '부담': 22, '없이': 22, '분': 17, '건성': 12, '시': 12, '민감': 11, '안': 11, '성분': 11, '바르': 11}
#
#
# skincare26_crc_positive_list_df의 고유 긍정 단어 리스트:
# {'잘': 199, '친구': 85, '주': 64, '습니다': 54, '만족': 50, '되': 49, '보': 44, '너무': 36, '선물': 35, '흡수': 33, '네요': 30, '저': 29, '맞': 23}
#
#
# skincare27_crc_positive_list_df의 고유 긍정 단어 리스트:
# {'잘': 284, '친구': 102, '만족': 96, '주': 89, '사': 76, '되': 69, '선물': 56, '보': 52, '구매': 51, '맞': 49, '않': 39, '안': 32, '흡수': 29}
#
#
# skincare28_crc_positive_list_df의 고유 긍정 단어 리스트:
# {'잘': 282, '친구': 137, '남자': 129, '만족': 117, 'ᆸ니다': 97, '사': 95, '선물': 78, '구매': 62, '맞': 44, '되': 43, '시': 42, '보습': 42, '로션': 29, '안': 27}
#
#
# skincare32_crc_positive_list_df의 고유 긍정 단어 리스트:
# {'잘': 193, '보': 85, '만족': 80, '되': 73, '자작나무': 49, '맞': 43, '너무': 40, '독도': 38, '흡수': 30, '랩': 27, '느낌': 27}

# %% [markdown]
# # word cloud

# %%
#부정 단어 딕셔너리들
# skincare_unique_negative_words
#긍정 단어 딕셔너리들
# skincare_unique_positive_words

#병합: 단어와 빈도를 합치고, 같은 단어가 여러 스킨케어 제품에 등장할 경우 빈도를 누적하여 더함


# 부정 단어 리스트 병합
combined_negative_words = {}
for word_dict in skincare_unique_negative_words.values():
    for word, freq in word_dict.items():
        if word in combined_negative_words:
            combined_negative_words[word] += freq
        else:
            combined_negative_words[word] = freq

# 긍정 단어 리스트 병합
combined_positive_words = {}
for word_dict in skincare_unique_positive_words.values():
    for word, freq in word_dict.items():
        if word in combined_positive_words:
            combined_positive_words[word] += freq
        else:
            combined_positive_words[word] = freq

# 결과 출력
print("부정 단어 리스트:")
print(combined_negative_words)

print("\n긍정 단어 리스트:")
print(combined_positive_words)
# Out:
# 부정 단어 리스트:
# {'없이': 65, '부족': 89, '부담': 58, '포맨': 6, '겨울': 10, '건조': 5, '없': 5, '수분': 30, '시': 20, '때': 9, '자작나무': 4, '좀': 8, '불편': 3, '지성': 64, '분': 24, '수': 13, '저': 4, '화장품': 4, '편': 4, '바르': 20, '트러블': 8, '않': 5, '나': 5, '화': 5, '올라오': 5, '이거': 5, '건성': 12, '민감': 11, '안': 11, '성분': 11}
#
# 긍정 단어 리스트:
# {'잘': 958, '친구': 324, '주': 153, '습니다': 54, '만족': 343, '되': 234, '보': 181, '너무': 76, '선물': 169, '흡수': 92, '네요': 30, '저': 29, '맞': 159, '사': 171, '구매': 113, '않': 39, '안': 59, '남자': 129, 'ᆸ니다': 97, '시': 42, '보습': 42, '로션': 29, '자작나무': 49, '독도': 38, '랩': 27, '느낌': 27}

# %%
unique_positive_df_sorted = pd.DataFrame(list(combined_positive_words.items()), columns=['단어','빈도'])
unique_negative_df_sorted = pd.DataFrame(list(combined_negative_words.items()), columns=['단어','빈도'])

unique_negative_df_sorted
# Out:
#       단어  빈도
# 0     없이  65
# 1     부족  89
# 2     부담  58
# 3     포맨   6
# 4     겨울  10
# 5     건조   5
# 6      없   5
# 7     수분  30
# 8      시  20
# 9      때   9
# 10  자작나무   4
# 11     좀   8
# 12    불편   3
# 13    지성  64
# 14     분  24
# 15     수  13
# 16     저   4
# 17   화장품   4
# 18     편   4
# 19    바르  20
# 20   트러블   8
# 21     않   5
# 22     나   5
# 23     화   5
# 24   올라오   5
# 25    이거   5
# 26    건성  12
# 27    민감  11
# 28     안  11
# 29    성분  11

# %% [markdown]
# ## 부정

# %%
#부정
#불필요한 글자 제거
df_word = unique_negative_df_sorted.drop(index=[0,6,8,9,11,14,15,16,18,19,21,22,23,25,28])
df_word
# Out:
#       단어  빈도
# 1     부족  89
# 2     부담  58
# 3     포맨   6
# 4     겨울  10
# 5     건조   5
# 7     수분  30
# 10  자작나무   4
# 12    불편   3
# 13    지성  64
# 17   화장품   4
# 20   트러블   8
# 24   올라오   5
# 26    건성  12
# 27    민감  11
# 29    성분  11

# %%
# DataFrame -> Dictionary
dic_word = df_word.set_index('단어').to_dict()['빈도']
dic_word
# Out:
# {'부족': 89,
#  '부담': 58,
#  '포맨': 6,
#  '겨울': 10,
#  '건조': 5,
#  '수분': 30,
#  '자작나무': 4,
#  '불편': 3,
#  '지성': 64,
#  '화장품': 4,
#  '트러블': 8,
#  '올라오': 5,
#  '건성': 12,
#  '민감': 11,
#  '성분': 11}

# %%
# 채택!!
import numpy as np
from wordcloud import WordCloud #워드클라우드 제작 라이브러리
import matplotlib.pyplot as plt  #워드클라우드 시각화 라이브러리

# 워드클라우드에서 각 단어에 적용할 색상을 결정하는 함수
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    # 색조(hue) 지정
    hue_choices = [203,220]    #np.random.randint(50, 100)   # 색상의 기본 톤 hsl(203, 50%, 80%)  hsl(220, 31%, 39%)
    hue = np.random.choice(hue_choices)
    # 채도(saturation) 지정
    saturation_choices = [50,31]
    saturation = np.random.choice(saturation_choices)
    
    # 밝기는 랜덤 범위로 설정
    lightness = np.random.randint(39, 80)   # 사이의 랜덤 밝기
    
    # hsl 형식으로 색상 값을 반환
    return f"hsl({hue}, {saturation}%, {lightness}%)"

font_path=r"C:\대학교\학생성장지원시스템\(탈잉)실무에 가장 많이 쓰는 PPT 디자인\Jalnan.ttf"

#wordcloud 함수 사용
wc = WordCloud(random_state=42,font_path= font_path , width = 400,
               height = 400, background_color = 'white', color_func = color_func )
img_wordcloud = wc.generate_from_frequencies(dic_word)

plt.figure(figsize = (10, 10)) #크기 지정하기
plt.axis('off') #축 없애기
plt.imshow(img_wordcloud) #결과 보여주기
plt.savefig('Skincare_J_negative_wordcloud') #파일 저장 #black soybean

# %% [markdown]
# ## 긍정

# %%
unique_positive_df_sorted
# Out:
#       단어   빈도
# 0      잘  958
# 1     친구  324
# 2      주  153
# 3    습니다   54
# 4     만족  343
# 5      되  234
# 6      보  181
# 7     너무   76
# 8     선물  169
# 9     흡수   92
# 10    네요   30
# 11     저   29
# 12     맞  159
# 13     사  171
# 14    구매  113
# 15     않   39
# 16     안   59
# 17    남자  129
# 18   ᆸ니다   97
# 19     시   42
# 20    보습   42
# 21    로션   29
# 22  자작나무   49
# 23    독도   38
# 24     랩   27
# 25    느낌   27

# %%
#긍정
#불필요한 글자 제거
df_word2 = unique_positive_df_sorted.drop(index=[0,2,3,5,6,7,10,11,12,13,15,16,18,19,24])
df_word2
# Out:
#       단어   빈도
# 1     친구  324
# 4     만족  343
# 8     선물  169
# 9     흡수   92
# 14    구매  113
# 17    남자  129
# 20    보습   42
# 21    로션   29
# 22  자작나무   49
# 23    독도   38
# 25    느낌   27

# %%
# DataFrame -> Dictionary
dic_word2 = df_word2.set_index('단어').to_dict()['빈도']
dic_word2
# Out:
# {'친구': 324,
#  '만족': 343,
#  '선물': 169,
#  '흡수': 92,
#  '구매': 113,
#  '남자': 129,
#  '보습': 42,
#  '로션': 29,
#  '자작나무': 49,
#  '독도': 38,
#  '느낌': 27}

# %%
# 채택!!
import numpy as np
from wordcloud import WordCloud #워드클라우드 제작 라이브러리
import matplotlib.pyplot as plt  #워드클라우드 시각화 라이브러리

# 워드클라우드에서 각 단어에 적용할 색상을 결정하는 함수
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    # 색조(hue) 지정
    hue_choices = [203,220]    #np.random.randint(50, 100)   # 색상의 기본 톤 hsl(203, 50%, 80%)  hsl(220, 31%, 39%)
    hue = np.random.choice(hue_choices)
    # 채도(saturation) 지정
    saturation_choices = [50,31]
    saturation = np.random.choice(saturation_choices)
    
    # 밝기는 랜덤 범위로 설정
    lightness = np.random.randint(39, 80)   # 사이의 랜덤 밝기
    
    # hsl 형식으로 색상 값을 반환
    return f"hsl({hue}, {saturation}%, {lightness}%)"

font_path=r"C:\대학교\학생성장지원시스템\(탈잉)실무에 가장 많이 쓰는 PPT 디자인\Jalnan.ttf"

#wordcloud 함수 사용
wc = WordCloud(random_state=42,font_path= font_path , width = 400,
               height = 400, background_color = 'white', color_func = color_func )
img_wordcloud = wc.generate_from_frequencies(dic_word2)

plt.figure(figsize = (10, 10)) #크기 지정하기
plt.axis('off') #축 없애기
plt.imshow(img_wordcloud) #결과 보여주기
plt.savefig('Skincare_J_positive_wordcloud') #파일 저장
