# %% [markdown]
# # 소나무
# - skincare8	[고민진정] 라운드랩 포 맨 소나무 진정 시카 크림 75ml
# - skincare9	[화해1위] 라운드랩 포 맨 소나무 진정 시카 로션 200ml
# - skincare10	[고민진정] 라운드랩 포 맨 소나무 진정 시카 토너 200ml
# - skincare19	[민감진정] 라운드랩 소나무 진정 시카 토너 250ml
# - skincare20	[민감진정] 라운드랩 소나무 진정 시카 로션 250ml

# %% [markdown]
# ## 파일 불러오기

# %%
#skincare8 포 맨 크림
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare8_crc.xlsx"
skincare8_crc_df = pd.read_excel(file_path)
print(skincare8_crc_df)
# Out:
#                                                       0
# 0                                      역시 진정 라운드 랩 더라고요
# 1                                소나무 추출 팔 미리 바르 보 사용 어요
# 2                              세일 사 건조 잘 주 순하 같 다음 로션 사
# 3                                    군대 가 동생 필요 구매 주 어요
# 4                                       라운드 랩 라인 쓰 같 어요
# ...                                                 ...
# 2056                                              추천 어요
# 2057  나 기름 많이 나오 속 땅기 자작나무 안 나 기름 많이 나오 진정 필요 소나무 라인...
# 2058  토너 크림 중간 수분 앰풀 넣 주 속 건조 싹 잡히 습니다 복합 피부 기준 지금 같...
# 2059                              여름 크림 로션 바꾸 되 꺼 같 습니다
# 2060                       자작나무 수분 라인 잘 쓰 시키 보 너무 기대 네요
#
# [2061 rows x 1 columns]

# %%
#skincare9 포 맨 로션
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare9_crc.xlsx"
skincare9_crc_df = pd.read_excel(file_path)
print(skincare9_crc_df)
# Out:
#                                           0
# 0                              아직 잘 쓰 있 습니다
# 1      토너 로션 화장 전 기초 많이 사용 클렌징 폼 항상 사용 중 에요
# 2       거품 잘 나 자극 없이 순하 저 사용 때 트러블 올라오 않 어요
# 3                                        어요
# 4                             처음 구매 보 효과 네요
# ...                                     ...
# 2277          평소 쓰 토너 로션 세트 할인 이벤트 쟁이 놓 ᆸ니다
# 2278         토너 사용 보 사용 때 산뜻 느낌 들 촉촉 느끼 ᆸ니다
# 2279  수분 너무 촉촉하 에누리 판매 기간 때 저렴하 사 너무 만족 ᆸ니다
# 2280                       보습 로션 좀 묽 그래도 어요
# 2281                           이벤트 가격 진짜 최고
#
# [2282 rows x 1 columns]

# %%
#skincare10 포 맨 토너
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare10_crc.xlsx"
skincare10_crc_df = pd.read_excel(file_path)
print(skincare10_crc_df)
# Out:
#                                               0
# 0                                            어요
# 1                                 처음 구매 보 효과 네요
# 2            평소 독도 쓰 트러블 올라오 이거 진정 트러블 안 올라오 어요
# 3                          진짜 지성 피부 강력 추천 꼭 쓰 보
# 4                                 진짜 강력히 추천 ᆸ니다
# ...                                         ...
# 2236  평소 조금 틀어지 여드름 홍조 건조 많이 올라오 이번 쓰 많이 잠잠 습니다
# 2237                               앞 계속 사용 같 어요
# 2238                                      산뜻 어요
# 2239                                  족 점 있 습니다
# 2240                                   남자 친구 어요
#
# [2241 rows x 1 columns]

# %%
#skincar19 토너
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare19_crc.xlsx"
skincare19_crc_df = pd.read_excel(file_path)
print(skincare19_crc_df)
# Out:
#                                                0
# 0                         화장품 잘못 쓰 뒤집히 순하 진정 습니다
# 1         여름 사용 너무 은데요 진정 잘 되 팩 닦 자극 없이 수 있 더 어요
# 2                                   뾰루지 많이 개선 네요
# 3                      독도 유명 개인 이것 같 내 팩 토하 같 어요
# 4                                          향 안 나
# ..                                           ...
# 500                            토너 깔끔 타입 아주 만족 어요
# 501                                     향 거의 무 향
# 502                        색 소나무 추출액 초록색 ᆫ가 보 어요
# 503  간혹 피부 열 올라오 울긋불긋 소나무 토너 패드 너무 잘 쓰 토너 구매 습니다
# 504                                꾸준히 잘 쓰 보 습니다
#
# [505 rows x 1 columns]

# %%
#skincare20 로션
import pandas as pd
file_path = r"C:\Users\82108\Downloads\제품리뷰전처리\skincare20_crc.xlsx"
skincare20_crc_df = pd.read_excel(file_path)
print(skincare20_crc_df)
# Out:
#                                      0
# 0              진정 되 잘 느끼 보습 감 끈적이 않 어요
# 1                            여름철 끈적이 ᆷ
# 2              없이 순하 제품 수분 부족 지성 피부 추천
# 3     순하 보습 원하 비추 기초 바르 끈적 아예 싫 분 살 세요
# 4              저 끈적 보습 팀 바르 살 사람 별로 어요
# ...                                ...
# 1016                          자극 적 끈적이
# 1017                      없이 빠르 흡수 ᆸ니다
# 1018                 라운드 랩 제품 순하 느끼 어요
# 1019                            만족 습니다
# 1020                          양 꽤 많 어요
#
# [1021 rows x 1 columns]

# %%
import pandas as pd

# 데이터프레임을 리스트에 저장(단품)
dataframes_list1 = [
    skincare8_crc_df,
    skincare9_crc_df,
    skincare10_crc_df,
    skincare19_crc_df,
    skincare20_crc_df
]

dataframes_list1
# Out:
# [                                                      0
#  0                                      역시 진정 라운드 랩 더라고요
#  1                                소나무 추출 팔 미리 바르 보 사용 어요
#  2                              세일 사 건조 잘 주 순하 같 다음 로션 사
#  3                                    군대 가 동생 필요 구매 주 어요
#  4                                       라운드 랩 라인 쓰 같 어요
#  ...                                                 ...
#  2056                                              추천 어요
#  2057  나 기름 많이 나오 속 땅기 자작나무 안 나 기름 많이 나오 진정 필요 소나무 라인...
#  2058  토너 크림 중간 수분 앰풀 넣 주 속 건조 싹 잡히 습니다 복합 피부 기준 지금 같...
#  2059                              여름 크림 로션 바꾸 되 꺼 같 습니다
#  2060                       자작나무 수분 라인 잘 쓰 시키 보 너무 기대 네요
#
#  [2061 rows x 1 columns],
#                                            0
#  0                              아직 잘 쓰 있 습니다
#  1      토너 로션 화장 전 기초 많이 사용 클렌징 폼 항상 사용 중 에요
#  2       거품 잘 나 자극 없이 순하 저 사용 때 트러블 올라오 않 어요
#  3                                        어요
#  4                             처음 구매 보 효과 네요
#  ...                                     ...
#  2277          평소 쓰 토너 로션 세트 할인 이벤트 쟁이 놓 ᆸ니다
#  2278         토너 사용 보 사용 때 산뜻 느낌 들 촉촉 느끼 ᆸ니다
#  2279  수분 너무 촉촉하 에누리 판매 기간 때 저렴하 사 너무 만족 ᆸ니다
#  2280                       보습 로션 좀 묽 그래도 어요
#  2281                           이벤트 가격 진짜 최고
#
#  [2282 rows x 1 columns],
#                                                0
#  0                                            어요
#  1                                 처음 구매 보 효과 네요
#  2            평소 독도 쓰 트러블 올라오 이거 진정 트러블 안 올라오 어요
#  3                          진짜 지성 피부 강력 추천 꼭 쓰 보
#  4                                 진짜 강력히 추천 ᆸ니다
#  ...                                         ...
#  2236  평소 조금 틀어지 여드름 홍조 건조 많이 올라오 이번 쓰 많이 잠잠 습니다
#  2237                               앞 계속 사용 같 어요
#  2238                                      산뜻 어요
#  2239                                  족 점 있 습니다
#  2240                                   남자 친구 어요
#
#  [2241 rows x 1 columns],
#                                                 0
#  0                         화장품 잘못 쓰 뒤집히 순하 진정 습니다
#  1         여름 사용 너무 은데요 진정 잘 되 팩 닦 자극 없이 수 있 더 어요
#  2                                   뾰루지 많이 개선 네요
#  3                      독도 유명 개인 이것 같 내 팩 토하 같 어요
#  4                                          향 안 나
#  ..                                           ...
#  500                            토너 깔끔 타입 아주 만족 어요
#  501                                     향 거의 무 향
#  502                        색 소나무 추출액 초록색 ᆫ가 보 어요
#  503  간혹 피부 열 올라오 울긋불긋 소나무 토너 패드 너무 잘 쓰 토너 구매 습니다
#  504                                꾸준히 잘 쓰 보 습니다
#
#  [505 rows x 1 columns],
#                                       0
#  0              진정 되 잘 느끼 보습 감 끈적이 않 어요
#  1                            여름철 끈적이 ᆷ
#  2              없이 순하 제품 수분 부족 지성 피부 추천
#  3     순하 보습 원하 비추 기초 바르 끈적 아예 싫 분 살 세요
#  4              저 끈적 보습 팀 바르 살 사람 별로 어요
#  ...                                ...
#  1016                          자극 적 끈적이
#  1017                      없이 빠르 흡수 ᆸ니다
#  1018                 라운드 랩 제품 순하 느끼 어요
#  1019                            만족 습니다
#  1020                          양 꽤 많 어요
#
#  [1021 rows x 1 columns]]

# %% [markdown]
# # 소나무 감성분석

# %%
# 형태소 분석기
from konlpy.tag import Okt
okt = Okt()

# SentiWord_Dict.txt 감성사전 불러오기
def load_senti_dict(file_path):
    senti_dict = {}
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split()  # 공백으로 분리
            if len(parts) > 1:
                word = ' '.join(parts[:-1])  # 마지막 항목을 제외한 나머지를 단어로 결합
                score = int(parts[-1])  # 마지막 항목을 점수로 처리
                senti_dict[word] = score
            else:
                print(f"해당 줄을 무시합니다: {line}")
    return senti_dict

# 감성 사전 로드
senti_dict = load_senti_dict(r"C:\Users\82108\Downloads\KnuSentiLex-master(1)\KnuSentiLex-master\SentiWord_Dict.txt")

# 감성 분석 함수 
def analyze_sentiment(text, senti_dict):
    # 형태소 분석
    morphs = okt.morphs(text)
    
    # 감정 점수 계산
    sentiment_score = 0
    for word in morphs:
        if word in senti_dict:  # 단어가 사전에 있는 경우
            sentiment_score += senti_dict[word]
    
    # 점수에 따라 감정 판단
    if sentiment_score > 0:
        return "긍정"
    elif sentiment_score < 0:
        return "부정"
    else:
        return "중립"

# %% [markdown]
# ## 긍정/부정/중립

# %%
#단품 리스트
# 데이터프레임과 이름을 튜플로 저장
dataframes = [
    ("skincare8_crc_df", skincare8_crc_df),
    ("skincare9_crc_df", skincare9_crc_df),
    ("skincare10_crc_df", skincare10_crc_df),
    ("skincare19_crc_df", skincare19_crc_df),
    ("skincare20_crc_df", skincare20_crc_df)
]

results_list = []

# 각 데이터프레임 처리 및 결과 출력
for name, df in dataframes:
    print(f"Processing DataFrame: {name}")
    
    # 텍스트를 리스트로 변환
    skincare_text_list1 = df.iloc[:, 0].astype(str).tolist()
    
    # 감성 분석 수행
    skincare_results1 = [(text, analyze_sentiment(text, senti_dict)) for text in skincare_text_list1]
    
    # 결과 데이터프레임 생성
    skincare_results1_df = pd.DataFrame(skincare_results1, columns=['Text', 'Sentiment'])
    
    # 결과를 리스트에 저장
    results_list.append((name, skincare_results1_df))
    
    # 결과 출력
    print(skincare_results1_df)
    print("\n")  # 각 데이터프레임 결과 사이에 공백 추가
# Out:
# Processing DataFrame: skincare8_crc_df
#                                                    Text Sentiment
# 0                                      역시 진정 라운드 랩 더라고요        중립
# 1                                소나무 추출 팔 미리 바르 보 사용 어요        중립
# 2                              세일 사 건조 잘 주 순하 같 다음 로션 사        긍정
# 3                                    군대 가 동생 필요 구매 주 어요        중립
# 4                                       라운드 랩 라인 쓰 같 어요        중립
# ...                                                 ...       ...
# 2056                                              추천 어요        중립
# 2057  나 기름 많이 나오 속 땅기 자작나무 안 나 기름 많이 나오 진정 필요 소나무 라인...        중립
# 2058  토너 크림 중간 수분 앰풀 넣 주 속 건조 싹 잡히 습니다 복합 피부 기준 지금 같...        중립
# 2059                              여름 크림 로션 바꾸 되 꺼 같 습니다        중립
# 2060                       자작나무 수분 라인 잘 쓰 시키 보 너무 기대 네요        긍정
#
# [2061 rows x 2 columns]
#
#
# Processing DataFrame: skincare9_crc_df
#                                        Text Sentiment
# 0                              아직 잘 쓰 있 습니다        긍정
# 1      토너 로션 화장 전 기초 많이 사용 클렌징 폼 항상 사용 중 에요        중립
# 2       거품 잘 나 자극 없이 순하 저 사용 때 트러블 올라오 않 어요        긍정
# 3                                        어요        중립
# 4                             처음 구매 보 효과 네요        중립
# ...                                     ...       ...
# 2277          평소 쓰 토너 로션 세트 할인 이벤트 쟁이 놓 ᆸ니다        긍정
# 2278         토너 사용 보 사용 때 산뜻 느낌 들 촉촉 느끼 ᆸ니다        중립
# 2279  수분 너무 촉촉하 에누리 판매 기간 때 저렴하 사 너무 만족 ᆸ니다        긍정
# 2280                       보습 로션 좀 묽 그래도 어요        중립
# 2281                           이벤트 가격 진짜 최고        긍정
#
# [2282 rows x 2 columns]
#
#
# Processing DataFrame: skincare10_crc_df
#                                            Text Sentiment
# 0                                            어요        중립
# 1                                 처음 구매 보 효과 네요        중립
# 2            평소 독도 쓰 트러블 올라오 이거 진정 트러블 안 올라오 어요        중립
# 3                          진짜 지성 피부 강력 추천 꼭 쓰 보        중립
# 4                                 진짜 강력히 추천 ᆸ니다        중립
# ...                                         ...       ...
# 2236  평소 조금 틀어지 여드름 홍조 건조 많이 올라오 이번 쓰 많이 잠잠 습니다        중립
# 2237                               앞 계속 사용 같 어요        중립
# 2238                                      산뜻 어요        중립
# 2239                                  족 점 있 습니다        중립
# 2240                                   남자 친구 어요        긍정
#
# [2241 rows x 2 columns]
#
#
# Processing DataFrame: skincare19_crc_df
#                                             Text Sentiment
# 0                         화장품 잘못 쓰 뒤집히 순하 진정 습니다        부정
# 1         여름 사용 너무 은데요 진정 잘 되 팩 닦 자극 없이 수 있 더 어요        긍정
# 2                                   뾰루지 많이 개선 네요        긍정
# 3                      독도 유명 개인 이것 같 내 팩 토하 같 어요        중립
# 4                                          향 안 나        중립
# ..                                           ...       ...
# 500                            토너 깔끔 타입 아주 만족 어요        긍정
# 501                                     향 거의 무 향        중립
# 502                        색 소나무 추출액 초록색 ᆫ가 보 어요        중립
# 503  간혹 피부 열 올라오 울긋불긋 소나무 토너 패드 너무 잘 쓰 토너 구매 습니다        긍정
# 504                                꾸준히 잘 쓰 보 습니다        긍정
#
# [505 rows x 2 columns]
#
#
# Processing DataFrame: skincare20_crc_df
#                                   Text Sentiment
# 0              진정 되 잘 느끼 보습 감 끈적이 않 어요        긍정
# 1                            여름철 끈적이 ᆷ        중립
# 2              없이 순하 제품 수분 부족 지성 피부 추천        부정
# 3     순하 보습 원하 비추 기초 바르 끈적 아예 싫 분 살 세요        중립
# 4              저 끈적 보습 팀 바르 살 사람 별로 어요        중립
# ...                                ...       ...
# 1016                          자극 적 끈적이        중립
# 1017                      없이 빠르 흡수 ᆸ니다        중립
# 1018                 라운드 랩 제품 순하 느끼 어요        중립
# 1019                            만족 습니다        긍정
# 1020                          양 꽤 많 어요        중립
#
# [1021 rows x 2 columns]

# %% [markdown]
# ## 긍정/부정/중립 리스트 만들기

# %%
import pandas as pd
from konlpy.tag import Okt

# 형태소 분석기 초기화
okt = Okt()

# 감성 분석 함수 정의
def analyze_sentiment(text, senti_dict):
    # 형태소 분석
    morphs = okt.morphs(text)
    
    # 감정 점수 계산
    sentiment_score = 0
    for word in morphs:
        if word in senti_dict:  # 단어가 사전에 있는 경우
            sentiment_score += senti_dict[word]
    
    # 점수에 따라 감정 판단
    if sentiment_score > 0:
        return "긍정"
    elif sentiment_score < 0:
        return "부정"
    else:
        return "중립"


# 데이터프레임과 이름을 튜플로 저장
dataframes = [
     ("skincare8_crc_df", skincare8_crc_df),
    ("skincare9_crc_df", skincare9_crc_df),
    ("skincare10_crc_df", skincare10_crc_df),
    ("skincare19_crc_df", skincare19_crc_df),
    ("skincare20_crc_df", skincare20_crc_df)
]

# 결과를 저장할 딕셔너리 (각 데이터프레임별로)
results_dict = {}

# 각 데이터프레임 처리 및 감정 분석 수행
for name, df in dataframes:
    print(f"Processing DataFrame: {name}")
    
    # 텍스트를 리스트로 변환
    text_list = df.iloc[:, 0].astype(str).tolist()
    
    # 긍정, 부정, 중립 리스트 초기화
    positive_list = []
    negative_list = []
    neutral_list = []
    
    # 감성 분석 수행 및 리스트에 저장
    for text in text_list:
        sentiment = analyze_sentiment(text, senti_dict)
        if sentiment == "긍정":
            positive_list.append(text)
        elif sentiment == "부정":
            negative_list.append(text)
        else:
            neutral_list.append(text)
    
    # 결과를 각 데이터프레임 이름별로 저장
    results_dict[name] = {
        "긍정": positive_list,
        "부정": negative_list,
        "중립": neutral_list
    }
# Out:
# Processing DataFrame: skincare8_crc_df
# Processing DataFrame: skincare9_crc_df
# Processing DataFrame: skincare10_crc_df
# Processing DataFrame: skincare19_crc_df
# Processing DataFrame: skincare20_crc_df

# %%
results_dict['skincare8_crc_df']
# Out:
# {'긍정': ['세일 사 건조 잘 주 순하 같 다음 로션 사',
#   '남자 친구 선물 주 어요',
#   '동생 꾸준히 잘 쓰 있 피붓결 좀 정리 같 어요',
#   '남자 친구 선물 사 엄청나 잘 쓰 있 더라고',
#   '진정 굉장히 잘 되 보습 감 어요',
#   '예전 잘 쓰 성분 구매 ᆸ니다',
#   '다음 할인 좀 더',
#   '세트 너무 편리 같 어요',
#   '라운드 랩 서 크림 잘 사용 있 피부 진정 보습 크림 구매 보 어요',
#   '아직 더 쓰 보 지금 정말 만족 사용 있 습니다',
#   '얼마나 행복 어요',
#   '특히 토너 진정 도움 되 같 어요',
#   '별나 우리 아빠 세수 후 누르 매우 잘 쓰 시 ᆷ',
#   '남자 친구 소나무 라인 좋아하 구매 어요',
#   '지성 끈적거리 없 만족 ᆸ니다',
#   '감사 ᆸ니다',
#   '잘 사용 습니다',
#   '홍조 개선',
#   '가격 최고 중 최고',
#   '남자 친구 사 주 민감 트러블 잘 쓰 있 같 어요',
#   '확실히 인기 있 이유 있 네요',
#   '할인 전 살 고민 었었 집 오 보 관하 살림 할인 영상 뜨 바로 사 습니다',
#   '남자 친구 구매 주 자극 않 ᆸ니다',
#   '잘 쓰 ᆯ게요',
#   '흡수 진짜 잘 되 체형 산뜻 좀 적 편 어요',
#   '발림 촉촉 잘 발리 네요',
#   '쫀쫀 잘 발리 같 어요',
#   '유명 브랜드 기대 되게 많이 저 생각 훨씬 괜찮 어요',
#   '아주 만족 습니다',
#   '잘 사용 있 어요',
#   '꾸준히 쓰 중 야',
#   '남자 친구 선물 사 주 어요',
#   '잘 쓰 있 다네',
#   '남자 친구 피부 뒤집어지 사 주 어요',
#   '자극 없이 순하 만족 사용 있 ᆸ니다',
#   '민감 지성 피부 번들거리 주 트러블 돌보 주 제품 중 찾 보 제품 저 피부 잘 맞 같 선택 자극 없이 순 진정 되 괜찮 더라고',
#   '없이 잘 흡수 피붓결 정돈 되 촉촉하 수분 공급 잘 되 만족 잘 사용 중 에요',
#   '너무 성공 만족 ᆸ니다',
#   '남성 전용 쓰이 있 저 피부 안 맞 줄 알 하도 예민 트러블 많 너무 놀라 정도 잘 맞 네요',
#   '나머지 인생 크림 정도 너무 만족 고민 많이 소나무 제품 더욱더 구매 어요',
#   '사랑 ᆸ니다',
#   '아주 잘 사용 있 어요',
#   '단점 뚜껑 안정감 주 않 같 어요',
#   '저 기분 탓 모르 일단 잘 닫히 걸리 그것 ᆸ니다',
#   '잘 맞 같 무난하 쓰 같 어요',
#   '넘치 잘 쓰 저 잘',
#   '꾸준히 쓰 효과 있 같 어요',
#   '남편 쓰 잘 사용',
#   '자극 없이 순하 데일리 크림 최고 예요',
#   '크림 묽 끈적거리 싫어하 매우 만족 같 어요',
#   '저 형 수분 보충 잘 주 기름지 느낌 별로 없 습니다',
#   '진정 수분 같 여드름 피부 자극 않 꾸준히 쓰 보 어요',
#   '남자 친구 팍팍 쓰 가성비 어요',
#   '만족 어요',
#   '역시 진정 최고',
#   '남자 친구 사 주 만족 ᆫ다네',
#   '늘 쓰 제품 할인 때 구매 어요',
#   '자극 없이 순하 보습 잘 되 어요',
#   '잘 쓰 ᆯ게여',
#   '감사 ᆫ다',
#   '남자 친구 선물 구매 저 더 잘 쓰 중',
#   '저 특히 스킨 너무 잘 쓰 중 에요',
#   '여드름 피부 사용 구매 꾸준히 쓰 어요',
#   '남자 친구 사 주 잘 바르 어요',
#   '여드름 친구 쓰 여드름 잘 안 나 선물 주 너무 만족 어요',
#   '로션 크림 다 제형 크림 구매 데 만족 어요',
#   '크크 친구 대요',
#   '최고 ᆸ니다',
#   '이거 쓰 잡티 많이 사라지 최고 화장품 에요',
#   '여드름 피부 남자 친구 선물 사 주 어요',
#   '자작나무 라인 너무 만족 상품 또한 기대 되 네요',
#   '아주 만족 습니다',
#   '감사 ᆸ니다',
#   '만족 어요',
#   '달 사용 진정 잘 되 남자 잘 맞 피부 관리 제품 ᆸ니다',
#   '잘 사용 있 습니다',
#   '토너 클렌징 잘 사용 있 어요',
#   '크림 좀 별로 잘 모르 어요',
#   '매일 매일 꾸준히 바르 보 새 피부 훨씬 더라고',
#   '보습 감 지성 피부 잘 맞 어요',
#   '생각 진정 잘 되 않 같 어요',
#   '진정 수분 같 여드름 피부 자극 않 꾸준히 쓰 보 어요',
#   '남자 친구 주 사 어요',
#   '여드름 피부 잘 맞 네요',
#   '동생 라운드 랩 소나무 라인 워낙 잘 쓰 남자 세트 아예 구매 어요',
#   '동생 끈적 되게 싫 데 잘 바르 더라고요',
#   '할인 행사 많이 주',
#   '마침 스킨 크림 세트 기획 할인 중 구매 어요',
#   '자극 않 잘 쓰 있 다네',
#   '토너 무난 보습 채우 주 지성 피부 저 잘 맞 크림 바르 나 금방 흡수 되 끈적이',
#   '토너 팩 물 같 제형 만족 구성 품 만족 ᆸ니다',
#   '여기 브랜드 서 크림 잘 쓰 있 사 보 어요',
#   '남자 친구 선물 사 괜찮 같 어요',
#   '기획 할인 세트 만 원 초반 대 잘 사 습니다',
#   '달 사용 피부 진정 효과 있 붉 기 개선 같 어요',
#   '남자 친구 트러블 심하 사 주 꾸준히 바르 대요',
#   '크림 진정 도움 되 같 토너 좁쌀 여드름 나 ᆷ',
#   '라운드 랩 기획 나오 제품 사용 중 확실히 사용 전 보 피부 트러블 줄어들 토너 피붓결 정리 진정 크림 바르 보습 크림 올리 주 피부 윤기 나 어요',
#   '남동생 사 주 잘 바르 다니 ᆷ 로션 너무 묽 크림 사 었었 얘 크림 묽 듯 남성 은가',
#   '세트 매우 저렴하 가격 구하 아주 만족 ᆸ니다',
#   '현재 자극 진정 잘 쓰이 있 습니다',
#   '저 잘 맞 화장품 찾 같 어요',
#   '세트 사 잘 쓰 있 습니다',
#   '군인 저 피부 맞 화장품 찾 같 계속 꾸준히 쓰 같 어요',
#   '진짜 베이직 제형 사용 감 이벤트 저렴하 구매 수 있 어요',
#   '남자 친구 사용 어요',
#   '남자 제품 보 잘 쓰 같 네요',
#   '관하 살림 좋아하 바로 사 기대 이상 너무 네요',
#   '만족 ᆸ니다',
#   '증정 품 세안제 사 용감 정말 어요',
#   '평소 저 라운드 랩 제품 아주 남자 친구 이번 피부 관리 바꾸 거든요',
#   '남자 친구 붉 기 싹 진정 피부 아주 어요',
#   '너무 기대 많이 었었 보 ᆸ니다',
#   '요즘 날씨 잘 쓰 있 습니다',
#   '자극 없 보습 잘 되 보습 감 크림 하나 찾 습니다',
#   '저 형 흡수 잘 되 진정 효과 잘 보 있 어요',
#   '발림 크림 택하 잘 네요',
#   '너무 잘 쓰 습니다',
#   '이벤트 때 구매 저렴하 사 어요',
#   '오래 쓰 화장품 버리 관하 살 형 사 보 박 만족 쓰 있 어요',
#   '남자 친구 관 살림 추천 구매 잘 쓰 있 습니다',
#   '이벤트 꽤 할인 가격 구매 습니다',
#   '저 지성 보 가지 장점 더욱 맘 들 습니다',
#   '토너 흡수력 가장 크 장점 같 어요',
#   '순하 자극 없 여드름 박멸 그날 열심히 바르 어요',
#   '평소 저 복합 계절 바뀌 시기 트러블 잘 올라오 편 소나무 진정 토너 크림 사용 후 빠르 진정 어요',
#   '의외로 토너 진정 잘 되 어요',
#   '근데 진정 잘 되 괜찮 같 어요',
#   '올리브 영 쿠폰 가격 가성비 잘 살 같 네요',
#   '산뜻 속 보습 잘 주 어요',
#   '엄청 피부 예민 편 진정 아주 너무 만족 ᆸ니다',
#   '잘 쓰 습니다',
#   '꾸준히 쓰 보 알',
#   '관 시 유튜브 보 할인 행사 미치 냉큼 구매',
#   '기존 자작나무 쓰 있 소나무 너무 기대 네요',
#   '평소 라운드 랩 제품 잘 사용 있 가격 너무 착하 나오 라운드 랩 이벤트 최고 ᆸ니다',
#   '원래 자작나무 라인 잘 쓰 있 라운드 랩 신상 바로 구매 습니다',
#   '덕분 정말 저렴하 구매 크림 생각 피부 흡수 잘 되 네요',
#   '잘 쓰 습니다',
#   '사실 오프라인 포맨 줄 확인 안 사 불구 잘 맞 같 어요',
#   '트러블 진정 효과 기대 ᆸ니다',
#   '처음 잘 모르 사용 가 ᆷ 이 있 문제 되 없 어요',
#   '토너 로션 제품 사 그거 비하 수분 부족 지성 쓰 딱 적당 같 흔적 개선 효과 별로 없 진정 효과 매우 효과 듯 ᆷ',
#   '소나무 씨 카 라인 잘 쓰 동생 사 주 구매 ᆷ 아직 안 쓰 보 잘 모르 음',
#   '아직 트러블 여드름 잘 나 않 네요',
#   '촉촉하 유분 않 잘 사용 있 습니다',
#   '시키 진정 토너 크림 세트 완전히 잘 쓰 있 습니다',
#   '할인 또 또 살 같 어요',
#   '그러 중 관리 살 자 유튜브 채널 통하 저 피부 유형 타입 관리 방법 제품 등 알 되 지속 사용 보 저 잘 맞 만족 사용 있 습니다',
#   '감사 ᆸ니다',
#   '토너 크림 둘 다 순하 피부 잘 맞 너무 어요',
#   '관하 살림 영상 보 해당 제품 사용 최근 날씨 따뜻 정말 잘 쓰 있 어요',
#   '진정 습도 정말 잘 유지 같 어요',
#   '관리 살 님 유튜브 영상 알 되 이번 처음 소나무 토너 크림 구매 보 민감 저 피부 다행히 잘 맞 네요',
#   '예전 로션 아무거 바르 때 화농 여드름 많이 나 피부 건조 다행히 소나무 토너 크림 잘 맞 다행 에요',
#   '저 피부 발림 자극 크 없이 유분 조절 잘 되 네요',
#   '진정 위주 나오 피부 자극 없 너무 잘 쓰 있 습니다',
#   '관하 살림 영상 보 구매 피부 엄청나 잘 스며들 찌 득 없 같 어요',
#   '피부 관리 도움 많이 되 습니다',
#   '피부 관리 도움 많이 되 습니다',
#   '토너 크림 함께 사용 진정 럼 사용 피부 진정 효과 탁월 습니다',
#   '너무 잘 쓰 있 습니다',
#   '관 시 정원 시장 열 주 시 저렴하 가격 잘 사 습니다',
#   '시키 성분 피부 재생 성분 들 있 자극 없 화장품 되게 만족 네요',
#   '성분 많이 있 꾸준히 잘 쓰 보 ᆯ게요',
#   '가격 감사 ᆸ니다',
#   '여자 친구 추천 사용 되 습니다',
#   '잘 쓰 ᆯ게요',
#   '사용 얼마 안 되 산뜻 발리 피부 진정 도움 되 같 어요',
#   '아직 사용 전 너무 기대 어요',
#   '이벤트 이번 감사 드리 ᆸ니다',
#   '남자 친구 기념일 사 주 기존 라저 인원 제품 말 ᆸ니다',
#   '요즘 남자 관리 시기 남자 친구 선물 어요',
#   '기존 제품 보습 감 덜 토너 로션 세트 토너 크림 세트 구매 시 건성 분 잘 사용 시 수 있 같 습니다',
#   '달 동안 쓰 보 결과 피부 확실히 촉촉하 편안 로션 크림 둘 다 똑같이 같 피부 맛있 느끼 수 있 다 우마',
#   '크림 맛집',
#   '잘 쓰 습니다',
#   '이벤트 홀 때 저렴 잘 사 습니다',
#   '크림 뭐 바르 오후 되 개기름 폭발 친구 바르 나 뒤 유수 조화 이루어지 같 습니다',
#   '가격 너무 품질 최고 예요',
#   '상당히 저 피부 잘 맞 어요',
#   '예민 피부 저 너무 잘 맞 만족 쓰 있 어요',
#   '피부 보호 주 느낌 할인 타이밍 너무 완벽 구매 ᆸ니다',
#   '많 유튜버 소개 번 쓰 보 싶 딱 세일 구매 잘 이용 있 어요',
#   '유튜브 보 남자 전용 처음 사 보 기대 되 네요',
#   '잘 쓰 습니다',
#   '수요 너무 많 오랫동안 기다리 만큼 가치 있 생각 ᆸ니다',
#   '피부 답답 않 여름 잘 사용 같 습니다',
#   '감사 ᆸ니다',
#   '소나무 앰풀 크림 잘 쓰 어',
#   '기대 구매 습니다',
#   '피부 유형 잘 맞 무난하 누구 사용 같 습니다',
#   '시키 성분 잘 맞 계속 사용 있 어요',
#   '저 여드름 피부 예민하 너무 잘 맞 진정 효과 탁월하 ᆸ니다',
#   '이번 행사 싸 잘 사 어요',
#   '또 할인 주 세요',
#   '잘 쓰 있 습니다',
#   '평소 라운드 랩 제품 애용 할인 때 사 놓 네요',
#   '쓰 라운드 랩 최고',
#   '토너 보습 있 사계절 다 잘 사용 같 어요',
#   '지성 수 부지 분 겨울 제외 다 잘 쓰 같 어요',
#   '자 전 제품 바르 자 향 강하 않 보습 감 풍부 너무 만족 있 어요',
#   '관 화살 봄 여름 가을 추천 시 라운드 랩 자작나무 라인 잘 쓰 있 사 습니다',
#   '수분 너무 촉촉하 에누리 판매 기간 때 저렴하 사 너무 만족 ᆸ니다',
#   '촉촉하 흡수 잘 되 너무 네요',
#   '끈적거리 없 최고',
#   '진정 필수 아이템 모이 있 피부 진정 필요 때 매우 잘 사용 있 어요',
#   '유튜브 보 할인 사 어요',
#   '잘 쓰 있 어요',
#   '이벤트 가격 아주 양 많 토너 산뜻 어요',
#   '민감 피부 저 진정 토너 및 크림 더 잘 맞 같 네요',
#   '이벤트 전 가격 세트 구매 더 어요',
#   '제품 너무 쫀쫀 보습 잘 되 같 너무 잘 쓰 있 어요',
#   '감사히 잘 쓰 ᆯ게요',
#   '잘 쓰 있 습니다',
#   '월 일 남자 친구 쓰 보 후기 남기 어요',
#   '수염 부분 트러블 자주 나누 편 좀 진정 가라앉히 순하 같 어 너무 잘 쓰 있 어요',
#   'wow 감사 ᆸ니다',
#   '흡수 빨리 되 산뜻 의미 의미 알 같 느낌 피부 트러블 잘 안 나 ᆷ',
#   '피부 잘 진정 저 피부 유형 너무 찰떡 네요',
#   '제품 이벤트 주 시 감사 ᆸ니다',
#   '이벤트 가격 싸 습니다',
#   '우선 토너 원하 느낌 크림 또한 끈적이 줄 알 지금 계절 딱 맞 사용 수 있 촉촉하 번들거리 않 아주 만족 습니다',
#   '붉 기 잡히 전반 만족 ᆸ니다',
#   '여드름 발생 원인 중 모공 막 성분 없 더 믿음 가 같 어요',
#   '크림 세트 스킨 로션 세트 개 모두 구매 사용 감 산뜻 지성 여드름 남편 얼굴 매우 잘 맞 보 어요',
#   '유튜브 이벤트 첨 쓰 보 너무 네요',
#   '굿 관하 실 최고',
#   '피부 예민 지금 며칠 쓰 보 피부 민간 없이 잘 맞 같 어요',
#   '이벤트 덕분 토너 로션 크림 저렴하 가격 구매 수 있 습니다',
#   '남자 친구 선물 구입 습니다',
#   '소나무 마스크 팩 세럼 굉장히 잘 쓰 기억 있 포맨 라인 괜찮 같 구매 습니다',
#   '이번 이벤트 세트 구매 어요',
#   '이번 자작나무 소나무 라인 정말 잘 나오 정착 고민 ᆸ니다',
#   '스킨 보습 감 수분 부족 지성 피부 저 너무 잘 맞 보습 크림 진짜 잘 맞 어요',
#   '보습 감 빵빵 진정 능력 말 안 되 ᆸ니다',
#   '자작나무 시리즈 잘 쓰 라운드 랩 사 습니다',
#   '빠르 배송 감사 ᆸ니다',
#   '아직 사용 전 저 피부 도움 되 네요',
#   '이벤트 감사 ᆸ니다',
#   '진정 잘 되 흡수 잘 되 네요',
#   '같 상표 제품 쓰 너무 만족 번 더 구매 습니다',
#   '자작나무 시리즈 사용 다 떨어지 때 소나무 시리즈 할인 때 사용 보 구매 습니다',
#   '날씨 점점 풀리 흡수 잘 제품 필요 딱 알맞 같 어요',
#   '마침 기본 피부 관리 제품 필요 할인 쿠폰 적용 저렴하 아이템 획득 어요',
#   '사용 보 저 잘 맞 제품 재 구매 려고요',
#   '중복 남자 친구 자작나무 소나무 더 산뜻 요거 픽 어요',
#   '하나 없 면도 후 진정 정말 잘 되 붉 기 올라오 없 습니다',
#   '감사 ᆸ니다',
#   '진짜 자주 사용 제품 관 시 형 이벤트 가져오 시 아주 기쁘 구매 습니다',
#   '이번 이벤트 구매 어요',
#   '독도 제품 잘 사용 었었 제품 무난하 사용 습니다',
#   '잘 사용 습니다',
#   '여드름 피부 듯 기대 중 ᆸ니다',
#   '저 만족 ᆸ니다',
#   '잘 사용 습니다',
#   '봄 여름 무리 없이 사용 수 있 같 용량 크 충분히 쓰 구매 되 같 습니다',
#   '로션 크림 모두 테스트 보 둘 다 끈적이 없 흡수력 너무 만족 네요',
#   '여드름 피부 보 진정 팀 찾 있 유튜브 관리 살 님 영상 보고 전 소나무 씨 보디 미스트 잘 사용 바로 구매 현재 사용 중 ᆸ니다',
#   '전반 무난하 진정 잘 되 피부 트러블 조금 들어가 눈 보이 만족 잘 사용 중 ᆸ니다',
#   '잘 쓰 습니다',
#   '스킨 크림 모두 번들거리 않 피부 잘 흡수 유수 균형 확실히 우수 ᆸ니다',
#   '토너 너무 촉촉하 흡수 잘 되 습니다',
#   '살 관 시 평소 잘 보 있 바로 지르 습니다',
#   '계절 맞 상품 싸 구매 주 시 감사 ᆸ니다',
#   '확실히 자작나무 라인 진정 잘 되 같 어요',
#   '앞 꾸준히 이용 잘 습니다',
#   '발림 사용 만족 습니다',
#   '가격 잘 구매 기분 습니다 가성비 정말 어요',
#   '유튜버 보 사 매우 만족 제품 ᆸ니다',
#   '올해 열심히 관리 보',
#   '피부 진정 잘 되 붉 기 옅 같 어요',
#   '너무 않 피부 흡수 너무 잘 되 어요',
#   '작년 여름 진정 필요 느끼 이번 여름 이거 바르 피부 잘 진정 바라 ᆸ니다',
#   '관하 실 최고',
#   '운 시장 참여 되 로션 크림 제품 전부 이용 보 수 있 겨울 크림 제품 사용 로션 여름 이용 예정 ᆸ니다',
#   '둘 다 너무 만족 제품 겨울 크림 제품 저 더 맞 듯 싶 습니다',
#   '저 구독 신뢰 보 관 시 채널 이벤트 바로 구입 습니다',
#   '예전 종종 사용 제품 할인 때 구매 두 배 네요',
#   '잘 쓰 ᆯ게요',
#   '요즘 쓰 건조 않 진정 잘 되 ᆸ니다',
#   '건조 요즘 수분 보충 잘 되 진정 효과 미치 습니다',
#   '유튜버보고 추천 구매 순 잘 맞 같 습니다',
#   '피부 잘 맞 같 선택 생각 어요',
#   '구매 며칠 쓰 보 진정 잘 흡수 어요',
#   '촉촉하 흡수 잘 되 어요',
#   '아직 쌀쌀하 피부 건조 당분간 보습 잘 되 크림 세트 쓰 여름 오 로션 세트 쓰 어요',
#   '감사 ᆸ니다',
#   '잘 쓰 습니다',
#   '상품 증정 품 잘 습니다',
#   '기존 기초 제품 다 쓰 잘 쓰 습니다',
#   '남자 친구 선물 구매 어요',
#   '평소 건조 예민 피부 건조 잘 주 예민 없이 진정 잘 되 ᆸ니다',
#   '크림 쪽 처음 쓰 보 데 잘 쓰 습니다',
#   '자작나무 라인 뚜껑 잘 쓰 있 어요',
#   '제품 세트 사용 때 진정 효과 잘 느끼 너무 습니다',
#   '가격 구성 품 만들 주 시 감사 ᆸ니다',
#   '잔여 가 없이 잘 스며들 사용 감 만족 어요',
#   '이벤트 싸 잘 사 너무 순하 어요',
#   '보습 최고 ᆸ니다',
#   '여자 라운드 랩 포맨 라인 잘 맞 소나무 진정 바로 구매 습니다',
#   '진정 잘 되 어요',
#   '촉촉 쫙쫙 운동 쓰 집 쓰 라운드 랩 맛집 ᆸ니다',
#   '크림 토너 로션 비슷하 마찬가지 재형 조금 물건 편 굉장히 잘 발리 흡수 잘 되 편 ᆸ니다',
#   '세일 때 저렴 잘 사 습니다',
#   '보습 순하 사계절 내내 잘 사용 수 있 같 어요',
#   '토너 크림 모두 정말 만족 습니다',
#   '토너 생각 쫀쫀하니 흡수 잘 되 어요',
#   '쓰 제품 항상 잘 쓰 있 어요',
#   '감사 ᆸ니다',
#   '가지 스킨 로션 쓰 보 여기 최고 같 습니다',
#   '라운드 랩 상품 사용 보 저렴하 가격 구매 추후 사용 기대 있 어요',
#   '저 복합 피부 저 피부 잘 맞 네요',
#   '구매 잘 같 습니다',
#   '원래 라운드 랩 포 시리즈 잘 이용 있 저 유튜버 공동 참여 시 같이 출시 시 개량 판 생각 구매 습니다',
#   '건성 피부 크림 더 잘 맞 느낌 로션 물론 건조 시 분 크림 더 잘 맞 같 어요',
#   '이번 여름 라운드 랩 함께 보내 같 어요',
#   '가격 사 수 있 행복 ᆸ니다',
#   '이번 이벤트 저렴하 구매 저 피부 정말 예민하 라운드 랩 구매 습니다',
#   '좀 더 쓰 보 알 잘 맞 이거 정착 ᆸ니다',
#   '잘 발리 흡수 잘 되 무엇 피부 눈 잘 보이 네요',
#   '향기 잘 흡수 네요',
#   '진정 효과 기대 보 ᆸ니다',
#   '발림 촉촉 진정 효과 있 꾸준히 쓰 보 다시 리뷰 적 보 습니다',
#   '크림 아직 좀 날 쓰 보 사용 안 보 로션 사용 보 결과 크림 충분히 같 습니다',
#   '기획전 저렴하 잘 사 습니다',
#   '라운드 랩 자작나무 라인 잘 쓰 기억 있 한번 구매 보 지성 피부 산뜻 습니다',
#   '아주 이번 제품 만족 어요',
#   '무 향 이거 토너 쓰 그냥 기분 좀 크림 보습 있 빨리 흡수 느낌 저 잘 맞 어요',
#   '미백 잘 모르 진정 효과 확실히 있 같 어요',
#   '예전 자작나무 라인 자주 사용 유튜버 관 시 추천 사 진정 잘 되 산뜻 다가오 봄 여름 잘 쓰 같 어요',
#   '코너 흡수 잘 되 ᆸ니다',
#   '발림 너무 저 피부 잘 맞 같 어요',
#   '운동 전후 편하 쓰 습니다 가성비 잘 쓰 ᆯ게요',
#   '쓰 보 끈적이 않 피부 보습 유지 채 흡수 아주 만족 ᆸ니다',
#   '이벤트 저렴하 가격 구매 수 있 기분 네요',
#   '건성 거치 칠하 제품 고민 라운드 랩 처음 구매 너무 저렴하 가성비 잘 사 잘 사용 같 네요',
#   '예전 라운드 랩 듯 할인 날 기다리 기회 저렴하 구매 어요',
#   '잘 쓰 보 ᆯ게요',
#   '관하 살림 영상 보 구매 배송 빠르 너무 만족 습니다',
#   '라운드 랩 평소 독도 라인 잘 쓰 있 소나무 라인 쓰 보 ᆯ게요',
#   '이벤트 참여 네요',
#   '같이 오 정액 정말 만족 ᆸ니다',
#   '라운드 랩 세트 구매 처음 해보 구성 만족 습니다',
#   '토너 진정 잘 되 크림 쫀쫀 너무 잘 쓰 있 어요',
#   '라운드 랩 원래 살 각 재 있 바로 이렇게 할인 들어가 지르 네요',
#   '스킨 로션 제품 함께 구매 지금 같 환절기 or 겨울철 보습 좀 부족 싶 때 사용 좀 더 채우 주 수 있 제품 같 만족 습니다',
#   '이벤트 저렴하 잘 구매 어요',
#   '아직 사용 전 워낙 유명 제품 기대 ᆸ니다',
#   '시장 때 구매 잘 네요',
#   '원래 라운드 랩 자작나무 라인 잘 이용 었었',
#   '또 요즘 잘 나가 성분 보 더 기대 ᆸ니다',
#   '진정 잘 되 느낌 ᆸ니다',
#   '크림 진정 효과 있 피부 잘 흡수 어요',
#   '제품 사용 이후 피부 상태 개선 건강 느낌 수 있 정말 만족 어요',
#   '여름 잘 사용 같 어요',
#   '아주 만족 습니다',
#   '배송 사용 보 너무 저 피부 잘 맞 만족 사용 ᆸ니다',
#   '정도 쓰 보 만족 잘 쓰 있 습니다',
#   '배송 빠르 가성비 잘 사용 ᆯ게요',
#   '토너 크림 떨어지 가 시기 주문 되 배송 빠르 상품 만족 ᆸ니다',
#   '매번 잘 쓰 라운드 랩 오늘 사 쓰 네요',
#   '잘 쓰 습니다',
#   '가격 시장 주 시 감사 ᆸ니다',
#   '남편 피부 잘 맞 네요',
#   '피부 촉촉 잘 유지 주 어요',
#   '관하 살림 덕분 너무 너무 잘 살 같 기쁘 어요',
#   '리뷰 이벤트 작성 보 ᆸ니다',
#   '친구 선물 주 아주 족 네요',
#   '제품 이벤트 기간 저렴하 가격 구매 습니다',
#   '직접 사용 보 보습 효과 최고 네요',
#   '원래 쓰 잘 쓰 습니다',
#   '기회 저렴하 잘 구매 어요',
#   '수분 라인 쓰 었었 이번 기회 통하 진정 라인 쓰 되 너무 산뜻 진정 잘 되 같 어요',
#   '기존 자작나무 포맨 수분 라인 잘 사용 있 이번 기회 소나무 진정 라인 쓰 보 밤 쓰 라인 더 어요',
#   '효과 기대 꾸준히 잘 바르 보 ᆯ게요',
#   '토너 사용 구매 순하 진정 잘 되 만족 사용 있 습니다',
#   '아직 쓰 보 못 관리 살 정 원님 PICK 너무 같 습니다',
#   '배송 빠르 진정 효과 뛰어나 끈적이',
#   '스킨 로션 만족',
#   '라운드 랩 제품 항상 잘 쓰 있 실제로 피부 소리 정도 너무 효과 어요',
#   '역시 라운드 랩 최고 항상 구매 ᆸ니다',
#   '저렴하 가격 구입 너무 만족 습니다',
#   '남자 필수 같 네요',
#   '확실히 소나무 라인 진정 잘 되 사용 데 어요',
#   '라운드 랩 화장품 할인 크림 구매 구매 잘 네요',
#   '순하 잘 맞 어요',
#   '처음 쓰 보 후기 기대 ᆸ니다',
#   '잘 맞 정착 쓰',
#   '사용 감 산뜻 유분 없 너무 잘 사용 있 습니다',
#   '덜덜덜 만족 ᆸ니다',
#   '여드름 중 차나무 성분 안 맞 시키 잘 맞 사람 강',
#   '싸 잘 사 네요',
#   '확실히 야드 진정 도움 많이 되 ᆸ니다',
#   '피부 자체 좀 지성 피부 묽 로션 필요 재형 물 흡수 잘 되 확실히 피부 자극 덜 ᆸ니다',
#   '감사 ᆸ니다',
#   '잘 바르 산뜻 어요',
#   '라운드 랩 소나무 라인 보디 제품 잘 쓰 있 기대 중 ᆸ니다',
#   '잘 사용 ᆯ게요',
#   '감사 ᆸ니다',
#   '감사 ᆸ니다',
#   '소나무 라인 예전 잘 맞 사용 이번 정원 덕분 할인 가격 구입 되 너무 어요',
#   '완전 혜자 일단 토너 너무 진정 잘 되 함토든 닦토로든 너무 사용 끈적이',
#   '사 듯 흡수 빠르 정 어요',
#   '서 크림 잘 쓰 있 진정 제품 정착 수 있 같 어요',
#   '초보 저 자극 느끼 이제 앞 피부 관리 더 잘 일 남 네요',
#   '제형 기대 되 ᆸ니다',
#   '크림 다 쓰 사 되 너무 만족 잘 쓰 있 습니다',
#   '토너 시원 진정 되 크림 촉촉 잘 발리 네요',
#   '토너 크림 세안제 알차 구성 가격 가성비 싸 잘 생각 들 네요',
#   '제품 쓰 이번 바꾸 되 매우 만족 사용 있 습니다',
#   '피부 진정 많 도움 되 같 네요',
#   '여드름 피부 소나무 화장품 원래 알 있 마침 요즘 피부 뒤집어지 잘 다',
#   '잘 쓰 습니다',
#   '친구 선물 하나 사 너무 잘 맞 같 만족 ᆸ니다',
#   '평소 라운드 랩 선 크림 사용 주로 기대 네요',
#   '생각 피부 잘 맞 기본 스킨 로션 충분하 보이 네요',
#   '워낙 진정 좋아서 같 라인 제품 사 거든요',
#   '요즘 같 환절기 바르 보습 잘 느끼 크림 토너 함께 바르 때 시너지 있 같 습니다',
#   '라운드 랩 소나무 라인 처음 쓰 보 데 만족 앰풀 쓰 보 싶 마음 있 습니다',
#   '확실히 유튜버 추천 믿음 가 사용 보 촉촉하 네요',
#   '이벤트 감사 ᆸ니다',
#   '며칠 쓰 보 저 잘 맞 같 달 이상 쓰 보 다시 오 ᆯ게요',
#   '합리 가격 구매 만족 네요',
#   '제조 연월일 언제 사용 수 있 주 시 감사 드리 습니다',
#   '피부 트러블 쓰 제품 찾 있 잘 쓰 습니다',
#   '감사 ᆸ니다',
#   '번갈 가 잘 사용 습니다',
#   '상품 빠르 배송 감사 ᆸ니다',
#   '잘 쓰 ᆯ게요',
#   '또 이벤트 주',
#   '항상 너무 잘 쓰 제품 이번 또 구매 되 어요',
#   '진정 너무 잘 되사 항상 잘 쓰 있 습니다',
#   '피부 유형 너무 잘 맞 산뜻 어요',
#   '싸 가격 너무 잘 사 만족 ᆸ니다',
#   '겨울철 피부 뒤집어지 잘 맞 네요',
#   '원래 라운드 랩 제품 좋아하 잘 사용 있 유튜브 관리 살 자 보 가격 제품 잘 구매 습니다',
#   '어떻게 알 되 사용 있 이번 프로모션 주 시 감사 어요',
#   '일단 산뜻 사용 감 저 만족 시키 크림 생각 저녁 바르 습니다',
#   '빠르 잘 습니다',
#   '진정 잘 되 같 어요',
#   '적당 가격 처음 쓰 제품 잘 사용 습니다',
#   '마침 월 영세 일 때 산 토너 크림 다 떨어지 가 정말 저렴 잘 살 같 습니다',
#   '평소 만족 잘 쓰 제품 할인 ᆫ다',
#   '소나무 앰풀 잘 쓰 있 토너 크림 이번 기회 사용 ᆸ니다',
#   '크림 아직 겨울 여운 있 함께 구매 어요',
#   '잘 선택 사진 등록 안 되 어요',
#   '혜자 구성 감사 ᆸ니다',
#   '잘 쓰 ᆯ게요',
#   '할인 구매 생각 배송 빠르 정말 습니다',
#   '예전 라운드 랩 제품 잘 사용 가격 바로 구매 습니다',
#   '잘 쓰 습니다',
#   '이쪽 라인 제품 저 잘 맞 같 더라구요',
#   '사용 보 촉촉하 과하 번들거리 않 피부 잘 스며들 느낌 들 사용 감 네요',
#   '유튜브 관리 살 구독 이벤트 바로 구입 어요',
#   '이번 관 시 유튜브 이벤트 구매 되 정말 같 습니다',
#   '할인 치킨 마리 가격 나오 너무 습니다',
#   '라운드 랩 사랑 ᆸ니다',
#   '토너 크림 진정 도움 되 바라 잘 쓰 ᆯ게요',
#   '다가오 봄 대비 마련 진정 팀 피부 잘 맞 어요',
#   '가격 잘 구매 습니다',
#   '대 복합 남자 알칼리 세안제 잘 맞 어요',
#   '너무 만족 네요',
#   '피부 딱 맞 보습 진정 잘 되 뭐 쓰 고민 분 이거 입문 보 세요',
#   '남 장사 맞 크크크 가격 만족도 효과 끈적이 없 촉촉 찾 있 진짜 너무 잘 찾아오 생각 들 제품 ᆸ니다',
#   '피부 예민 제품 만들 주 시 감사 ᆸ니다',
#   '아침 자 전 번 사용 데 너무 편안 기분',
#   '그런데 관 살 임 엄청나 할인 들 오 시 구매 시 습니다',
#   '우리 알 갓 더 랩 그대로 정말 잘 맞 습니다',
#   '할인 많이 해주 사용',
#   '토너 누구 잘 맞 같 크림 촉촉 진정 잘 되 만족 ᆸ니다',
#   '자작나무 쓰 이벤트 구매 봄 여름 쓰 어요',
#   '아직 사용 안 보 로션 세트 쓰 보 크림 세트 효과 무조건 같 기대 ᆸ니다',
#   '사랑 ᆸ니다',
#   '토너 남 크림 남 미루 미루 화장품 다 떨어지 가 때 피부 또 뭐 쓰 고민 찰나 이렇게 또 저 필요 ᆷ 화장품 뭐 성분 필요 알 시 이벤트 주 시 너무 너무 감사 ᆸ니다',
#   '잘 쓰 습니다',
#   '벌써 또 세일 기대 ᆸ니다',
#   '유튜버 관하 살림 이벤트 구매 어요',
#   '진짜 사 마음먹 정말 쓰 순하 잘 발리 습니다',
#   '소나무 너무 잘 쓰 있 습니다',
#   '저 피부 너무 잘 맞 같 습니다',
#   '토너 향 거의 없 약하 너무 크림 아주 잘 발리 ᆸ니다',
#   '둘 다 만족 ᆸ니다',
#   '관 시 형 덕분 또 아이템 잘 챙기 가 ᆸ니다',
#   '산뜻 발리 흡수 잘 바르 너무 같 어요',
#   '배송 빠르 안전 포장 오 여드름 피부 어요',
#   '슬슬 풀리 날씨 쓰 토너 및 크림 아주 만족 ᆸ니다',
#   '관하 실 최고',
#   '봄철 진정 효과 기대 사 어요',
#   '잘 사용 습니다',
#   '원래 앰프 쓰 있 알 있 그냥 최고 중 최고 최고 ᆷ',
#   '여드름 피부 잘 맞 습니다',
#   '배송 빨리 오 싸 가격 잘 구매 습니다',
#   '너무 기대 어요',
#   '감사히 잘 사용 습니다',
#   '평소 저 피부 붉 여드름 뾰루지 많이 생기 진정 제품 찾 있 우연히 컬래버 제품 합리 가격 출시 되 제품 라운드 랩 크림 말 벌써 진정 잘 사용 습니다',
#   '감사 어요',
#   '잘 쓰 보 습니다',
#   '예전 사용 싶 유튜버 보 타이밍 저렴 구매 잘 어요',
#   '크림 보습 감 만족 습니다',
#   '감사 ᆸ니다',
#   '항상 사용 라운드 랩 제품 싸 할인 중 구매 어요',
#   '이번 관하 살림 시장 싸 구매 토너 크림 모두 사용 너무 만족 앞 재 구매 같 습니다',
#   '마침 쓰 제품 다 떨어지 가 구매 관하 살림 이벤트 주 시 구매 되 어요',
#   '이번 봄 여름 쓰 화장품 필요 마침 세일 너무 싸 잘 살 같 어요',
#   '관하 살림 유튜브 보 너무 가격 구매 되 잘 쓰 습니다',
#   '어요 가성비 잘 싸 네요',
#   '로션 같이 주문 로션 크림 저 더 잘 맞 같 어요',
#   '쓰 소나무 라인 저 집 소나무 팩 스킨 패드 세럼 크림 너무 잘 쓰 남자 친구 구매 완료 가격 너무 끈적이 않 남자 친구 좋아하 어요',
#   '남자 사용 흡수 잘 되 보습 감 네요',
#   '꾸준히 잘 사용 보 습니다',
#   '소나무 라인 좋아하 이번 기회 있 사 만족 ᆸ니다',
#   '할인 때 구매 습니다',
#   '상품 배송 사용 보 토너 너무 시 듯 촉촉 마음 들 어요 가성비 최고 상품 같 습니다',
#   '관하 실 채널 역대 급 이벤트 바로 달려가 구매 습니다',
#   '마침 화장품 거의 떨어지 있 구성 잘 살 같 어요',
#   '요즘 피부 뒤집어지 뭐 사 고민 마침 이벤트 사 습니다',
#   '잘 쓰 습니다',
#   '진정 효과 기대 ᆸ니다',
#   '처음 쓰 보 기대 이상 ᆸ니다',
#   '배송 엄청 빠르 봄 맞 스킨 로션 필요 잘 사용 보 습니다',
#   '오 바르 보 너무 흡수 잘 되 네요',
#   '라운드 랩 자작나무 수분 라인 잘 쓰 있 저렴하 가격 토너 크림 세안제 살 수 있 미리 쟁이 두 ᆸ니다',
#   '진정 라인 기대 되 ᆸ니다',
#   '제품 잘 습니다',
#   '제품 잘 사용 습니다',
#   '감사 ᆸ니다',
#   '진정 크림 필요 피부 잘 맞 너무 습니다',
#   '감사 ᆸ니다',
#   '마침 크림 다 쓰 가 이벤트 주 시 다니',
#   '감사 뿐 ᆸ니다',
#   '잘 사용 보 습니다',
#   '감사 ᆸ니다',
#   '토너 잘 발리 끈적이 하나 없 너무 습니다',
#   '자작나무 라인 만족 사용 소나무 세트 구매 확실히 산뜻 보습 있 점 그대로 네요',
#   '패키지 너무 이쁘 싸 가격 잘 구매 같 어요',
#   '기대 ᆸ니다',
#   '관하 살림 시장 합리 가격 제품 잘 구매 습니다',
#   '배송 빠르 포장 잘 되 오 어요 잘 사용 습니다',
#   '쟁이 이득',
#   '이번 이벤트 통하 가격 구매 습니다',
#   '사용 감 꾸준히 사용 계획 ᆸ니다',
#   '이벤트 가격 구매 습니다',
#   '너무 산뜻 겨울철 쓰 크림 잘 구매 같 어요',
#   '너무 만족 중',
#   '갑자기 피부 때문 고민 많 관 시 형 이벤트 기회 구매 습니다',
#   '감사 ᆸ니다',
#   '관하 살림 컬래버 아주 정액 토너 가격 가지 가 ᆸ니다 가성비 잘 어요',
#   '겨울 사용 보습 너무 잘 되 습니다',
#   '구매 잘 네요',
#   '아주 가격 잘 사 어요',
#   '평상시 라운드 랩 토너 쓰 있 너무 만족 습니다',
#   '감사 ᆸ니다',
#   '평소 여드름 많이 나 피부 경우 많 잘 진정 같 습니다',
#   '크림 생각 않 건성 분 잘 쓰 시 같 습니다',
#   '진정 토너 함께 지금 같 날씨 쓰 크림 세안제 함께 구성 있 네요',
#   '무엇 너무 쓰 보 싶 제품 만족 ᆸ니다',
#   '아직 로션 크림 계절 잘 맞 같 쓰 편하 진정 느낌 습니다',
#   '상품 배송 상태 아주 잘 습니다',
#   '피부 트러블 진정 듯 기대 있 습니다',
#   '잘 쓰 습니다',
#   '감사 ᆸ니다',
#   '올 여름 잘 사용 되 같 어요',
#   '사용 후기 열심히 사용 주변 후기 남기 ᆯ게요',
#   '진정 잘 되 정도 수분 있',
#   '잘 사용 보 ᆯ게요',
#   '유튜버 관하 살림 통하 할인 기간 알 되 제품 가격 영입 습니다',
#   '워낙 평 라운드 랩 제품 기대 사용 보',
#   '이벤트 싸 사 수 있 더욱 더 습니다',
#   '여름 제외 제품 잘 안 바르 되 더라고',
#   '이번 소나무 포맨 라인 출시 때 고민 고민 건성 정원 현재 잘 쓰 시 시 구매 보 습니다',
#   '라인 나오 기대 이번 봄동 안 잘 사용 보 습니다',
#   '토너 다 떨어지 할인 겸 구매 지성 피부 쓰 적합 같 어요',
#   '산뜻 봄 여름 잘 쓰 같 습니다',
#   '스킨 흡수 빠르 수분 충전 잘 주 크림 진정 도움 되 ᆸ니다',
#   '상품 잘 습니다',
#   '감사 ᆸ니다',
#   '자작나무 시리즈 너무 만족 사용 기억 있 요번 관 시 이벤트 보 바로 사 습니다',
#   '너무 만족 어요',
#   '유튜버 관 시 형 라운드 랩 피땀 노력 담기 소나무 라인 혜택 너무 바로 구매 습니다',
#   '세안제 주 시 호텔 패키지 안 오 뒤 오 수 있 기대 기다리 보 ᆯ게요',
#   '감사 ᆸ니다',
#   '양도 얼굴 반경 넓 저 아주 많 보습 촉촉 너무 잘 유지 습니다',
#   '유튜브 할인 덕분 잘 사 습니다',
#   '세안제 크림 다그 봄 적당 제형 잘 바르 어요',
#   '잘 쓰 ᆯ게요',
#   '조건 감사 ᆸ니다',
#   '싸 잘 구입',
#   '달 간 잘 쓰 ᆯ게요',
#   '제품 만들 주 시 감사 어요',
#   '제품 감사 ᆸ니다',
#   '진정 같 기대 네요',
#   '빠르 잘 습니다',
#   '화장품 뭐 사 고민 구성 잘 쓰 보 ᆯ게요',
#   '성분 너무 보이 기대 네요',
#   '너무 유분 느낌 들 이 흡수 잘 되 네요',
#   '진짜 저 찾 크림 중 최고 같 어요',
#   '겨울 끝나 가 크림 필요 마침 이벤트 네요',
#   '잘 쓰 ᆯ게요',
#   '확실히 그냥 토너 크림 쓰 확실히 피부 진정 도움 되 ᆸ니다',
#   '잘 쓰 습니다',
#   '감사 ᆸ니다',
#   '적당 가격 성분 전문인 라운드 랩 믿음 가 ᆸ니다',
#   '포맨 라인 잘 쓰 이것 산뜻 피부 잘 맞 어요',
#   '잘 쓰 ᆯ게요',
#   '관하 살리 보 기회 궁금 제품 쓰 수 있 되 너무 감사 어요',
#   '배송 도착 전 올리브 영 가 바르 보 제형 보 산뜻 지성 피부 너무 만족 어요',
#   '감사 ᆸ니다',
#   '라운드 랩 클렌징 잘 쓰 있 이번 피부 관리 촉촉하 어요',
#   '평소 사용 싶 제품 관 살림 유튜브 통하 저렴 구입 어요 복합 너무 촉촉하 금방 흡수 너무 잘 맞 같 어요',
#   '라운드 랩 잘 쓰 이번 할인 저렴하 잘 사 어요',
#   '건성 번 열심히 쓰 보 ᆯ게요',
#   '기대 되 네요',
#   '단지 광고 절대 사용 매우 만족 ᆸ니다',
#   '엄청 촉촉하 가격 저렴하 잘 구매 같 습니다',
#   '배송 빠르 물건 잘 습니다',
#   '향 일단 너무 만족 끈적이 안 적당히 발림 있 요즘 건조 데 오래 지속 만족 ᆸ니다',
#   '정액 만족 사용 어요',
#   '가지 점 있 포장 과정 검수 잘 안 되 박스 살짝 찢어지 오 습니다',
#   '역시 피부 진정 라운드 랩 최고 같 어요',
#   '좀 더 따뜻 잘 쓰 ᆯ게요',
#   '라운드 랩 소나무 라인 남성 위하 제품 나오 민감 피부 가지 친구 선물 구매 어요',
#   '선물 친구 클렌징 폼 사용 때 순하 촉촉 만족 네요',
#   '잘 쓰 ᆯ게요',
#   '한번 잘 싸 보 ᆯ게요',
#   '토너 반 안 남 앰풀 다 쓰 마침 이벤트 뽕 잘 가 ᆸ니다',
#   '아직 사용 안 이전 제품 만족 사용 기대 ᆸ니다',
#   '관하 살림 덕분 제품 사용 수 있 정말 감사 ᆸ니다',
#   '잘 사용 보 ᆯ게요',
#   '잘 사용 습니다',
#   '진정 도움 많이 되 같 어요',
#   '순하 흡수 잘 되 습니다',
#   '아주 잘 쓰 습니다',
#   '효과 기대 보 ᆸ니다',
#   '덕분 싸 잘 구매 습니다',
#   '저녁 기대 되 네요',
#   '오 사용 촉촉하 발림 성 굿 굿 통 기구 때문 구매 앞 잘 이용 같 어요',
#   '항상 잘 쓰 있 제품 ᆸ니다',
#   '꾸준히 사용 예정',
#   '가격 정말 말 안 되 수준 보습 발림 모두 최고 ᆸ니다',
#   '잘 습니다',
#   '크림 끈적 않 흡수 잘 되 다시 구매 싶 네요',
#   '구성 합리 가격 잘 구매 습니다',
#   '여드름 지성 복합 성 고민 분 다 보 시 시키 성분 듬뿍 들 있 잘 쓰 피부 관리 보 습니다',
#   '가격 정말 저렴하 잘 구매 다음 가격 구매 수 있 네요',
#   '오늘 처음 쓰 보 매우 만족',
#   '소나무 진정 마스크 팩 쓰 잘 맞 생각 었었 마침 크림 다 떨어지 관하 살림 이벤트 바로 구매 되 습니다',
#   '겨울 찬바람 많이 맞 여드름 약 먹 있 진정 딱 필요 타이밍 쓰 보 아직 많이 쓰 보 않 확실히 진정 라인 부 듯 피부 도움 되 같 습니다',
#   '앞 꾸준히 쓰 다시 후기 남기 습니다',
#   '저렴하 잘 구매 어요',
#   '기존 쓰 있 구매 예정 잘 쓰 ᆯ게요',
#   '라운드 랩 제품 유명 알 있 이번 관 시 형 덕 싸 사 수 있 되 너무 기쁘 ᆸ니다',
#   '만족 이벤트 진행 주 시 감사 ᆸ니다',
#   '건성 약간 민감 같 잘 맞 어요',
#   '수분 라인 쓰 오 역시 사용 감 너무 조금 괜찮 만족 ᆸ니다',
#   '라운드 랩 제품 원래 잘 쓰 오늘 운동 오 바르 보 진정 잘 되 같 어요',
#   '너무 가격 잘 살 같 습니다',
#   '소나무 팩 번 쓰 보 괜찮 이번 세일 김 싸 잘 사 어요',
#   '다섯 팩 재고 없 못 오늘 드림 되 못 모르 재고 없 표시 없 호텔 패키지 원하 사람 그저 운 맡기 오늘 드림 변경 확인 통하 다시 보내 주 시 ᆸ니다',
#   '잘 쓰 습니다',
#   '라운드 랩 기존 잘 쓰 이번 제품 역시 촉촉하 습니다',
#   '유분 싫 남자 친구 로션 사 주 습니다',
#   '발렌타인 기념 남자 친구 선물 구매 구성 어요',
#   '남자 친구 선물 구매 습니다',
#   '모공 쫀쫀 지성 피부 도움 되 같 습니다',
#   '자작나무 수분 라인 잘 쓰 시키 보 너무 기대 네요'],
#  '부정': ['부담 없이 바르 어요',
#   '여드름 걱정 끝 너무 산뜻 습니다',
#   '예민 피부 걱정 괜찮 어요',
#   '쯧쯧쯧 재앙',
#   '여드름 스트레스 동생 이것 제일 같 사 어요',
#   '토너 진짜 산뜻 지성 수분 부족 지성 둘 다 쓰 같 어요',
#   '크림 촉촉하 발리 산뜻 마무리 부담 없이 쓰 어요',
#   '순하 민감 사람 걱정 없이 사용 수 있 제품 같 어요',
#   '달 사용 사용 전 비교 때 여드름 흉터 여드름 나 많이 사라지 어요',
#   '토너 확실히 수분 부족 지성 지성 분 쓰 어요',
#   '토너 바르 때 주르르 물 재질 바르 죄게끔 힘들 ᆸ니다',
#   '크림 촉촉 진정 크림 재질 저 피부 수분 너무 부족 지성 분 바리기 괜찮 같 습니다',
#   '아침 급하 준비 사용 부담 없 어요',
#   '냄새 은은 부담 없이 쓰 같 어요',
#   '보습 불편 감 없이 네요',
#   '진정 위주 제품 흡수 빠르 보습 너무 없 않 불편 않 어요',
#   '라운드 랩 독 유명 죠',
#   '데일리 쓰 부담 없 어요',
#   '피부 예민 편 잘못 바르 바르 피부 이거 괜찮 어요',
#   '건성 부족 보습 같 복합 성분 볼 좀 건조 같 어요',
#   '자작나무 시리즈 전부 순하 같 피부 부작용 없이 잘 맞 네요',
#   '수분 부족 지성 전혀 안 건조 번들거리 없 어요',
#   '건성 분 여름 괜찮 같 쌀쌀하 때 좀 부족 같 어요',
#   '기존 쓰 제품 쓰 나 특히 면도 후 진정 안 면도 턱 볼 붉 시간 정도 올라오 너무 스트레스 습니다',
#   '건성 피부 보습 위주 자작나무 쓰 쓰 걱정 보습 번들거리 않 정도 있 겨울 동안 바람 붉 올라오 피부 진정 있 같 네요',
#   '촉촉하 위기 ᆸ니다',
#   '얼굴 바르 산뜻 끄 적 짐 덜 너무 어요',
#   '세트 필요 들 있 번 사 한동안 피부 관리 걱정 없 같 네요',
#   '라운드 랩 독도 토너 로션 출시 때 쓰 오 수분 부족 지성',
#   '피부 기름 많 지성인 분 크림 바르 좀 부담 때 있 이거 굉장히 건조 계절 완전 겨울 때 피하 다 잘 쓰 수 있 같 어요',
#   '저 피부 민감 수분 부족 지성 이거 오 쓰 시간 지나 여드름 확실히 진정 많이 되 습니다',
#   '크림 수분 부족 지성 저 지금 시기 사용 적절 같 습니다',
#   '구성 너무 사용 보 불편 없이 잘 쓰 있 어요',
#   '부담 않 바르 습니다',
#   '피부 민감 기초 잘못 바르 따끔거리 피부 트러블 생기 시키 성분 진정 효과 있 무척 마음 들 어요',
#   '평상시 라운드 랩 포맨 수분 라인 사용 었었 역시 진정 라인 데일리 부담 없이 사용 너무 어요',
#   '남성 전용 나오 제품 평상시 잘 안 바르 시 남자분 불편 없이 바르 진정 포커스 맞추 제품 진정 효과 어요',
#   '수분 부족 지성 봄 쓰 구매 어요 가격 싸 품질 어요',
#   '봄 여름 소나무 바르 보 이번 기회 저렴하 가격 모시 오 습니다',
#   '수분 부족 지성 여름 쓰 딱 같 크림 제형 네요',
#   '수분 부족 지성 기준 크림 봄 가을 사용 시 스킨 봄 여름 사용 수 있 제형 ᆸ니다',
#   '저 민감 편 피부 착착 감기 느낌 올라오 반응 없',
#   '피부 예민 걱정 많 사용 생각 기대 되 ᆸ니다',
#   '수분 부족 지성 피부 곧 다가오 봄 여름 가을 위주 사용 같 습니다',
#   '그래도 부족 점 있 점 드립 ᆸ니다',
#   '부담 없이 매일 바르 어요',
#   '여름 걱정 없 같 네요',
#   '덕분 올여름 걱정 없 어요',
#   '바르 나 피부 엄청나 촉촉 느낌 역시 쓰 브랜드 실망 않 네요',
#   '수분 부족 지성 타입 ᆸ니다',
#   '건성 수분 부족 지성 분 다 사용 가능 네요',
#   '로션 같이 사 토너 바르 앰풀 바르 후 크림 로션 좀 섞 쓰 수분 부족 지성 피부 적격',
#   '사은품 보너스 많 구매 후회 없 어요',
#   '수분 부족 피지 많 어 날씨 풀리 때 대비 화장품 찾 중 발견 습니다',
#   '다만 보습 감 있 보습 부족 겨울철 단독 사용 건조 ᆸ니다'],
#  '중립': ['역시 진정 라운드 랩 더라고요',
#   '소나무 추출 팔 미리 바르 보 사용 어요',
#   '군대 가 동생 필요 구매 주 어요',
#   '라운드 랩 라인 쓰 같 어요',
#   '로션 크림 확실히 흡수 빠르 ᆸ니다',
#   '로션 흡수 속도 좀 느리 속 터지 어요',
#   '확실히 붉 기 많이 사라지 네요',
#   'nan',
#   '아토피 민감 극 건성 피부 남동생 피부 관리 보 사 달 직접 올리브 영 매장 가 같이 테스트 구매 습니다',
#   '시원 쿨링 있 끈적이 않 듯 네요',
#   '세트 구성 가성비 완전 짱 에요',
#   '바르 귀찮 대충 바르 자 되 편 대요',
#   '제품 쓰 하도 번들거리 뭐 촉촉 않 리뷰 관하 살림 추천 보 사 사용 느낌 딱 오 습니다',
#   '동생 생일 선물 주 좋아하 네요',
#   '진정 순하 선물 어요',
#   '크림 번 사용 보 세요',
#   '원래 독도 인원 사용 이번 유튜브 보 사 주 정도 쓰 결과 확실히 여드름 없 느끼 습니다',
#   '양 같 가격 대비 적 참 세요',
#   '때문 개 드리 ᆸ니다',
#   '이번 진정 크림 바꾸 피부 자극 덜 오 피부 땅기 없 습니다',
#   '진짜 라운드 랩 다 살 죠',
#   '너무',
#   '바르 자 깨끗 있',
#   '당장 사 버리 세요',
#   '끈적이 없 구성 어요',
#   '세안제 약 알칼리 거품 세안제 일 번 정도 쓰 있 어요',
#   '토너 물 토너 느낌 바르 찝찝 없 막 바르 되 어요',
#   '추천 드리 ᆸ니다',
#   '무 향 무취 보습 피부 진정 음',
#   '세트 참 선물 죠',
#   '진정 같 어요',
#   '무난하 누구 사용 선물 딱 맞 듯 어요',
#   '주 정도 쓰 같 눈 띄 여드름 많이 없 어요',
#   '저 크림 바르 때 여드름 연고 섞 같이 바르 더 효과 같 어요',
#   '남동생 새로 바꾸 사 오 구매 보',
#   '무난 사용 어요',
#   '세일 때 사 괜찮 네요',
#   '하하 애매 ᆸ니다',
#   '민감 피부 차분 만들 주 라운드 랩 소나무 제품 요즘 날씨 제격 에요',
#   '부모 사 드리 순하 괜찮 시 네요',
#   '떨어지 또 사 드리 려고',
#   '아직 토너 쓰 보 행사 때 구매 어요',
#   '죠',
#   '사 어요',
#   '발림 구매 수 있 습니다',
#   '가격 구매 습니다',
#   '진짜 정말 어요',
#   '소 진정 스킨 크림 소나무 진정 스킨 크림 어요',
#   '순하 유명 제품 진정 필요 여드름 피부 쓰 구매 ᆷ 향 소나무 향 나 평범하 어요',
#   '자극 없이 순하 바르 어요',
#   '포맨 이제야 알 자기 전 듬뿍 바르 주 자 아침 피부 너무 열',
#   '원래 라인 토너 로션 쓰 크림 구매 역시 유',
#   '이거 쓰 인생 바뀌 습니다',
#   '역시 놀 코 제닉 나이스',
#   '구매 의사 있 습니다',
#   '관하 살림 추천 구매 어요',
#   '쟁이 두 구매 어요',
#   '아주 습니다',
#   '강력히 추천 ᆸ니다',
#   '매년 쓰 제품 아주 습니다',
#   '남친 어요',
#   '좀 순하 마무릿감 같 어요',
#   '자극 없 어요',
#   '행사 가격 구입 어요',
#   '너무 어요',
#   '또 구매 ᆯ게요',
#   '이거 좀 어요',
#   '저 지성 크림 로션 더 요',
#   '순하 같 은근히 눈 시리 있 구매 안 같 네요',
#   '너무 습니다',
#   '항상 쓰 자작나무 하하 진정 효과 느낌 예민하 사람 강력 추천',
#   '늘 사용 구매 어요',
#   '무척 마음 들 어요',
#   '계속 사용 중 ᆸ니다',
#   '리뷰 구매 보 어요',
#   '쓰 같 습니다',
#   '아버지 사용 시 시 저 고르 드리 습니다',
#   '무난히 같 어요',
#   '안 찌 듯 가리 어요',
#   '남성분 강력히 추천 드리 ᆸ니다',
#   '집 있 돼지 마리 피부 관리 싶 사 주 안 쓰 네요',
#   '번 쓰 보 피부 열 감 내려가 같 어요',
#   '진짜 맨날 쓰 어요',
#   '바르 자 피부 아침 기분 일어나 수 있 어요',
#   '공병 만 개 두셋',
#   '요즘 날씨 서수 분 감 말 땅 화장품 필요 기획전 기간 아이템 획득 네요',
#   '너무 순하 스킨 가능 듯',
#   '자극 없이 순하 스킨 찾 으시 라운드 랩 강력 추천',
#   'THE FACT 기획전 통 저렴하 구매 어요',
#   '행사 상품 저렴하 구매 가성비 네요',
#   '바르 나 끈적이',
#   '저 민감 피부 얼굴 유분 많 분 제품 추천 어요',
#   '자극 없이 순하 확실히 진정 나오 피부 진정 같 어요',
#   '사실 사 전 남성',
#   '피부 자극 없 산뜻 마무리 주 다 쓰 사고 다 쓰 사고 크림 이거 정착 가능 같 정도',
#   '양 너무너무 네요',
#   '순하 촉촉하 습니다',
#   '구매 의사 있 습니다',
#   '크림 번 사 싶 매장 눈 띄 가지 오 되 습니다',
#   '최근 피부 뾰루지 나 여드름 전쟁 었었',
#   '뾰루지 좀 가라앉 병원 처방 약 계속 바르 더 이상 나아지 없 약 바르 부분 계속 각질 일어나 진정 크림 필요 습니다',
#   '연고 나오 바르 그다지 꾸덕꾸덕 않 습니다',
#   '보습 확실히 같 습니다',
#   '지속 있 습니다',
#   '올라오 뾰루지 흔적 점점 가라앉 눈 보이 ᆸ니다 제일 부분',
#   '세트 구성 사용 딱 선물 추천 제품 순하 촉촉 느낌 사용 감 더라고요',
#   '크림 제품 끄 적 없 촉촉 발림 요즘 여름 시원 사용 습니다',
#   '크림 지나치 묽 않 유분 크 않 사용 어요',
#   '구매 습니다',
#   '아주 무난하 쓰 같 어요',
#   '궁금증 해소 번 사 보 만 같 네요',
#   '아직 사용 안 보 어요',
#   '끄 적 없 촉촉하 ᆸ니다',
#   '발림',
#   '바르 동안 때문 확실 않 트러블 없 어요',
#   '너무 찐득 않 적당히 촉촉하 진짜 너무 어요',
#   '토너 좀 바르 찐득찐득 같 크림 정말 네요',
#   '추천',
#   '여름 지성 피부 쓰 습니다',
#   '그냥 소소하 ᆸ니다',
#   '아주 무난하 터 ᆷ 가끔 생각 나 때 찾 같 어요',
#   '오래 쓰 ᆯ게요',
#   '완전 대박 ᆸ니다',
#   '강력히 추천 ᆸ니다',
#   '저 맨날 요것 쓰 어요',
#   '라운드 랩 소나무 토너 크림 세트 구매 어요',
#   '크림 토너에 클렌징 크림 구성 향 강하 않 끈적이 많 않 질 발리 ᆸ니다',
#   '달 양 적 어요',
#   '아끼 쓰 듯',
#   '세안제 용품 제품 비하 너무 어요',
#   '계속 사용 싶 토너 크림 세트 에요',
#   '그냥 사 주 어요',
#   '저렴',
#   '아빠 필요 시 사 드리 어요',
#   '시키 진정 습니다',
#   '남성분 면도 후 애프터셰이브 대신 이거 바르 시 ᆸ쇼 신세계 ᆸ니다',
#   '엄청 피부 때 바르 좀 너무 때 바르 시원하 어요',
#   '여드름 좀 괜찮 같 어요',
#   '구매 의사 있 습니다',
#   '또 구매 어요',
#   '양 작 너무 너무 너무 양 좀 비싸 그거 빼 진짜 아주 어요',
#   '라운드 랩 다음 일 때 조금 더 싸',
#   '주 세요',
#   '구성 마음 들 향 무 향 생각 향 다르 네요',
#   '자극 없이 순하 피부 답답 않 제형 지성 피부 쓰 네요',
#   '남동생 사용 중 데 자극 없이 괜찮 네요',
#   '벌써 토너 통 다 비우 대요',
#   '우우어어앙더 어냐',
#   '특유 남자 기초 화장 냄새 안 나 어요',
#   '저 쓰 보 무 향 유분 없 어요',
#   '민감 피부 사용 후 않 화끈거리 없 어요',
#   '알 동생 선물 너무 또 사 달 어요',
#   '너 사 어요',
#   'nan',
#   '때 클렌징 폼 나오 토너 돌보 주 마지막 진정 크림 번 다 돌보 수 있 어요',
#   '진정 효과 있 구매 어요',
#   '동생 여드름 심 사 주 아직 별다르 효과 없 달 뒤 후기 남기 ᆯ게요',
#   '남친 주 사 었었 주 나 헤어지 어요',
#   '상당히 멋지 사용 딱히 변화 없 무난 같 다',
#   '아빠 사 주 습니다',
#   '올리브 영 너무 비싸 팔 네요',
#   '백 원 차이 쿠폰 못 쓰 넘 아끼 ᆷ',
#   '급하 구매 얼굴 무난하 사용 습니다',
#   '흡수 빠르 되 어요',
#   '진정 빠르 되 무난 쓰 수 있 크림 어요',
#   '추천 ᆸ니다',
#   '남동생 새로 바꾸 사 오 구매 보',
#   '남동생 새로 바꾸 사 오 구매 보',
#   '남동생 새로 바꾸 사 오 구매 보',
#   '스킨 로션 같이 구성 있 기획 꾸러미 진정 용도 나오 피부 관리 어요',
#   '좋아하 네요',
#   '라운드 랩 진정 제품 처음 사용 보 역시 너무 습니다',
#   '처음 쓰 보 보습 진정 습니다',
#   '용량 크 나오 습니다',
#   '이거 아주 너무 너무 습니다',
#   '구매 의사 간호사 약사 판사 검사 있 습니다',
#   '로션 봄 여름 크림 가을 겨울 쓰 딱 같 어요',
#   '너무 습니다',
#   '동생 이것 쓰 피부 몰라보 어요',
#   '오랜만 보 쓰 물어보 요거 더라고요',
#   '소나무 라인 진정 듯 구매 습니다',
#   '자주 쓰 있 습니다',
#   '너무 습니다',
#   '앞 자주 사용 려고요',
#   '스킨 크림 합치 정도 가격',
#   '가격 남동생 사 습니다',
#   '순하 성분 네요',
#   '많이 팔 세요',
#   '여름 쓰 제품 ᆸ니다',
#   '악 건성 사용 좀 건조 감 있 습니다',
#   '꾸덕꾸덕 가 없이 보습 크림 발리 트러블 피부 어요',
#   '순하 발림 추천 ᆸ니다',
#   '군',
#   '진짜 하나 끈적이 않 촉촉하 ᆸ니다',
#   '보습 감 주 산뜻 어요',
#   '보습 크림 봄 쓰 토너 크림 양 많 가격 싸 어요',
#   '강력히 추천 ᆸ니다',
#   '봄 여름 쓰 딱 어요',
#   '저 안 맞 뾰루지 더 나 같 어요',
#   '라운드 랩 소나무 토너 크림 세트 구매 어요',
#   '크림 토너에 클렌징 크림 구성 향 강하 않 끈적이 많 않 질 발리 ᆸ니다',
#   '달 양 적 어요',
#   '아끼 쓰 듯',
#   '피부 엄청나 보들보들 저 좁쌀 좀 효과 보 같 어요',
#   '개발 쓰 중개 쓰 세요',
#   '이거 진짜 개 어요',
#   '매일 쓰 중진 짜개 꼴',
#   '남동생 주 구매 템 에요',
#   '크크 다 쓰 또 사 달 ᆯ래',
#   '너 사 습니다',
#   '후후',
#   '요새 날씨 자극 심하 이거 바르 어요',
#   '세트 들 있 따로 구매 않 되 편하 어요',
#   '토너 크림 기획 품 가격 대비 바르 나 기름 올라오 듯',
#   '토너 바르 크림 바르 피부 촉촉하 느낌 느끼 어요',
#   '이거 말 미백 제거 크림 같이 바르 이거 먼저 바르 토너 바르 피부 마르 느낌 없 어요',
#   '트러블 고생 이거 쓰 아주 기초 라인 아예 이거 다 바꾸 어요',
#   '우리 아빠 아무거 못 쓰 이거 쓰 어요',
#   '크크크 순하 어요',
#   '무 향 남자 그냥 주 쓰 예요',
#   '우리 아빠 진짜 선물 주 냄새나 유분 있 절대 안 쓰 다시 가져가 이거 그냥 쓱쓱 산뜻 시 보 어요',
#   '아빠 사 드리 어요',
#   '기내 같 어요',
#   '비싸 ᆷ',
#   '맨날 운동 애 얼굴 바르 시 주 끈적이 없 좋아하 네요',
#   '남동생 새로 바꾸 사 오 구매 보',
#   '시키 성분 들 있 골 습니다',
#   '크림 로션 살짝 수분 빵빵 데 진짜 진정 팀 진짜 진짜 어요',
#   '무조건 사 쓰 세요',
#   '지성 민감 피부 진짜 습니다',
#   '남동생 사 주 지성 여드름 자국 조금 있 편 ᆸ니다',
#   '남친 주 사 남친 대요',
#   '다만 보습 크림 향 좀 이상 다네요',
#   '그거 외 성분 촉촉 끈적이 않 네요',
#   '하나 안 남 너무 어요',
#   '라운드 랩 포맨 소나무 진정 토너 로션 이거 아주 너무너무 굿 ᆸ니다',
#   '시키 성분 트러블 보살핌 효과 거의 없 좀 어요',
#   '순하 촉촉 어요',
#   '나름 괜찮 같 어요',
#   '사용 주 지나 트러블 나 시키 크림 찾 도중 세일 구매 보 정력 괜찮 색소 침착 완벽히 점점 연하 보이 ᆸ니다',
#   '더 제품 있 사용 싶 전 계속 쓰 같 습니다',
#   '진정 무난하 자극 없이 사용 어요',
#   '적당히 촉촉하 어요',
#   '여드름 피부 구매 습니다',
#   '오늘 드림 시간 후 집 앞 배송 오 아주 어요',
#   '날 쓰 제품 ᆸ니다',
#   '토너 않 또 너무 적당히 피붓결 정돈 네요',
#   '남동생 새로 바꾸 사 오 구매 보',
#   '여드름 피부 피부 많이 습니다',
#   '얼굴 광 나 어요',
#   '진짜 피부 진정 효과 있 같 어요',
#   '앰풀 같이 사 같이 쓰 진정 확 되 네요',
#   '토너 세안제 크림 전부 다',
#   '이제 이것 쓰 같슺니돠앙',
#   '여드름 피부 어요',
#   '남동생 사 주 무난하 괜찮 네요',
#   '다만 향 무 향 이거 호불호 있 같 어요',
#   '남동생 새로 바꾸 사 오 구매 보',
#   '크림 진정 아주 토너 바르 크림 바르 촉촉하 뽀송 ᆸ니다',
#   '피부 진정 같 듯 ᆸ니다',
#   '보습 크림 너무 않 적당 느낌 ᆸ니다',
#   '달 사용 후기 지성 피부 역시 딱 맞 습니다',
#   '매우 저렴하 가격 구매 기름 많 청소년 피부 가을 겨울 쓰 정말 같 습니다',
#   '무조건 구매 의사 있 어요',
#   '다음 꼭 사 습니다',
#   '아주 대박 ᆸ니다',
#   '건성 민감 피부 ᆸ니다',
#   '거품',
#   '비슷 피부 남 있 습니다',
#   '라운드 랩 포맨 나이스 정원 형 관하 실 짱 만 가지',
#   '사용 감 진정 습니다',
#   '무난 전체 사용 습니다',
#   '남자 기본 아이템 사용 어요',
#   '구성 무척 마음 들 어요',
#   '여드름 많 이번 소나무 라인 다 바꾸 네요',
#   '확실히 여드름 진정 느끼 네요',
#   '라운드 랩 제품 다 바꾸 습니다',
#   '여드름 진정 데일리 바르 편하 ᆸ니다',
#   '정말 남성분 추천 드리 ᆸ니다',
#   '보습 습니다',
#   '주 사용 중 봄 쓰 정말 순하 너무 어요',
#   '가을 겨울 오 전 제품 사용 같 네요',
#   '남자 쓰 너무 어요',
#   '유분 않 수분 채우 주 진정 주',
#   'nan',
#   '아무것 안 바르 이거 바르 괜찮 같 습니다',
#   '어요',
#   '항상 정착 못 이것저것 쓰 이제 이거 정착 같 어요',
#   '세럼 사 증정 쓰 보 괜찮 구매 어요',
#   '트러블 보살핌 진정 단순 보습 크림 정도 괜찮 어요',
#   '스킨 맑 쫀쫀 각질 날리 주 기분 들 로션 않 샤르륵 스며들 트러블 진짜 안 나 네요',
#   '자극 없',
#   '그냥 쓰 라운드 랩 제품 쓰 보 시 같 어요',
#   '클렌징 폼 순화 피부 자극 없 데 정력 괜찮 스킨 크림 스킨 굉장히 묽 산뜻 나오 구멍 별로 깔끔 안 나오 ᆷ',
#   'nan',
#   '크림 꾸덕꾸덕 편 자기 전 듬뿍 올리 두 자 굿',
#   '일단 구성 너무 어요',
#   '포함 제품 봄 쓰 어요',
#   '토너 크림 이루어지 있',
#   '일단 둘 다 사용 꽤 습니다',
#   '흡수력 빠르 어요',
#   '토너 물 흐르 데 바르 흡수 금방 되 얼굴 촉촉하 ᆸ니다',
#   '크림 보습 크림 바르 나 후 유분 거의 없 어요',
#   '토너 로션 크림 셋 다 지성 쓰 같 생각 들 습니다',
#   '피붓결 정리 느낌 앞 요거 정착 어요',
#   '피부 컨디션 따르 로션 크림 번갈 가 쓰 어요',
#   '독도 살 관하 살림 기획 꾸러미 너무 싸 나오 보 지르 습니다',
#   '진짜 산뜻 마무리 나이트 루틴 사용 사 습니다',
#   '습니다',
#   '남자 쓰 미끈거리 않 제형 아주 매일 쓰 어요',
#   '크림 건성 저 좀 쓰 어요',
#   '토너 흡수 빠르 어요',
#   '크림 밤 바르 자 다음 날 촉촉 느낌',
#   '발림 데일리 쓰 어요',
#   '남자 쓰 정말 브랜드',
#   '기존 독도 토너 로션 자작나무 토너 로션 사용 이번 트러블 피부 라인 나오 구매 어요',
#   '선물 사 나쁘 않 어요',
#   '로션 세트 둘 다 구매 봄 가을 크림 세트 여름 로션 세트 가 일반 남성분 딱 맞 으시 같 어요',
#   '요즘 같 계절 크림 세트 너무 습니다',
#   '다음 컬래',
#   '버 꼭 구매 ᆯ게요',
#   '라운드 랩 시 ᆸ쇼',
#   '라운드 랩 소나무 쓰 제품 죠',
#   '세일 바로 구매 어요',
#   '오늘 바로 사용 보 촉촉하 피부 진정 같 어요',
#   '어요',
#   '관리 살 유튜버 보 살 ᆸ니다',
#   '복합 피부 남자 ᆸ니다',
#   '쓰 시 같 습니다',
#   '다 쓰 세일 때 댕기 놓 을게요',
#   'nan',
#   '쓰 보 않 순하 구매 보 어요',
#   '세안제 같이 들 있 이거 세트 하나 있 충분하 같 어요',
#   '바르 나 촉촉하 향 어요',
#   '끈적이 없 순하 습니다',
#   '예민 사람 추천 어요',
#   '너무 순하 촉촉하 어요',
#   '하나 더 추가 구매 어요',
#   '성분 순하 특히 크림 보습 효과 네요',
#   '기존 라운드 랩 제품 사용 있 이번 유튜브 보 구성 소나무 갈아타 보 습니다',
#   '확실히 피부 진정 효과 많이 보 습니다',
#   '평소 조금 틀어지 여드름 홍조 건조 많이 올라오 이번 쓰 많이 잠잠 습니다',
#   '앞 계속 사용 같 어요',
#   '평소 관리 따로 보 적 없 사람 클렌징 및 스킨 돌보 때 제품 피부 맞 모르 습니다',
#   '계절 사용 제품 다 구매 습니다',
#   '다음 이러 기획 기다리 있 습니다',
#   '가격 너무 착하 기분 바로 구매 네요',
#   '크림 아침저녁 바르 일단 촉촉 정말 시원 진정 되 같 추천 ᆸ니다',
#   '진정 너무 어요',
#   '또 금방 흡수 끈적이 하나 없 어요',
#   '다음 또 구매 싶 네요',
#   '시키 진정 라인 금방 트러블 진정 피부 깨끗 만들 주 네요',
#   '구매 의사 있 습니다',
#   '주일 쓰 보 여드름 가라앉 느끼 네요',
#   '통 거의 다 쓰 구매 싶 네요',
#   '다음 또 구매 ᆯ게요',
#   '보습 습니다',
#   '역시 살 라운드 랩 ᆸ니다',
#   '관하 살림 통하 구매 되 확실히 다르 토너 크림 다르 진정 효과 보 습니다',
#   '추가 오 세안제 쫀쫀 씻기 느낌 부가 세안제 쓰',
#   '지성 피부 저 봄 또 뭐 쓰 고민 찰나 합리 가격 올리 주 시 구매 어요',
#   'nan',
#   'nan',
#   '기존 사용 아직 남 사용 전 평 많 빨리 쓰 보 싶 네요',
#   '다시 기회 있 저렴하 가격 품질 화장품 구매 싶 어요',
#   '사용 후 구매 이어지 같 네요',
#   '제품 같 어요',
#   '로션 더 꾸덕꾸덕 급 급히 쌀쌀하 때 자 전 바르 같 어요',
#   '계속 쓰 보 생각 ᆸ니다',
#   '아직 모르 네요',
#   '일주일 쓰 보 진짜 넘 조아여',
#   '피부 짱 ᆷ',
#   '산뜻 좋아하 진짜 좁쌀',
#   '같 들어가 같 어요',
#   '꼭 사',
#   '토너 적당히 촉촉하 순하 각질 제거 성분 들 있 크림 정말 저 같 지성 피부 딱 상품 네요',
#   '관 화살 사랑해 자작나무 계속 쓰 보이 넘어가 너무 네요',
#   '진정 때리 넣 번 쓰 보 계속 사용 예정 ᆸ니다',
#   '수분 적당히 채우 데일리 쓰 무난 네요',
#   '소나무 성분 덕분 진정 어요',
#   '조아욤 트러블 많이 나 스킨 바르 나서 나 같 어요',
#   '그런데 소나무 라인 출시 습니다',
#   '저 지성 남자 피부',
#   '스킨 자극 없 향 없 확 스며들 산뜻 제품 ᆸ니다',
#   '남성분 이거 갈아타 세요',
#   '요즘 갑자기 여드름 올라오 피부 관리 바꾸 보 마침 관 시 정원 시장 올라오 바꾸 보 너무',
#   '사용 아주 평소 라운드 랩 자작나무 시리즈 애용 있 소나무 시리즈 더 여름 유분 많 때 사용 같 네요',
#   '촉촉하 어요',
#   '피부 진정 느낌 에요',
#   '기존 쓰 소나무 토너 크림 세트 거의 다 떨어지 살 고민 중 관하 시 컬래',
#   '버 알 되 구매 보 습니다',
#   '촉촉하 기름 조금 있 습니다',
#   '다음 구매 의사 있 습니다',
#   '사용 양 조절 데 용이하 무엇 가성비 너무 습니다',
#   '마침 스킨 로션 다 떨어지 제품 사 고민 중 가격 제품 구입 되 습니다',
#   '원래 라운드 랩 제품 사용 관하 살림 유튜브 보 바로 구매 습니다',
#   '앞 오래 쓰 같 어요',
#   '뭐 사 고민 남성 추천 ᆸ니다',
#   '바르 보 아주 간편 산뜻 괜찮 더라고요',
#   '더 이용 보 괜찮 계속 쓰 어요',
#   '요즘 뭐 사용 고민 와중 유튜브 영상 보 바로 구매 되 습니다',
#   '정말 추천 제품',
#   '진정 성분 많 같 어요',
#   '평소 관심 있 라운드 랩 소나무 진정 라인 상품 합리 가격 구매 수 있 어요',
#   '사은품 클렌징 폼 너무 구성 습니다',
#   '유튜브 보 구매 습니다',
#   '성분 발림 편 사용 중 에요',
#   '계속 쓰 오 포맨 소나무',
#   '사용 리뷰 ᆸ니다',
#   '가지 제품 다 진정 성분 들어가 있 되게 시원 네요',
#   '로션 크림 모두 습니다',
#   '로션 바르 보습 감 듯 사 듯 크림 촉촉하 발리 ᆸ니다',
#   '둘 다 바르 시간 지나 좀 기름지 느낌 없 습니다',
#   '형 힘내 세요',
#   '저 쓰 약간 건조 면 없 않 괜찮 습니다',
#   '어요',
#   '토너 크림 항상 사용 남 좀 더 쟁이 놓 어요',
#   '로션 같이 사 로션 조금 더 촉촉하 어요',
#   '아끼 놓 겨울 사용 같 어요',
#   '크림 생각 더 더라고요',
#   '여름 쓰 같 제형 비슷 제형 토 진정 크림 비슷하 어요',
#   '크림 끈적 않 보습 챙기 주 습니다',
#   '사용 정도 되 같 어요',
#   '구매 예정 ᆸ니다',
#   '확실히 좀 더 느낌 진정 효과 있 봄 쓰 피부 관리 제품 찾 으시 분 하나 사 쓰 보',
#   '평소 자주 애용 소나무 진정 세트 이번 기회 더 쟁이 놓 어요',
#   '행사 기간 쿠폰 사용 만 원 구매 매우 알차 들 있 놀라 습니다',
#   '원래 쓰 바르 기름 같 많이 올라오 번들거리 이거 없이 어요',
#   '토너 바르 앰풀 바르 크림 바르 더 같 어요',
#   '클렌징 폼 같이 오 헬스장 가 때 들 다니 어요',
#   '로션 같이 사 날 풀리 쓰 보 ᆯ게요',
#   '내보내 관하 살림 통 저렴하 구매 무척 마음 들 ᆸ니다',
#   '특히 지성 피부 끈적 느낌 없 너무 네요',
#   '크림 제품 지성 피부 밤 바르 자 어 안 답답하 어요',
#   '그동안 라운드 랩 자작나무 수분 라인 쓰 보 소나무 진정 라인 처음 쓰 보 습니다',
#   '라운드 랩 항상 쓰 ᆸ니다',
#   '진정 팀 진짜 남성 같 네요',
#   '가격 네요',
#   '관 시 정원 형 덕분 상품 가격 구매 습니다',
#   'nan',
#   '지성 피부 건조 않 유분 많 번들거리 않 너무 네요',
#   '제품 저렴하 가격 구매 수 있 습니다',
#   '기존 사용 비슷 진정 촉촉하 ᆸ니다',
#   '남자 사용 같 어요',
#   '다 쓰 사용 생각 있 습니다',
#   '어요',
#   'nan',
#   '촉촉하 쓰 어요',
#   '타입 쓰 어요',
#   '남친 복합 토너 바르 크림 바르 촉촉하 겨울 좀 건조 편 저녁 촉촉하 더라고요',
#   '순하 유명 곳 역시 맘 들 네요',
#   '저렴하 구매 어요',
#   '촉촉하 습니다',
#   '관하 실 어요',
#   '굿',
#   '인원 로션 편하 바르 었었 얼굴 항상 땅기 더라고',
#   '이번 행사 겸 토너 크림 쓰 보 얼굴 안 땅기 촉촉 느낌 오래 가 정말 습니다',
#   '스킨 크림 세안제 구성 어요',
#   '지성 피부 매번 얼굴 번들거리 피지 때문 고민 많 피부 습니다',
#   '가격 적당 시키 성분 확실히 진정 효과 어요',
#   '끈적이 없 순하 같 어요',
#   '전 사 생각 화장품 바르 나 너무 산뜻 진정 느낌 들 습니다',
#   '화장품 유목민 드디어 정착 네요',
#   '어요',
#   '남편 유튜브 보 알 되 구매 달 더라고요',
#   '꼼꼼히 정독 후 구매 넘 맘 들 네요',
#   '행사 때 구매 가격 매우 맘 들 ᆸ니다',
#   '유튜브 보 사 되 어요',
#   '하하 싸 가격 세트 살 수 있 너무 습니다',
#   '담 또 기획 있 바로 달려오 습니다',
#   'nan',
#   '저 수분 부족 지성 아주 잘 맞 같 습니다',
#   '피붓결 어요',
#   '면도 후 피부 항상 예민하 었었 이거 바르 나 빨리 진정 느낌 에요',
#   '완전 촉촉하 세안제 진짜 순하 너무 어요',
#   '계속 봄 여름 가을 이거 가 같 어요',
#   'nan',
#   '저 찾 제품 ᆸ니다',
#   '습니다',
#   '아주 어요',
#   '앞 라운드 랩 제품 많이 이용 ᆯ게요',
#   '세수 나 개 있 피부 관리 끝 너무 편하 어요',
#   '피부 정말 민감 편 제품 요물 네',
#   '욯 이거 정착 습니다',
#   '자작나무 묽 제형 보습 감 비슷하 같 어요',
#   '좀 더 쓰 비교 보 같 습니다',
#   '상품 너무 진정 너무 같 습니다',
#   '또 사용 싶 네요',
#   '민감 피부 너무 어요',
#   '여드름 피부 트러블 많이 나 데 진정 되 어요',
#   '더 구매 보 어요',
#   '어요',
#   '저 형 적당히 묽 확실히 진정 효과 보이 어요',
#   '진정 붉 기 이만 제품 없 습니다',
#   '너무 기름지 않 어요',
#   '진정 팀 진짜 많이 쓰 보 틔 진정 팀 ᆸ니다',
#   '스킨 앰풀 크림 전부 진정 가져가 그냥 트러블 쏙쏙 들어가 ᆷ',
#   '너무 야비 이제 이거 쓰',
#   '역시 쓰 라운드 랩 ᆸ니다',
#   '기존 라인 더 산뜻 느낌 있 네요',
#   '기름 많 사람 강력히 추천 ᆸ니다',
#   '기름 많 무조건 이거',
#   '봄 사용 쟁이 놓 어요',
#   'nan',
#   '요새 환절기 날씨 변덕 심하 고민 토너 크림 너무 마무리 뽀송 사용 너무 어요',
#   '앞 계속 사용 같 네요',
#   '저 피부 유형 맞 너무 어요',
#   '끈적거리 않 정말 어요',
#   '저렴하 사 같 기분 네요',
#   '통 쓰 너무 고민 찰나 행사 바로 구매 어요',
#   '크림 단독 사용 트러블 바로 하루 만 진정 오 미치 다',
#   '박 싶 토너 같이 사용 주 정말 진정 끝판왕 ᆸ니다',
#   '건성 분 무조건 크림 강력 추천',
#   '정말 하루 만 눈 띄 달라지 ᆸ니다',
#   '지금 진정 다 쓰 보 이만큼 바로 확실 효과 보이 처음 에요',
#   '꼭 쓰 보',
#   '배송 빠르 어요',
#   '지금 날씨 쓰 어요',
#   '복합 건성 분 로션 쓰 진정 굿 속 건조 없 어요',
#   '저 건성 트러블 흔적 자주 남 데 사용 사용 생각 ᆸ니다',
#   '봄 여름 가을 제품 해결 수 있 어요',
#   '토너 크림 같이 있 선물 같 어요',
#   '유용 듯 어요',
#   '일단 가격 너무 착하 성능 어요',
#   '요거 자작 수분 라인 계속 쓰 오 소나무 진정 라인 새로 나오 이번 바꾸 보 어요',
#   '자작 수분 번들거리 편 소나무 진정 좀 더 산뜻 어요',
#   '중복 함지 분 쓰 시 괜찮 같 어요',
#   '크크크',
#   '효과 빠르 시간 피부 진정 주 수분 공급 촉촉하 생기 있 피부 가꾸 주 ᆸ니다',
#   '사용 감 산뜻 사용 피부 끈적이 느끼 않 습니다',
#   '촉촉하 어요',
#   '추천 ᆸ니다',
#   '소나무 라인 진정 죠',
#   '제품 보 중 관하 살림 유튜브 보 진정 특화 있 일단 구매 보',
#   '이제 기초 제품 가지 쭉 사용 생각 ᆸ니다',
#   '원래 쓰 쟁이 놓 어요',
#   '기름 너무 어요',
#   '이만 제품 못 보 ᆷ',
#   '기름 살 세요',
#   '발림 끈적이 없 어요',
#   '트러블 같 있 때 바르 어요',
#   '가격 일단 너무 합리 사용 끈적이 ᆷ',
#   '없이 깔끔 어요',
#   '발림 성 보습 감 산뜻 ᆷ 다 여드름 피부 가지 저 정말 제품 ᆸ니다',
#   '관하 살림 팬 구매 보 어요',
#   '크림 로션 바르 덫 바르 주 더 효과 같 어요',
#   '평소 수분 라인 쓰 이번 기회 통하 가성비 미치 진정 라인 사용 보 확실히 이것 같 네요',
#   'nan',
#   '수분 채우 주 진정 주 느낌 어요',
#   '역시 정원 형님 추천 쓰 ᆸ니다',
#   '이거 쓰 나 올해 여친 생기 나',
#   '너무 어요',
#   '피부 흡수 같 어요',
#   '가격 너무 개 더 구매 어요',
#   'nan',
#   '이번 토너 로션 세트 토너 크림 세트 모두 구매 아직 날 조금 같 어 토너 크림 세트 먼저 사용 보',
#   '가격 만나 보 수 있 네요',
#   '민감 피부 좀 쓰 보 알 같 어요',
#   'nan',
#   '크림 너무 유분 있 않 적당히 있 수분 채우 주 느낌 주 너무 어요',
#   '바르 때 확실히 피부 속 건조 느낌 없이 흡수 빠르 어요',
#   '로션 크림 뭐 피부 위 크림 남 있 느낌 뜨 느낌 뭐 정확히 설명 못하 느낌 전혀 없 어요',
#   'nan',
#   '평소 라운드 랩 제품 이용 었었 이번 관하 살림 덕분 저렴하 가격 구매 수 있 어요',
#   '남동생 피부 신경 쓰 하나 사 주 습니다',
#   '진정 효과 있 네요',
#   '끈적이 ᆷ',
#   '없이 발림 너무',
#   '컬래',
#   '버 너무 어요',
#   '로션 좀 더 산뜻 느낌 크림 조금 더 보습 느끼 어요',
#   '개인 앰풀 같 제품 사용 주 진정 효과 배 작용 같 습니다',
#   '진짜 강력 추천',
#   '확실히 남성 겨냥 만드 쓰 쓰 보이 ᆸ니다',
#   '건성 분 중간 세럼 하나 더 추가 주 시 되 같 습니다',
#   '피부 관리 안 관 화살 영상 보 피부 관심 가지 되 진짜 저 쓰 보 화장품 중 제일 어요',
#   '강력 추천 ᆸ니다',
#   '민감 피부 더 듯 구매 어요',
#   '하하 바르 며칠 지나 트러블 없이 어요',
#   '은은하 나 향 너무 마음 들 어요',
#   '관하 살림 보 진짜 현명 구매 수 있 너무 습니다',
#   '라운드 랩 번창 세요',
#   '라운드 랩 성분 향 은은 바르 유분 없이 촉촉하 사용 감 어요',
#   '군인 리뷰 남기 ᆸ니다',
#   '피부 전역 수 있 습니다',
#   '관 시 정원 형 바로 구매 습니다',
#   '너무 어요',
#   '쓰 라운드 랩 이번 구성 나오 구매 되 어요',
#   '진짜 남자 다 알 쓰 습니다',
#   '관리 살 님 유튜버 보 구매 어요',
#   '근데 저 평소 자작나무 보습 크림 사용 있 소나 무진정 토너 크림 쓰 보 순하 시원하 네요',
#   '효과 계속 사용 예정 ᆸ니다',
#   '요즘 날씨 건조 피부 관리 정말 중요 죠',
#   '스킨 크림 사용 보 어요',
#   '일단 제품 느끼 가격 저렴 포장 깔끔 어요',
#   '대학 가격 중요 제품 예산 내 구매 수 있 너무 어요',
#   '일단 쓰 보 같 복합 건조 때 바르 촉촉하 같 어요',
#   '배송 빠르 습니다',
#   'nan',
#   '봄 여름 사용 구매 습니다',
#   'nan',
#   '역시 라운드 랩 진정 보습 크림 쓰 너무 어요',
#   '상품',
#   '정액 알칼리 자극 없 습니다',
#   '크림 좀 더 따뜻 쓰 네요',
#   '아직 날씨 쌀쌀하 좀 느낌 ᆸ니다',
#   '관리 살 님 추천 영상 보 바로 구매 습니다',
#   '가격 성능 믿기 않 바르 끈적이 않 보습 트러블 부위 진정 느낌 여드름 피부 추천 드리 ᆸ니다',
#   '덕분 피부 광명 찾 습니다',
#   'but 정말 극구 극지 성분 로션 가 시 죠',
#   '수 부지 분 크림 추천',
#   '예전 계절 스킨 로션 상상 안 요즘 많이 배우 구분 살 중 ᆸ니다',
#   '그런데 즐기 보 채널 제품 추천 시즌 주 시 너무 편하 어요',
#   'nan',
#   '합리 가격 구매 습니다',
#   '앞 많 행사 부탁 드리 ᆸ니다',
#   '로션 보습 높 확실히 겨울 쓰 같 어요',
#   '요즘 피부 많이 뒤집어지 고민 토너 진정 쪽 맞추 보 생각 사 습니다',
#   '마침 크림 다 쓰',
#   '시원하 촉촉 사용 감 어요',
#   '진정 크림 처음 쓰 보 엄청 상쾌 산뜻 느낌 요즘 날씨 딱 쓰 크림',
#   '건성 쓰 듯',
#   '남자 쓰 적당 같 어요',
#   '향 진하 않 크림 끈적이 ᆷ',
#   '없이 네요',
#   '소나무 라인 쓰 보 싶 적당 가격 사 너무 어요',
#   '만 원 이상 구매 시 코 팩 증정 아빠 스킨 로션 선물 드리 좋아하 시 네요',
#   '끈적이 없 산뜻 시원 느낌 확실히 남자 쓰 어요',
#   '진정 효과 편 같 습니다',
#   '처음 입문 보 데 가격 적당 바로 구매 습니다',
#   'nan',
#   '날씨 풀리 데일리 쓰 같 어요',
#   '건성 피부 적합 딱 어요',
#   '라운드 랩 제품 이번 처음 너무 네요 가성비 있 어요',
#   '토너 크림 모두 너무 촉촉하 어요',
#   '배송 빠르 어요',
#   '구매 의사 있 습니다',
#   '바르 때 과하 끈적이 않 산뜻 느낌 네요',
#   '민감 피부 저 맞 제품 찾 진정 보습 괜찮 데일리 사용 같 습니다',
#   '제품 너무 괜찮 같 어요',
#   '앞 외출 때 자주 사용 같 어요',
#   '라운드 랩 상품 자주 쓰 오 이번 구매 보 어요',
#   '집 있 군대 화장품 쓰 평범 남자 ᆸ니다',
#   '마지막 예비군 쟁이 두 다 사용 이제 어디 사 중 마침 발견 구매 어요',
#   '용량 있 터 네요',
#   '아무거 쓰 남친 남편 남동생 오라버니 선물 추천',
#   '끈적이 않 발림 어요',
#   '크림 로션 보습 감 더 촉촉하 네요',
#   '쓰 남 아직 사용 않 유명 제품 때문 사용 습니다',
#   '발림 너무 향 맘 들 어요',
#   '지금 날씨 딱 쓰 크림 같 어요',
#   '번 정도 바르 때 답답 않 쓰 어요',
#   '배송 빠르 코 팩 예상 빠르 오 기분 습니다',
#   '스킨 딱 요즘 날씨 쓰 적합 정도 보습 감 채우 주 크림 너무 않 딱 필요 보습 주 사용 너무 어요',
#   'nan',
#   '진정 성분 필요 구매 어요',
#   '끈적이 없 발림 사용 어요',
#   '여드름 보습 크림 구매 습니다',
#   '기존 원래 라운드 랩 쓰 있 이것 사용 보 역시 네요',
#   '소나무 진정 라인 마스크 팩 코 팩 사용 보 었었 자극 적 마음 들 기억 있 어요',
#   '이번 포 지지자 자주 애청 관 살림 내보내 나오 구매 보 습니다',
#   '토너 로션 크림 모두 일단 소나무 진정 시키 이름 걸맞 자극',
#   '오늘 처음 사용 보 괜찮 같 습니다',
#   '크림 발림 어요',
#   '원래 소나무 진정 라인 쓰 있 이번 기획 나오 세트 쟁이 어요',
#   '살 제품 죠',
#   '너무나 유명 소나무 라인 제품 ᆸ니다',
#   '관 시 유튜버 공동 제작 더 구매 ᆸ니다',
#   '이번 유튜브 보 처음 쓰 보 가격 저렴하 효과 다 떨어지 또 쓰 예요',
#   '토너 리뷰 말 자극 없이 쓰 굉장히',
#   '바르 나 시간 좀 지나 기름 많이 분비 없이 괜찮 습니다',
#   '로션 크림 쓰 보 조금 묵직 외출 때 크림 쓰 딱 맞 어요',
#   '가격 싸 습니다',
#   '촉촉 끈적이 없 어요',
#   '세안제 있 이거 필요 없 같 어요',
#   '관하 살림 유튜브 보 바로 구매 습니다',
#   '정말 습니다',
#   '구성 쓰 보 진정 되 끈적이 않 너무 어요',
#   '관리 살 님 유튜브 보 구매 역시 라운드 랩 소나무 라인 쓰 수 있 네요',
#   '크림 다시 구매 계획 기획 덕분 토너 세트 다시금 쓰 보 되 네요',
#   '끈적이 없이 보습 감 점점 피부 정리 가 느낌 들 어요',
#   '덕분 트러블 많이 가라앉 어요',
#   '아직 첫날 사용 애매 이것 ᆸ니다',
#   '원래 소나무 진정 럼 쓰 토너 크림 병행 피부 진정 더욱 효과 같 습니다',
#   '서 크림 라운드 랩 쓰 어요',
#   '안 그래도 피부 건조 크림 사 기회 싸 가 어요',
#   '원래 쓰 제품 얼굴 계속 건조 제품 바꾸 후 계속 촉촉 유지 같 어요',
#   '가격 적당 사용 때 피부 보습 충분 채우 같 어요',
#   '관리 살 유튜브 영상 보 제품 싸 구매 습니다',
#   '원래 포 맨 시리즈 진정 효과 들어가 너무 듯 ᆸ니다',
#   'nan',
#   '유튜브 보고 구성 괜찮 같 주문 어요',
#   '라운드 랩 이미 유명 브랜드 사용 수 있 어요',
#   'nan',
#   '민감 피부 금방 진정 어요',
#   '지금 계절 딱 쓰 느낌',
#   '촉촉하 흡수력 어요',
#   '남편 지성 피부 스킨 크림 세트 되 있 저렴하 사 보 어요',
#   '끈적 없 산뜻 습니다',
#   '민감 피부 정말 순하 쓰 네요',
#   '배송 거의 하루 만 오 같 어요',
#   '일단 데일리 쓰 너무 진정 성분 보 순 확 느끼 더라고',
#   '건성 피부 쓰 되게 어요',
#   '양 많',
#   '관하 살림 영상 보 구매 어요',
#   '너무 어요',
#   '남자 역시 라운드 랩 하하 보습 감 습니다',
#   'nan',
#   '너무 가격 구매 기쁘 ᆸ니다',
#   '토너 흡수력 빠르 진정 수분 채우 주 진짜 습니다',
#   '클렌징 폼 알칼리 자극 마무릿 미치 습니다',
#   '다음 살 의향 있 습니다',
#   '아직 좀 건조 크림 바르 딱 습니다',
#   '이제 배송 오 한동안 쓰 후 리뷰 또 남기 습니다',
#   '피부 진정 탁월하 너무 네요',
#   '일단 토너 먼저 말 민감 피부 안 맞 토너 많 이때 토너 개 쓰 보 보습 감 이것 편 에요',
#   '이거 쓰 저 하루 뒤 바로 효과 보 어요',
#   '지금 일 정도 쓰 네요',
#   '토너 되게 맘 들 네요',
#   '끈적이 없 흡수력 습니다',
#   '다음 토너 같 제품 쓰 같 네요',
#   '건성 아직 건조 봄 쓰 괜찮 같 어요',
#   'nan',
#   '크림 나쁘 않 괜찮 어요',
#   '세안제 여행 가 때 쓰 사용 않 습니다',
#   '쓰 인원 제품 다 쓰 새로 구매 피부 관리 제품 찾 중 유튜버 라운드 랩 기획 상품 내놓 구매 습니다',
#   '크림 세트 로션 세트 둘 다 구매 쟁이 놓 중 에요',
#   '조금 더 쓰 보 구매 의사 있 습니다',
#   '독도 라인 쓰 구매 습니다',
#   '봄 쓰 너무 네요',
#   'nan',
#   '도착 바로 세안 쓰 보 정말 어요',
#   '라운드 랩 자작나무 라인 제품 자주 쓰 진정 제품 번 사 보 ᆸ니다',
#   '원래 라운드 랩 제품 사용 었었 관하 살림 유튜브 올라오 보 바로 사 버리 습니다',
#   '특히 크림 처음 쓰 보 요거 완전 물건 네요',
#   '자극 없이 순하 도전 보 습니다',
#   '라운드 랩 포맨 제품 향 강하 않 은은 어요',
#   '끈적거리 않 사용 어요',
#   '바르 금방 흡수 끈적이 거의 없 번들거리 없 산뜻 어요',
#   '촉촉하 보습 있 당기 않 어요',
#   '또 살 같 어요',
#   '관 시 형 영상 보 바로 지르 습니다',
#   '일주일 못 쓰 보 확실히 느낌 남다르 ᆸ니다',
#   '아직 안 쓰 보 구성 알차 제품 같 어요',
#   '양 많 어요',
#   '겨울 바람 많이 맞 피부 봉기 일으키 토너 크림 토너 패드 쓰 중 지금 피부 아주 또 면도 눈썹 정리 좀 자극 심하 때 바르 주 점점 없어지 체감 되 ᆸ니다',
#   '토너 크림 둘 다 사용 진정 배 빠르 같 어요',
#   '완전 습니다',
#   '편 사용 습니다',
#   '쫀쫀 ᆸ니다',
#   '데일리 사용 같 습니다',
#   '관리 살 유튜버 영상 보 구매',
#   '여자 민감 피부 사용 보 산뜻 너무 어요',
#   '懶',
#   '버전 나오 가격 판매 구매 ᆸ니다',
#   '사 싶 마침 세일 살 ᆸ니다',
#   '사은품 어요',
#   '강력히 추천 ᆸ니다',
#   '로션 크림 둘 다 사 보 사람 ᆸ니다',
#   '토너 묽 조금 손 덜 얼굴 바르 주 시 땅 흐르 않 바르 방법 ᆸ니다',
#   '토너 날아가 제형 피부 부들부들 용도 ᆸ니다',
#   '크림 로션 보습 크림 크림 조금 더 진하 보습 크림 일반 로션 세타필 정도 제형 ᆸ니다',
#   '저 건성 민감 아토피 피부 바르 분 지나 로션 크림 둘 다 속 당김 없 지금 월 건조 기온 로션 살짝 겉 부분 세미 광택 없 습니다',
#   '크림 비단 같 피부 되 ᆸ니다',
#   '관 시 만세 관리 살 만 가지 나이스 습니다',
#   '유명 소나무 라인 구매 습니다',
#   '산뜻 발리 무게 않 남정 저격 제품 같 습니다',
#   '민감 피부 적합 사용 감 에요',
#   '토너 거의 물 같 제형 바르 때 끈적이 아예 없 다',
#   '크림 마찬가지 발림 굉장히 끈적이 없 편 점 유분 감 보습 약하 편',
#   '라운드 랩 포 소나무 토너 크림 사용 보 정말로 효과 더라고요',
#   '토너 순하 산뜻 향 나 사용 어요',
#   '피부 촉촉하 흡수 건조 덜 주 피붓결 어요',
#   '피부 예민 편 따로 자극 느끼 않 사용 수 있 어요',
#   '추천 ᆸ니다',
#   '관하 살림 덕분 정말 제품 싸 가격 쓰 보 네요',
#   '구성 정말 완벽 화장품 성능 아주 어요',
#   '피부 촉촉',
#   '각질 관리 쓰 같 습니다',
#   '이전 사용 제품 사용 감 더 올라가 같 어요',
#   '쓰 라운드 랩 기회 구매 네요',
#   '크림 건조 때 쓰 네요',
#   '유튜버 관리 살 님 영상 올라오 영상 끝나 전 주문 완료 제품',
#   'nan',
#   '하루 종일 마스크 쓰 생활 라운드 랩 제품 바르 진정 금방 되 느낌 없 어요',
#   '가격 사 수 있 어요',
#   '처음 쓰 보 데 또 구매 같 어요',
#   '너무 네요',
#   '토너 크림 세안제 오 토너 너무 어요',
#   '또 구매 싶 네요',
#   '복합 쓰 어요',
#   '너무 어요',
#   '예전 일본 쓰 뭐 ᆫ가 미끄덩 거리 느낌 있 속 당기 이 착 달라붙 네요',
#   '제품 순하 어요',
#   '기존 쓰 제품 다 쓰 가 참 마침 관리 살 님 올리 영상 보 되 네요',
#   '아직 쓰 제품 남 있 사용 보 않 있 습니다',
#   '저렴하 가격 토너 크림 클렌징 폼 수 있 너무 예민하 피부 토너 크림 쓰 자극 없 진정 습니다',
#   '관하 살림 영상 보 남편 주 구매 습니다',
#   '쓰 라운드 랩 길 이번 영상 연구소 나오 보 고민 안 구매 어요',
#   'nan',
#   '유튜버 보 나 관리 좀 구매 지성 피부 확실히 덜 끈적이 흡수 향 다국적 않 괜찮 어요',
#   '다음 에센스 좀 구매 싶 네요',
#   '유튜버 보 구매 피부 만지 질 네요',
#   '싸 보 습니다',
#   '가격 보 고민 안 구매 구매 네요',
#   '구성 가격 너무 착하 토너 크림 라운드 랩 피부 진정 구매 ᆸ니다',
#   '자극 않 로션 비하 보습 조금 더 오래 가 같 어요',
#   '아직 사용 얼마 되 않 여드름 덜 나 같 기분 ᆸ니다',
#   '기존 쓰 제품 아직 남 있 다 쓰 쓰 아직 사용 안 보 어요',
#   '날씨 따뜻 있 지금 피부 관리 바꾸 때 되 생각 때 마침 마음 쏙 들 같 발견 진심 바로 구매 습니다',
#   'nan',
#   '기름지 않 진정 효과 같 어요',
#   '라운드 랩 제품 쓰 오 제품 나오 도전 보 ᆸ니다',
#   '쓰 라운드 래',
#   'nan',
#   '기존 라운드 랩 사용 있 아직 봄 많이 건조 크림 먼저 쓰 있 수분 주 정도 되 습니다',
#   '무조건 구매 각 에요',
#   '여드름 피부 때문 아주 고민 ᆸ니다',
#   '차나무 기름 바르 보 영',
#   '지성 피부 적합 딱 어요',
#   '라운드 랩 제품 항상 사용 브랜드 사용 있 습니다',
#   '없이 산뜻 사용 수 있 어요',
#   '기존 자작나무 시리즈 쓰 있',
#   'nan',
#   '소나무 시리즈 나오 네요',
#   '자작나무 수분 소나무 진정 포커스 맞추 네요',
#   '둥둥',
#   '관리 살 보 구매 어요',
#   '세트 구성 너무',
#   '라운드 랩 소나무 역시 쓰 ᆸ니다',
#   '건성 피부 적합 같 어요',
#   '이거 정말 야무지 ᆸ니다',
#   '진정 순하 깔 없 습니다',
#   'nan',
#   '기초 제품 다 쓰 새로 구입 보 너무 순하 가격 너무 착하 네요',
#   '쓰 소나무 ᆸ니다',
#   '마침 크림 다 떨어지 가격 구매 ᆸ니다',
#   '봄 사용 너무 습니다',
#   '산뜻 발리 느낌 플라시보 효과 모르 붉 기 줄 들 느낌 에요',
#   '막 그렇게 않 발림 습니다',
#   '일단 가격 너무 착하 ᆸ니다',
#   '스킨 크림 클렌징 폼 ml 주 만 원 초중반',
#   '개인 건성 조금 쓰기 엄청 같 은데 남자분 여드름 지성 피부 수분 주기 되게 제품 같 어요',
#   '보습 감 트러블 특화 같 습니다',
#   '토너 진정 크림 바르 확실히 피부 진정 되 네요',
#   '겨울 사용 위하 사 쟁이 두 ᆸ니다',
#   '평소 마음 보 라운드 랩 브랜드 시장 구성 이루 보 고민 없이 구매 습니다',
#   '사 보 습니다',
#   '코 팩 주 구성 알차 네요',
#   '싸 잘 구매 피부 민감 편 화 느낌 없 잘 쓰 있 어요',
#   '전혀 없 산뜻 촉촉하 ᆸ니다',
#   '크림 끄 적 없 봄 여름 사용 너무',
#   '피부 예민 편 자극 않 같 어요',
#   '않 발림 자주 사용 같 습니다',
#   '관 시 형 가 ᆸ니다',
#   '토너 크림 너무 어요',
#   '너무 습니다',
#   '관하 살림 추천 바로 구매 습니다',
#   '겨울 트러블 많이 나 진정 효과 아주 어요',
#   '배송 정말 빨리 오 가성비 주문 같 어요',
#   '원래 쓰 제품 이번 영상 보고 구매 후 쓰 보 복합 사람 쓰 자극 별로 없 괜찮 휴대 같 어요',
#   '이제 막 피부 관리 시작 초보 관리 남자 ᆸ니다',
#   '유튜브 보 사 되 진짜 순하 어요',
#   '세트 사 코 팩 야무지 여성분 마음 습니다',
#   '유튜버 시장 통하 저렴하 가격 습니다',
#   '복합 예민 편 트러블 줄 들 느낌 ᆸ니다',
#   '굿',
#   '자극 없 어요',
#   '토너 보습 감 바르 아주 습니다',
#   '요즘 살짝 건조 같 크림 세트 사 보습 해서 듬뿍 바르 잠자 습니다',
#   '바르 일어나 피부 쫙 진정 느낌 습니다',
#   '마침 토너 다 되어가 봄 오 크림 제품 필요 관하 살림 영상 보 구매 되 습니다',
#   '쓰 라운드 래',
#   '토너 발림 너무 상쾌 느낌 있 습니다',
#   '크림 너무 꾸덕꾸덕 않 딱 어요',
#   '사 습니다',
#   '아직 배송 오 얼마 안 되 사용 적 매우 적 확실하 화장품 디게 네요',
#   '같 어요',
#   'nan',
#   '요새 자꾸 피부 뭐 올라오 정세 사 보 아주 어요',
#   '향 괜찮 보습 진정 느낌 굿 ᆸ니다',
#   '기회 싸 가격 구매 되 습니다',
#   '사용 보 시원하 끈적거리 않 네요',
#   '유튜버 보 구입 보 습니다',
#   '유튜브 보 주문 습니다',
#   '성품 가격 너무 착하 어요',
#   '저 크림 저',
#   '가족 로션 더 다네요',
#   '그냥 막 쓰 습니다',
#   '토너 크림 둘 다 향 과하 않 어요',
#   '끈적 않 크림 바르 자 다음 날 확실히 느낌 들 네요',
#   '끈적이 없 느낌 발림 자극 없 너무 어요',
#   '소나무 진정 앰풀 먼저 입문 쓰 있 세일 소식 달려오 어요',
#   '아직 사용 이틀 촉촉하 진정 너무 네요',
#   '끈적이 않 굉장히 깔끔 발리 네요',
#   '보습 높 않 여름 쓰 듯 ᆸ니다',
#   '겨울 봄 넘어오 느낌 진정 세트 찾 있 마침 너무 구성 구매 습니다',
#   '진정 효과 탁월 네요',
#   '유튜브 보 구매 어요',
#   '기존 라운드 랩 제품 사용 시키 제품 어요',
#   '피부 진정 느낌 어요',
#   '오래 쓰 ᆯ게요',
#   '촉촉 발리 어요',
#   '끈적이 거의 없 습니다',
#   '강력 추천 강력 추천',
#   '건조 시기 시키 제품 쓰 보 수 있 기회 있 네요',
#   '느낌 습니다',
#   '라운드 랩 제품력 관하 살림 구매 습니다',
#   '이번 제품 디자인 깔끔 세련 어요',
#   '향 상쾌 너무 강하 않 발림 흡수 네요',
#   '계속 쓰 보 알 초반 피부 촉촉하 건조 많이 줄어들 어요',
#   '번 만 원 이상 구매 시 상품 호텔 패키지 안 오 습니다',
#   '저녁 배송 문의 곳 없 찾아보 송장 개 문자 사은품 기본 배송지 가 습니다',
#   '이전 주소지 사용 못 같 네요',
#   '더 제품 사용 기한 안 적히 있 네요',
#   '이전 파란색 제품 사용 었었 이제 다 사용 타이밍 저렴하 구매 습니다',
#   '토너 로션 set 같이 구매 로션 크림 확실히 보습 더 네요',
#   '정원 보 지르 습니다',
#   '클렌징 나 토너 크림 한꺼번에 살 수 있 어요',
#   '관 시 짱 너무 가격 너무 제품 획득',
#   '산뜻 사용 짱',
#   '건성 피부 토너 바르 크림 바르 전 확실히 촉촉하 느끼 어요',
#   '이거 다 쓰 또 살',
#   '토너 번 바꾸 쓰 보 확실히 진정 많이 되 같 어요',
#   '크림 아주 무난 같 습니다',
#   '배송 빠르 어요',
#   '흐흐흐 얼른 쓰 보 싶 네요',
#   'nan',
#   '순하 양 넉넉 습니다',
#   '사용 보 앰풀 사 보 네요',
#   '저 피부 수분 부족 지성 피부 저 피부 잘 맞 같 어요',
#   'nan',
#   '바로 구매 습니다',
#   '다음 또 구매 습니다',
#   '며칠 쓰 보 아직 무난하 어요',
#   '진정 굿',
#   '우선 배송 생각 빨리 오 놀라 습니다',
#   '시키 성분 들어가 제품 보 운동 후 자 전 사용 효과 만점 에요',
#   '시간 만 동나 다음 날 다시 물량 확보 주 시 시 겨우 아이템 획득 네요',
#   '관 시 형 가 중 ᆸ니다',
#   '다 피부 되 세요',
#   '토너 크림 세트 구매 습니다',
#   '정착 수 있 같 제품 ᆸ니다',
#   '추천 드리 어요',
#   '매번 라운드 랩 시리즈 나 피부 사용 있 포맨 나오 사용 보 구입 ᆸ니다',
#   '싸 가격 합리 네요',
#   '모공 막 않 정말 크 이점 같 어요',
#   '크림 아무래도 지성 나중 가을 겨울 쓰 어요',
#   '라운드 랩 소나무 토너 너무 사 듯 진정 습니다',
#   '크림 보습 진정 너무나 습니다',
#   '라운드 랩 진짜 너무 제품 습니다',
#   '끈적거리 거의 없 매일 쓰 다니 ᆸ니다',
#   '성분 봄 쓰 너무 순하 ᆸ니다',
#   '배송 빠르 기분 아침 토너 로션 저녁 토너 크림 사용 보 발리 진정 너무 습니다',
#   '일단 배송 굉장히 빨리 오 오늘 바로 쓰 보 괜찮 같 습니다',
#   '구성 품 알차 코 퍅 같이 네요',
#   '진짜 미치 습니다',
#   '이만 제품 없 같 어요',
#   '진정 정말 빠르 날 가 피부 느끼 ᆸ니다',
#   '무조건 강력히 추천 ᆸ니다',
#   '생각 진정 같 확실히 개운 느낌 들 같 어요',
#   '건성 피부 적합 딱 어요',
#   '라운드 랩 제품 이번 처음 너무 네요',
#   '구성 정말 알차 네요',
#   'nan',
#   '토너 촉촉하 어요',
#   '무난 쓰 수 있 어요',
#   '독도 자작나무 등 평소 자주 쓰 라운드 랩 상품',
#   '행사 소나무 제품 구매 어요',
#   '특히 소나무 토너 피부 진정 초점 맞추 민감 피부 사용 가능 크림 끈적이 덜 어요',
#   '역시 쓰 라운드 랩 네요',
#   '제품 쓰 선물 처음 쓰 보 너무 년 쓰 있 어요',
#   '제품 쓰 보 이것 너무 네요',
#   '일단 가격 미치 습니다',
#   '또 자극 진짜 아예 없 듯',
#   '꼭 번 사용 보 시 같 습니다',
#   '어제 배송 오 바로 사용 보 습니다',
#   '평소 라운드 랩 제품 많이 사용 ᆸ니다',
#   '독도 토너 선 크림 패드 등 등 가지 제품 사용 ᆸ니다',
#   '소나무 라인 소나무 앰 풀 소나무 마스크 팩 제품 사용 습니다',
#   '라운드 랩 수분 라인 사용 보 었었 진정 라인 너무 네요',
#   '정말 어요',
#   '피부 하얘지 같 기분 ᆸ니다',
#   '이때 화장품 쓰 이번 소나무 시리즈 쓰 보 확 체감 들 네요',
#   '화장품 싸 가격 수 있 정말 행운 같 습니다',
#   'nan',
#   '로션 세트 사 크림 세트 같이 구매 어요',
#   '너무 너무 어요',
#   '구매 의사 있 습니다',
#   '토너 말 없 크림 남성분 사용 꾸덕꾸덕 않 저 형 같 어요',
#   'nan',
#   '전 쓰 있 가격 사 어요',
#   '지성 분 쓰 같 어요',
#   '끈적 없 습니다',
#   '구매 싶 어요',
#   '사용 보 느끼 점 지성 피부 매우 안성맞춤 생각 ᆸ니다',
#   '크림 로션 중 크림 요즘 같이 약간 쌀쌀 날씨 바르 안성맞춤 세트 생각 ᆸ니다',
#   '저렴하 구매 이번 봄 제품 사용 보 ᆯ게요',
#   '확실히 습니다',
#   '자작나무 라인 편 속하 생각 제품 더 네요',
#   ...]}

# %%
#결과 수 확인
df_name = 'skincare8_crc_df'

if df_name in results_dict:
    # 긍정 항목의 수 출력
    positive_count = len(results_dict[df_name]['긍정'])
    print(f"긍정 항목의 수 for {df_name}: {positive_count}")

    # 부정 항목의 수 출력
    negative_count = len(results_dict[df_name]['부정'])
    print(f"부정 항목의 수 for {df_name}: {negative_count}")

    # 중립 항목의 수 출력
    neutral_count = len(results_dict[df_name]['중립'])
    print(f"중립 항목의 수 for {df_name}: {neutral_count}")

    # 전체 항목의 수 계산 및 출력
    total_count = positive_count + negative_count + neutral_count
    print(f"\n전체 항목의 수 for {df_name}: {total_count}")
else:
    print(f"No results found for {df_name}")
# Out:
# 긍정 항목의 수 for skincare8_crc_df: 666
# 부정 항목의 수 for skincare8_crc_df: 55
# 중립 항목의 수 for skincare8_crc_df: 1340
#
# 전체 항목의 수 for skincare8_crc_df: 2061

# %%
#결과 수 확인
df_name = 'skincare9_crc_df'

if df_name in results_dict:
    # 긍정 항목의 수 출력
    positive_count = len(results_dict[df_name]['긍정'])
    print(f"긍정 항목의 수 for {df_name}: {positive_count}")

    # 부정 항목의 수 출력
    negative_count = len(results_dict[df_name]['부정'])
    print(f"부정 항목의 수 for {df_name}: {negative_count}")

    # 중립 항목의 수 출력
    neutral_count = len(results_dict[df_name]['중립'])
    print(f"중립 항목의 수 for {df_name}: {neutral_count}")

    # 전체 항목의 수 계산 및 출력
    total_count = positive_count + negative_count + neutral_count
    print(f"\n전체 항목의 수 for {df_name}: {total_count}")
else:
    print(f"No results found for {df_name}")
# Out:
# 긍정 항목의 수 for skincare9_crc_df: 627
# 부정 항목의 수 for skincare9_crc_df: 71
# 중립 항목의 수 for skincare9_crc_df: 1584
#
# 전체 항목의 수 for skincare9_crc_df: 2282

# %%
#결과 수 확인
df_name = 'skincare10_crc_df'

if df_name in results_dict:
    # 긍정 항목의 수 출력
    positive_count = len(results_dict[df_name]['긍정'])
    print(f"긍정 항목의 수 for {df_name}: {positive_count}")

    # 부정 항목의 수 출력
    negative_count = len(results_dict[df_name]['부정'])
    print(f"부정 항목의 수 for {df_name}: {negative_count}")

    # 중립 항목의 수 출력
    neutral_count = len(results_dict[df_name]['중립'])
    print(f"중립 항목의 수 for {df_name}: {neutral_count}")

    # 전체 항목의 수 계산 및 출력
    total_count = positive_count + negative_count + neutral_count
    print(f"\n전체 항목의 수 for {df_name}: {total_count}")
else:
    print(f"No results found for {df_name}")
# Out:
# 긍정 항목의 수 for skincare10_crc_df: 626
# 부정 항목의 수 for skincare10_crc_df: 72
# 중립 항목의 수 for skincare10_crc_df: 1543
#
# 전체 항목의 수 for skincare10_crc_df: 2241

# %%
#결과 수 확인
df_name = 'skincare19_crc_df'

if df_name in results_dict:
    # 긍정 항목의 수 출력
    positive_count = len(results_dict[df_name]['긍정'])
    print(f"긍정 항목의 수 for {df_name}: {positive_count}")

    # 부정 항목의 수 출력
    negative_count = len(results_dict[df_name]['부정'])
    print(f"부정 항목의 수 for {df_name}: {negative_count}")

    # 중립 항목의 수 출력
    neutral_count = len(results_dict[df_name]['중립'])
    print(f"중립 항목의 수 for {df_name}: {neutral_count}")

    # 전체 항목의 수 계산 및 출력
    total_count = positive_count + negative_count + neutral_count
    print(f"\n전체 항목의 수 for {df_name}: {total_count}")
else:
    print(f"No results found for {df_name}")
# Out:
# 긍정 항목의 수 for skincare19_crc_df: 104
# 부정 항목의 수 for skincare19_crc_df: 18
# 중립 항목의 수 for skincare19_crc_df: 383
#
# 전체 항목의 수 for skincare19_crc_df: 505

# %%
#결과 수 확인
df_name = 'skincare20_crc_df'

if df_name in results_dict:
    # 긍정 항목의 수 출력
    positive_count = len(results_dict[df_name]['긍정'])
    print(f"긍정 항목의 수 for {df_name}: {positive_count}")

    # 부정 항목의 수 출력
    negative_count = len(results_dict[df_name]['부정'])
    print(f"부정 항목의 수 for {df_name}: {negative_count}")

    # 중립 항목의 수 출력
    neutral_count = len(results_dict[df_name]['중립'])
    print(f"중립 항목의 수 for {df_name}: {neutral_count}")

    # 전체 항목의 수 계산 및 출력
    total_count = positive_count + negative_count + neutral_count
    print(f"\n전체 항목의 수 for {df_name}: {total_count}")
else:
    print(f"No results found for {df_name}")
# Out:
# 긍정 항목의 수 for skincare20_crc_df: 207
# 부정 항목의 수 for skincare20_crc_df: 70
# 중립 항목의 수 for skincare20_crc_df: 744
#
# 전체 항목의 수 for skincare20_crc_df: 1021

# %% [markdown]
# ## 엑셀로 저장하기

# %%
#단품 리스트
import pandas as pd

# 결과를 저장할 경로 설정
output_dir = r"C:\Users\82108\Downloads"

# 각 데이터프레임 처리 및 엑셀 파일로 저장
for df_name in results_dict:
    # 긍정 리스트를 데이터프레임으로 변환 및 저장
    skincare_positive_df = pd.DataFrame({'Text': results_dict[df_name]['긍정']})
    skincare_positive_df.to_excel(f"{output_dir}\{df_name}_positive_list_P.xlsx", index=False) #소나무pine

    # 부정 리스트를 데이터프레임으로 변환 및 저장
    skincare_negative_df = pd.DataFrame({'Text': results_dict[df_name]['부정']})
    skincare_negative_df.to_excel(f"{output_dir}\{df_name}_negative_list_P.xlsx", index=False)

    # 중립 리스트를 데이터프레임으로 변환 및 저장
    #skincare_neutral_df = pd.DataFrame({'Text': results_dict[df_name]['중립']})
    #skincare_neutral_df.to_excel(f"{output_dir}\{df_name}_neutral_list.xlsx", index=False)

    print(f"{df_name} 데이터프레임의 긍정, 부정 리스트가 각각 엑셀 파일로 저장되었습니다.")
# Out:
# skincare8_crc_df 데이터프레임의 긍정, 부정 리스트가 각각 엑셀 파일로 저장되었습니다.
# skincare9_crc_df 데이터프레임의 긍정, 부정 리스트가 각각 엑셀 파일로 저장되었습니다.
# skincare10_crc_df 데이터프레임의 긍정, 부정 리스트가 각각 엑셀 파일로 저장되었습니다.
# skincare19_crc_df 데이터프레임의 긍정, 부정 리스트가 각각 엑셀 파일로 저장되었습니다.
# skincare20_crc_df 데이터프레임의 긍정, 부정 리스트가 각각 엑셀 파일로 저장되었습니다.

# %% [markdown]
# # 소나무 빈도분석

# %% [markdown]
# ## 엑셀파일 불러오기

# %%
import pandas as pd

# 불러올 파일 경로 설정
output_dir = r"C:\Users\82108\Downloads"

# 불러올 데이터프레임 목록
df_names = [
    'skincare8_crc_df',
    'skincare9_crc_df',
    'skincare10_crc_df',
    'skincare19_crc_df',
    'skincare20_crc_df'
]

# 각 데이터프레임 이름별로 데이터를 불러와 개별 변수에 저장
for df_name in df_names:
    # 긍정 리스트 엑셀 파일 불러오기
    positive_df = pd.read_excel(f"{output_dir}\{df_name}_positive_list_P.xlsx")
    positive_var_name = f"{df_name.replace('_df', '')}_positive_list_df"
    globals()[positive_var_name] = positive_df

    # 부정 리스트 엑셀 파일 불러오기
    negative_df = pd.read_excel(f"{output_dir}\{df_name}_negative_list_P.xlsx")
    negative_var_name = f"{df_name.replace('_df', '')}_negative_list_df"
    globals()[negative_var_name] = negative_df

    # 중립 리스트 엑셀 파일 불러오기 (필요한 경우)
    # neutral_df = pd.read_excel(f"{output_dir}\{df_name}_neutral_list.xlsx")
    # neutral_var_name = f"{df_name.replace('_df', '')}_neutral_list_df"
    # globals()[neutral_var_name] = neutral_df

# 예시: skincare12_crc_positive_list_df 출력해보기
print(skincare8_crc_positive_list_df.head())
print(skincare8_crc_negative_list_df.head())
# Out:
#                          Text
# 0    세일 사 건조 잘 주 순하 같 다음 로션 사
# 1               남자 친구 선물 주 어요
# 2  동생 꾸준히 잘 쓰 있 피붓결 좀 정리 같 어요
# 3    남자 친구 선물 사 엄청나 잘 쓰 있 더라고
# 4          진정 굉장히 잘 되 보습 감 어요
#                        Text
# 0               부담 없이 바르 어요
# 1        여드름 걱정 끝 너무 산뜻 습니다
# 2            예민 피부 걱정 괜찮 어요
# 3                    쯧쯧쯧 재앙
# 4  여드름 스트레스 동생 이것 제일 같 사 어요

# %%
#긍정리스트
positive_list_dfs = [skincare8_crc_positive_list_df, 
                     skincare9_crc_positive_list_df, 
                     skincare10_crc_positive_list_df, 
                     skincare19_crc_positive_list_df,
                     skincare20_crc_positive_list_df]
positive_list_dfs
# Out:
# [                             Text
#  0        세일 사 건조 잘 주 순하 같 다음 로션 사
#  1                   남자 친구 선물 주 어요
#  2      동생 꾸준히 잘 쓰 있 피붓결 좀 정리 같 어요
#  3        남자 친구 선물 사 엄청나 잘 쓰 있 더라고
#  4              진정 굉장히 잘 되 보습 감 어요
#  ..                            ...
#  661         유분 싫 남자 친구 로션 사 주 습니다
#  662     발렌타인 기념 남자 친구 선물 구매 구성 어요
#  663               남자 친구 선물 구매 습니다
#  664        모공 쫀쫀 지성 피부 도움 되 같 습니다
#  665  자작나무 수분 라인 잘 쓰 시키 보 너무 기대 네요
#
#  [666 rows x 1 columns],
#                                              Text
#  0                                   아직 잘 쓰 있 습니다
#  1            거품 잘 나 자극 없이 순하 저 사용 때 트러블 올라오 않 어요
#  2                       할인 행사 조금 더 저렴하 구매 수 있 어요
#  3                             요즘 같 날 잘 맞 아이템 ᆸ니다
#  4                                    되게 만족 중 ᆸ니다
#  ..                                           ...
#  622                           생각 효과 기능 아주 뛰어나 어요
#  623  관 화살 봄 여름 가을 추천 시 라운드 랩 자작나무 라인 잘 쓰 있 사 습니다
#  624                평소 쓰 토너 로션 세트 할인 이벤트 쟁이 놓 ᆸ니다
#  625        수분 너무 촉촉하 에누리 판매 기간 때 저렴하 사 너무 만족 ᆸ니다
#  626                                 이벤트 가격 진짜 최고
#
#  [627 rows x 1 columns],
#                           Text
#  0          요즘 같 날 잘 맞 아이템 ᆸ니다
#  1    세일 사 건조 잘 주 순하 같 다음 로션 사
#  2                 되게 만족 중 ᆸ니다
#  3      자주 구매 상품 이번 만족 높 사용 어요
#  4               남자 친구 선물 주 어요
#  ..                        ...
#  621  민감 피부 라운드 랩 항상 잘 쓰 있 습니다
#  622     소나무 제품 민감 피부 듯 기대 ᆸ니다
#  623            적절 가격 잘 구매 습니다
#  624                    감사 ᆸ니다
#  625                  남자 친구 어요
#
#  [626 rows x 1 columns],
#                                                    Text
#  0               여름 사용 너무 은데요 진정 잘 되 팩 닦 자극 없이 수 있 더 어요
#  1                                         뾰루지 많이 개선 네요
#  2                                           시키 덕 피부 기분
#  3                                자극 없 쓰 토너 보습 도움 되 ᆸ니다
#  4    요즘 날씨 뜨거워지 피부과 시술 자극 심하 피부 많이 지침 느낌 지치 피부 휴식 필...
#  ..                                                 ...
#  99               라운드 랩 수분 선 크림 독도 토너 워낙 잘 쓰 오 살 브랜드 에요
#  100                                          잘 쓰 보 ᆯ게요
#  101                                  토너 깔끔 타입 아주 만족 어요
#  102        간혹 피부 열 올라오 울긋불긋 소나무 토너 패드 너무 잘 쓰 토너 구매 습니다
#  103                                      꾸준히 잘 쓰 보 습니다
#
#  [104 rows x 1 columns],
#                                                    Text
#  0                              진정 되 잘 느끼 보습 감 끈적이 않 어요
#  1    진정 효과 뛰어나 모르 유분 있 로션 바르 뒤집어지 항상 로션 고르 힘들 제품 자극...
#  2    번 더 바르 주 보습 짱 진정 잘 되 용량 가족 다 쓰 넉넉 토너 같이 쓰 뾰루지 ...
#  3                                               감사 ᆸ니다
#  4                         여름 얼굴 답답 느낌 싫어하 무난하 잘 쓰 있 어요
#  ..                                                 ...
#  202                                      사용 기한 도움 되 어요
#  203                                 근데 용기 확실히 튜브 편하 어요
#  204                                     순하 성분 항상 만족 어요
#  205                       셀프 눈썹 탈색 피부 다 뒤집어지 잘 쓰 보 ᆯ게요
#  206                                             만족 습니다
#
#  [207 rows x 1 columns]]

# %%
#부정리스트
negative_list_dfs = [skincare8_crc_negative_list_df, 
                     skincare9_crc_negative_list_df, 
                     skincare10_crc_negative_list_df, 
                     skincare19_crc_negative_list_df,
                     skincare20_crc_negative_list_df]
negative_list_dfs
# Out:
# [                                                 Text
#  0                                         부담 없이 바르 어요
#  1                                  여드름 걱정 끝 너무 산뜻 습니다
#  2                                      예민 피부 걱정 괜찮 어요
#  3                                              쯧쯧쯧 재앙
#  4                            여드름 스트레스 동생 이것 제일 같 사 어요
#  5                     토너 진짜 산뜻 지성 수분 부족 지성 둘 다 쓰 같 어요
#  6                         크림 촉촉하 발리 산뜻 마무리 부담 없이 쓰 어요
#  7                       순하 민감 사람 걱정 없이 사용 수 있 제품 같 어요
#  8               달 사용 사용 전 비교 때 여드름 흉터 여드름 나 많이 사라지 어요
#  9                           토너 확실히 수분 부족 지성 지성 분 쓰 어요
#  10                     토너 바르 때 주르르 물 재질 바르 죄게끔 힘들 ᆸ니다
#  11     크림 촉촉 진정 크림 재질 저 피부 수분 너무 부족 지성 분 바리기 괜찮 같 습니다
#  12                                아침 급하 준비 사용 부담 없 어요
#  13                                 냄새 은은 부담 없이 쓰 같 어요
#  14                                      보습 불편 감 없이 네요
#  15                   진정 위주 제품 흡수 빠르 보습 너무 없 않 불편 않 어요
#  16                                       라운드 랩 독 유명 죠
#  17                                      데일리 쓰 부담 없 어요
#  18                       피부 예민 편 잘못 바르 바르 피부 이거 괜찮 어요
#  19                       건성 부족 보습 같 복합 성분 볼 좀 건조 같 어요
#  20                  자작나무 시리즈 전부 순하 같 피부 부작용 없이 잘 맞 네요
#  21                         수분 부족 지성 전혀 안 건조 번들거리 없 어요
#  22                       건성 분 여름 괜찮 같 쌀쌀하 때 좀 부족 같 어요
#  23  기존 쓰 제품 쓰 나 특히 면도 후 진정 안 면도 턱 볼 붉 시간 정도 올라오 너무...
#  24  건성 피부 보습 위주 자작나무 쓰 쓰 걱정 보습 번들거리 않 정도 있 겨울 동안 바...
#  25                                         촉촉하 위기 ᆸ니다
#  26                             얼굴 바르 산뜻 끄 적 짐 덜 너무 어요
#  27                  세트 필요 들 있 번 사 한동안 피부 관리 걱정 없 같 네요
#  28                   라운드 랩 독도 토너 로션 출시 때 쓰 오 수분 부족 지성
#  29  피부 기름 많 지성인 분 크림 바르 좀 부담 때 있 이거 굉장히 건조 계절 완전 겨...
#  30  저 피부 민감 수분 부족 지성 이거 오 쓰 시간 지나 여드름 확실히 진정 많이 되 습니다
#  31                    크림 수분 부족 지성 저 지금 시기 사용 적절 같 습니다
#  32                          구성 너무 사용 보 불편 없이 잘 쓰 있 어요
#  33                                        부담 않 바르 습니다
#  34  피부 민감 기초 잘못 바르 따끔거리 피부 트러블 생기 시키 성분 진정 효과 있 무척...
#  35  평상시 라운드 랩 포맨 수분 라인 사용 었었 역시 진정 라인 데일리 부담 없이 사용...
#  36  남성 전용 나오 제품 평상시 잘 안 바르 시 남자분 불편 없이 바르 진정 포커스 맞...
#  37                      수분 부족 지성 봄 쓰 구매 어요 가격 싸 품질 어요
#  38                봄 여름 소나무 바르 보 이번 기회 저렴하 가격 모시 오 습니다
#  39                         수분 부족 지성 여름 쓰 딱 같 크림 제형 네요
#  40     수분 부족 지성 기준 크림 봄 가을 사용 시 스킨 봄 여름 사용 수 있 제형 ᆸ니다
#  41                        저 민감 편 피부 착착 감기 느낌 올라오 반응 없
#  42                          피부 예민 걱정 많 사용 생각 기대 되 ᆸ니다
#  43              수분 부족 지성 피부 곧 다가오 봄 여름 가을 위주 사용 같 습니다
#  44                                그래도 부족 점 있 점 드립 ᆸ니다
#  45                                     부담 없이 매일 바르 어요
#  46                                       여름 걱정 없 같 네요
#  47                                     덕분 올여름 걱정 없 어요
#  48                 바르 나 피부 엄청나 촉촉 느낌 역시 쓰 브랜드 실망 않 네요
#  49                                    수분 부족 지성 타입 ᆸ니다
#  50                           건성 수분 부족 지성 분 다 사용 가능 네요
#  51   로션 같이 사 토너 바르 앰풀 바르 후 크림 로션 좀 섞 쓰 수분 부족 지성 피부 적격
#  52                               사은품 보너스 많 구매 후회 없 어요
#  53             수분 부족 피지 많 어 날씨 풀리 때 대비 화장품 찾 중 발견 습니다
#  54                   다만 보습 감 있 보습 부족 겨울철 단독 사용 건조 ᆸ니다,
#                                                   Text
#  0                                 저 복합 약간 보습 부족 느끼 어요
#  1                                             짜증 나 어요
#  2              예전 다르 로션 바르 피부 많이 안 힘들 소나무 로션 토너 바르 어요
#  3                                          이제 없 불안 어요
#  4   선 크림 바르 화 농성 좁쌀 여드름 많이 올라오 타입 클렌징 후 피부 관리 제품 고...
#  ..                                                ...
#  66                             스킨 부담 없이 바르 향 거의 없 습니다
#  67             피부 원래 민감 피부 최근 트러블 집중 진행 정말 스트레스 많이 어요
#  68                                  여름 부담 없이 잘 사용 습니다
#  69                       피부 예민 편 잘못 바르 바르 피부 이거 괜찮 어요
#  70  매일 아침저녁 바르 발림 너무 평소 뭐 찌 득 발리 로션 참 싫어하 불편 발리 촉촉...
#
#  [71 rows x 1 columns],
#                                                   Text
#  0                                             짜증 나 어요
#  1              예전 다르 로션 바르 피부 많이 안 힘들 소나무 로션 토너 바르 어요
#  2                             향 그윽 소나무 향 피로 확 풀 주 ᆸ니다
#  3                                          이제 없 불안 어요
#  4   선 크림 바르 화 농성 좁쌀 여드름 많이 올라오 타입 클렌징 후 피부 관리 제품 고...
#  ..                                                ...
#  67                                           의심 않 습니다
#  68                                 냄새 은은 부담 없이 쓰 같 어요
#  69                             가격 부담 않 확실히 지성 피부 같 네요
#  70                         진정 작용 있 염증 시켜 들 있 더 기대 ᆸ니다
#  71             평소 피부 자극 금방금방 올라오 스트레스 이번 진정 효과 아주 습니다
#
#  [72 rows x 1 columns],
#                                                   Text
#  0                              화장품 잘못 쓰 뒤집히 순하 진정 습니다
#  1                                           가격 부담 습니다
#  2                        하나 없이 산뜻 마무리 부담 없이 사용 아주 습니다
#  3                                       용량 어서 부족 않 어요
#  4                                            부담 없 습니다
#  5                        수분 부족 지성 복합 지성 피부 강력히 추천 ᆸ니다
#  6                              수분 부족 지성 피부 피부 나 사용 어요
#  7          지성 수분 부족 지성 피부 추천 토너 산뜻 물 토너 달 사용 리뷰 남기 어요
#  8                        자극 없이 순하 진정 되 부담 없이 쓰 수 있 어요
#  9             크크 끈적이 없 산뜻 느낌 복합 수분 부족 지성 모두 가능 시 같 어요
#  10                  라운드 랩 소나무 라인 지성 수분 부족 지성 피부 추천 어요
#  11                수분 부족 지성 유존 당김 있 편 번 닦 내 속 당김 없 더라고
#  12  총평 트러블 지성 수분 부족 지성 분 진정 템 피붓결 템 속 건조 템 찾 으시 추천 어요
#  13                   닦 사용 부담 없이 사용 수 있 순하 자주 손 가 같 어요
#  14                        단계 화 횟수 늘어나 보 토너 소비 빨리 되 어요
#  15                수분 부족 지성 유존 당김 있 편 번 닦 내 속 당김 없 더라고
#  16  총평 트러블 지성 수분 부족 지성 분 진정 템 피붓결 템 속 건조 템 찾 으시 추천 어요
#  17            크크 끈적이 없 산뜻 느낌 복합 수분 부족 지성 모두 가능 시 같 어요,
#                                                   Text
#  0                             없이 순하 제품 수분 부족 지성 피부 추천
#  1                              화장품 잘못 쓰 뒤집히 순하 진정 습니다
#  2                       크림 제형 달리 끈적이 않 많이 도포 부담 없 습니다
#  3                                           이제 병 쓰 어요
#  4                                       진짜 바르 부담 없 어요
#  ..                                                ...
#  65                                   다만 토 출구 좀 불편 습니다
#  66                          개인 펌프 제품 좋아하 짤 용기 불편 더라고요
#  67  소나무 진정 토너 자극 없이 순하 피부 잘 스며들 특히 남녀 모두 공용 사용 부담 ...
#  68               수분 부족 지성 유존 당김 있 편 로션 바르 속 당기 없 더라고요
#  69  총평 트러블 지성 수분 부족 지성 분 진정 템 피붓결 템 속 건조 템 찾 으시 추천 어요
#
#  [70 rows x 1 columns]]

# %% [markdown]
# ## 긍정(30개 추출)

# %%
import pandas as pd
from collections import Counter

positive_list_dfs = [
    ('skincare8_crc_positive_list_df', skincare8_crc_positive_list_df),
    ('skincare9_crc_positive_list_df', skincare9_crc_positive_list_df),
    ('skincare10_crc_positive_list_df', skincare10_crc_positive_list_df),
    ('skincare19_crc_positive_list_df', skincare19_crc_positive_list_df),
    ('skincare20_crc_positive_list_df', skincare20_crc_positive_list_df)
]


positive_list_df_results = []

# 각 데이터프레임을 순차적으로 처리합니다.
for name, df in positive_list_dfs:
    # 텍스트 열에서 단어를 추출하여 리스트로 만듭니다.
    words = df['Text'].str.split().sum()
    
    # 단어 빈도 계산
    words_freq = Counter(words)
    
    # 빈도 데이터를 데이터프레임으로 변환하고 정렬합니다.
    words_freq_df = pd.DataFrame(words_freq.items(), columns=['단어', '빈도']).sort_values(by='빈도', ascending=False).reset_index(drop=True)
    
    # 결과를 리스트에 추가합니다.
    positive_list_df_results.append((name, words_freq_df))

# 각 데이터프레임의 결과를 출력합니다. (예를 들어, 상위 10개 단어를 출력)
for name, positive_list_result_df in positive_list_df_results:
    print(f"{name}의 상위 10개 단어:")
    print(positive_list_result_df.head(10))
    print("\n")
# Out:
# skincare8_crc_positive_list_df의 상위 10개 단어:
#     단어   빈도
# 0    잘  376
# 1    쓰  197
# 2   어요  189
# 3  습니다  184
# 4  ᆸ니다  132
# 5   사용  131
# 6    있  126
# 7    같  112
# 8   피부  111
# 9   구매  110
#
#
# skincare9_crc_positive_list_df의 상위 10개 단어:
#     단어   빈도
# 0    잘  338
# 1   어요  234
# 2    쓰  191
# 3    있  153
# 4   사용  142
# 5  습니다  129
# 6  ᆸ니다  126
# 7   피부  118
# 8    같  115
# 9   만족  104
#
#
# skincare10_crc_positive_list_df의 상위 10개 단어:
#     단어   빈도
# 0    잘  330
# 1   어요  243
# 2    쓰  174
# 3    있  145
# 4   사용  140
# 5  ᆸ니다  122
# 6  습니다  112
# 7    같  111
# 8   피부  110
# 9   진정  102
#
#
# skincare19_crc_positive_list_df의 상위 10개 단어:
#     단어  빈도
# 0    잘  64
# 1   어요  53
# 2    있  36
# 3   사용  31
# 4    쓰  30
# 5   토너  29
# 6   진정  26
# 7   피부  20
# 8    되  17
# 9  습니다  16
#
#
# skincare20_crc_positive_list_df의 상위 10개 단어:
#    단어   빈도
# 0   잘  107
# 1  어요   87
# 2   쓰   60
# 3  로션   58
# 4   있   56
# 5  진정   50
# 6  피부   49
# 7  사용   49
# 8   되   38
# 9   보   35

# %%
# 특정 데이터프레임의 긍정 키워드만 보고 싶다면
def print_keywords_by_name(df_name):
    # 결과 리스트에서 특정 데이터프레임의 이름과 결과를 찾습니다.
    for name, result_df in positive_list_df_results:
        if name == df_name:
            print(f"{name}의 상위 30개 단어:")
            print(result_df.head(30))
            break
    else:
        print(f"{df_name} 데이터프레임을 찾을 수 없습니다.")

print_keywords_by_name('skincare8_crc_positive_list_df')
# Out:
# skincare8_crc_positive_list_df의 상위 30개 단어:
#      단어   빈도
# 0     잘  376
# 1     쓰  197
# 2    어요  189
# 3   습니다  184
# 4   ᆸ니다  132
# 5    사용  131
# 6     있  126
# 7     같  112
# 8    피부  111
# 9    구매  110
# 10    되  107
# 11    보  107
# 12   너무  103
# 13   진정   95
# 14   크림   88
# 15   만족   83
# 16   제품   79
# 17    맞   68
# 18   네요   67
# 19    사   63
# 20   토너   51
# 21    랩   49
# 22   가격   49
# 23  라운드   48
# 24    저   48
# 25   감사   47
# 26    주   47
# 27  이벤트   44
# 28    시   43
# 29   라인   40

# %% [markdown]
# ## 부정(30개추출)

# %%
import pandas as pd
from collections import Counter

negative_list_dfs = [
    ('skincare8_crc_negative_list_df', skincare8_crc_negative_list_df),
    ('skincare9_crc_negative_list_df', skincare9_crc_negative_list_df),
    ('skincare10_crc_negative_list_df', skincare10_crc_negative_list_df),
    ('skincare19_crc_negative_list_df', skincare19_crc_negative_list_df),
    ('skincare20_crc_negative_list_df', skincare20_crc_negative_list_df)
]

negative_list_df_results = []

# 각 데이터프레임을 순차적으로 처리합니다.
for name, df in negative_list_dfs:
    # 텍스트 열에서 단어를 추출하여 리스트로 만듭니다.
    words = df['Text'].str.split().sum()
    
    # 단어 빈도 계산
    words_freq = Counter(words)
    
    # 빈도 데이터를 데이터프레임으로 변환하고 정렬합니다.
    words_freq_df = pd.DataFrame(words_freq.items(), columns=['단어', '빈도']).sort_values(by='빈도', ascending=False).reset_index(drop=True)
    
    # 결과를 리스트에 추가합니다.
    negative_list_df_results.append((name, words_freq_df))

# 각 데이터프레임의 결과를 출력합니다. (예를 들어, 상위 10개 단어를 출력)
for name, negative_list_result_df in negative_list_df_results:
    print(f"{name}의 상위 10개 단어:")
    print(negative_list_result_df.head(10))
    print("\n")
# Out:
# skincare8_crc_negative_list_df의 상위 10개 단어:
#    단어  빈도
# 0  어요  27
# 1  부족  19
# 2  피부  17
# 3   쓰  17
# 4   같  17
# 5  수분  16
# 6  바르  16
# 7  지성  16
# 8  사용  14
# 9   있  11
#
#
# skincare9_crc_negative_list_df의 상위 10개 단어:
#    단어  빈도
# 0  어요  27
# 1  피부  24
# 2   쓰  22
# 3  부담  21
# 4   없  19
# 5  지성  18
# 6   있  17
# 7   않  17
# 8  부족  15
# 9  바르  15
#
#
# skincare10_crc_negative_list_df의 상위 10개 단어:
#    단어  빈도
# 0  어요  31
# 1   쓰  23
# 2  부담  22
# 3  지성  20
# 4   있  19
# 5   않  17
# 6  피부  17
# 7   없  17
# 8   같  14
# 9  부족  14
#
#
# skincare19_crc_negative_list_df의 상위 10개 단어:
#    단어  빈도
# 0  지성  15
# 1  어요  11
# 2  부족  11
# 3  수분  10
# 4   템   6
# 5  추천   5
# 6  사용   5
# 7  피부   5
# 8  부담   5
# 9   없   5
#
#
# skincare20_crc_negative_list_df의 상위 10개 단어:
#    단어  빈도
# 0  부족  30
# 1  어요  27
# 2  지성  26
# 3  수분  20
# 4  바르  19
# 5  로션  19
# 6  사용  18
# 7  피부  17
# 8  부담  17
# 9   않  16

# %%
# 특정 데이터프레임의 부정 키워드만 보고 싶다면
def print_keywords_by_name(df_name):
    # 결과 리스트에서 특정 데이터프레임의 이름과 결과를 찾습니다.
    for name, result_df in negative_list_df_results:
        if name == df_name:
            print(f"{name}의 상위 30개 단어:")
            print(result_df.head(30))
            break
    else:
        print(f"{df_name} 데이터프레임을 찾을 수 없습니다.")

# 예: 'skincare12_crc_negative_list_df'의 상위 30개 단어 출력
print_keywords_by_name('skincare8_crc_negative_list_df')
# Out:
# skincare8_crc_negative_list_df의 상위 30개 단어:
#      단어  빈도
# 0    어요  27
# 1    부족  19
# 2    피부  17
# 3     쓰  17
# 4     같  17
# 5    수분  16
# 6    바르  16
# 7    지성  16
# 8    사용  14
# 9     있  11
# 10   없이  10
# 11   부담   9
# 12    없   9
# 13  습니다   9
# 14   진정   9
# 15   네요   8
# 16   크림   8
# 17   걱정   8
# 18  ᆸ니다   7
# 19    때   7
# 20   보습   7
# 21   너무   7
# 22   여름   6
# 23    분   5
# 24    않   5
# 25   제품   5
# 26   토너   5
# 27  여드름   5
# 28    봄   5
# 29   괜찮   4

# %% [markdown]
# ## 중복제거

# %%
# import pandas as pd

# # 각 스킨케어 데이터프레임의 고유 부정 및 긍정 단어를 저장할 딕셔너리
# skincare_unique_negative_words = {}
# skincare_unique_positive_words = {}

# # negative_list_df_results와 positive_list_df_results가 있다고 가정
# # negative_list_df_results와 positive_list_df_results는 각각 부정, 긍정 단어의 빈도 데이터프레임을 포함하는 리스트입니다.

# # 각 스킨케어 데이터프레임을 순차적으로 처리
# for neg_item, pos_item in zip(negative_list_df_results, positive_list_df_results):
#     neg_name, negative_df = neg_item  # 부정 리스트
#     pos_name, positive_df = pos_item  # 긍정 리스트
    
#     # 부정 및 긍정 프레임의 단어 리스트 추출
#     negative_words = set(negative_df.head(30)['단어'])
#     positive_words = set(positive_df.head(30)['단어'])
    
#     # 중복 단어 필터링 (부정 및 긍정에 공통으로 있는 단어를 제거)
#     common_words = negative_words & positive_words
    
#     # 중복 단어를 제외한 부정 단어 리스트
#     unique_negative_words = [word for word in negative_words if word not in common_words]
    
#     # 중복 단어를 제외한 긍정 단어 리스트
#     unique_positive_words = [word for word in positive_words if word not in common_words]
    
#     # 각 스킨케어 이름에 고유한 부정 및 긍정 단어 리스트를 딕셔너리에 저장
#     skincare_unique_negative_words[neg_name] = unique_negative_words
#     skincare_unique_positive_words[pos_name] = unique_positive_words

# # 예시 출력: 각 스킨케어의 고유 부정 및 긍정 단어 리스트 출력
# for neg_name in skincare_unique_negative_words:
#     print(f"{neg_name}의 고유 부정 단어 리스트:")
#     print(skincare_unique_negative_words[neg_name])
#     print("\n")

# for pos_name in skincare_unique_positive_words:
#     print(f"{pos_name}의 고유 긍정 단어 리스트:")
#     print(skincare_unique_positive_words[pos_name])
#     print("\n")

# %%
#이걸로 해야 word clolud 할 수 있다~
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 각 스킨케어 데이터프레임의 고유 부정 및 긍정 단어를 저장할 딕셔너리
skincare_unique_negative_words = {}
skincare_unique_positive_words = {}

# negative_list_df_results와 positive_list_df_results가 있다고 가정
# negative_list_df_results와 positive_list_df_results는 각각 부정, 긍정 단어의 빈도 데이터프레임을 포함하는 리스트입니다.

# 각 스킨케어 데이터프레임을 순차적으로 처리
for neg_item, pos_item in zip(negative_list_df_results, positive_list_df_results):
    neg_name, negative_df = neg_item  # 부정 리스트
    pos_name, positive_df = pos_item  # 긍정 리스트
    
    # 부정 및 긍정 프레임의 단어 리스트 추출
    negative_words = set(negative_df.head(30)['단어'])
    positive_words = set(positive_df.head(30)['단어'])
    
    # 중복 단어 필터링 (부정 및 긍정에 공통으로 있는 단어를 제거)
    common_words = negative_words & positive_words
    
    # 중복 단어를 제외한 부정/긍정 단어 리스트와 빈도 값 추출
    unique_negative_df = negative_df[negative_df['단어'].isin(negative_words - common_words)]
    unique_positive_df = positive_df[positive_df['단어'].isin(positive_words - common_words)]
    
    # 고유 단어와 빈도를 딕셔너리에 저장 (워드클라우드용 데이터 생성)
    skincare_unique_negative_words[neg_name] = dict(zip(unique_negative_df['단어'], unique_negative_df['빈도']))
    skincare_unique_positive_words[pos_name] = dict(zip(unique_positive_df['단어'], unique_positive_df['빈도']))

# 예시 출력: 각 스킨케어의 고유 부정 및 긍정 단어 리스트 출력
for neg_name in skincare_unique_negative_words:
    print(f"{neg_name}의 고유 부정 단어 리스트:")
    print(skincare_unique_negative_words[neg_name])
    print("\n")

for pos_name in skincare_unique_positive_words:
    print(f"{pos_name}의 고유 긍정 단어 리스트:")
    print(skincare_unique_positive_words[pos_name])
    print("\n")
# Out:
# skincare8_crc_negative_list_df의 고유 부정 단어 리스트:
# {'부족': 19, '수분': 16, '바르': 16, '지성': 16, '없이': 10, '부담': 9, '없': 9, '걱정': 8, '때': 7, '보습': 7, '여름': 6, '분': 5, '않': 5, '여드름': 5, '봄': 5, '괜찮': 4}
#
#
# skincare9_crc_negative_list_df의 고유 부정 단어 리스트:
# {'부담': 21, '없': 19, '지성': 18, '않': 17, '부족': 15, '수분': 12, '없이': 10, '많이': 7, '나': 7, '불편': 6, '정말': 6, '걱정': 6, '여드름': 6}
#
#
# skincare10_crc_negative_list_df의 고유 부정 단어 리스트:
# {'부담': 22, '지성': 20, '않': 17, '없': 17, '부족': 14, '수분': 13, '없이': 11, '여드름': 10, '많이': 8, '산뜻': 7, '걱정': 7, '나': 6}
#
#
# skincare19_crc_negative_list_df의 고유 부정 단어 리스트:
# {'지성': 15, '부족': 11, '수분': 10, '템': 6, '추천': 5, '부담': 5, '없': 5, '없이': 5, '당김': 4, '속': 4, '산뜻': 4, '닦': 3, '복합': 3, '가능': 2, '크크': 2, '끈적이': 2, '모두': 2, '분': 2, '시': 2, '수': 2}
#
#
# skincare20_crc_negative_list_df의 고유 부정 단어 리스트:
# {'부족': 30, '지성': 26, '수분': 20, '부담': 17, '않': 16, '없이': 12, '불편': 12, '제형': 12, '건조': 9, '딱': 7, '때': 6, '템': 6, '번': 6, '좀': 6}
#
#
# skincare8_crc_positive_list_df의 고유 긍정 단어 리스트:
# {'잘': 376, '구매': 110, '되': 107, '보': 107, '만족': 83, '맞': 68, '사': 63, '랩': 49, '가격': 49, '라운드': 48, '저': 48, '감사': 47, '주': 47, '이벤트': 44, '시': 43, '라인': 40}
#
#
# skincare9_crc_positive_list_df의 고유 긍정 단어 리스트:
# {'잘': 338, '만족': 104, '진정': 86, '구매': 77, '되': 76, '남자': 62, '친구': 61, '맞': 47, '선물': 41, '저': 37, '순하': 34, '아주': 32, '소나무': 32}
#
#
# skincare10_crc_positive_list_df의 고유 긍정 단어 리스트:
# {'잘': 330, '만족': 99, '남자': 82, '구매': 80, '친구': 78, '되': 74, '선물': 41, '순하': 40, '맞': 39, '저': 37, '중': 33, '자극': 33}
#
#
# skincare19_crc_positive_list_df의 고유 긍정 단어 리스트:
# {'잘': 64, '쓰': 30, '되': 17, 'ᆸ니다': 15, '라인': 15, '너무': 15, '소나무': 14, '보': 13, '만족': 11, '구매': 11, '맞': 10, '자극': 10, '제품': 9, '장점': 9, '도움': 9, '트러블': 9, '시키': 8, '라운드': 8, '효과': 8, '랩': 8}
#
#
# skincare20_crc_positive_list_df의 고유 긍정 단어 리스트:
# {'잘': 107, '진정': 50, '되': 38, '보': 35, 'ᆸ니다': 30, '소나무': 29, '라운드': 27, '만족': 24, '랩': 24, '흡수': 19, '라인': 17, '효과': 16, '트러블': 16, '안': 16}

# %% [markdown]
# # word cloud

# %%
#부정 단어 딕셔너리들
# skincare_unique_negative_words
#긍정 단어 딕셔너리들
# skincare_unique_positive_words

#병합: 단어와 빈도를 합치고, 같은 단어가 여러 스킨케어 제품에 등장할 경우 빈도를 누적하여 더함


# 부정 단어 리스트 병합
combined_negative_words = {}
for word_dict in skincare_unique_negative_words.values():
    for word, freq in word_dict.items():
        if word in combined_negative_words:
            combined_negative_words[word] += freq
        else:
            combined_negative_words[word] = freq

# 긍정 단어 리스트 병합
combined_positive_words = {}
for word_dict in skincare_unique_positive_words.values():
    for word, freq in word_dict.items():
        if word in combined_positive_words:
            combined_positive_words[word] += freq
        else:
            combined_positive_words[word] = freq

# 결과 출력
print("부정 단어 리스트:")
print(combined_negative_words)

print("\n긍정 단어 리스트:")
print(combined_positive_words)
# Out:
# 부정 단어 리스트:
# {'부족': 89, '수분': 71, '바르': 16, '지성': 95, '없이': 48, '부담': 74, '없': 50, '걱정': 21, '때': 13, '보습': 7, '여름': 6, '분': 7, '않': 55, '여드름': 21, '봄': 5, '괜찮': 4, '많이': 15, '나': 13, '불편': 18, '정말': 6, '산뜻': 11, '템': 12, '추천': 5, '당김': 4, '속': 4, '닦': 3, '복합': 3, '가능': 2, '크크': 2, '끈적이': 2, '모두': 2, '시': 2, '수': 2, '제형': 12, '건조': 9, '딱': 7, '번': 6, '좀': 6}
#
# 긍정 단어 리스트:
# {'잘': 1215, '구매': 278, '되': 312, '보': 155, '만족': 321, '맞': 164, '사': 63, '랩': 81, '가격': 49, '라운드': 83, '저': 122, '감사': 47, '주': 47, '이벤트': 44, '시': 43, '라인': 72, '진정': 136, '남자': 144, '친구': 139, '선물': 82, '순하': 74, '아주': 32, '소나무': 75, '중': 33, '자극': 43, '쓰': 30, 'ᆸ니다': 45, '너무': 15, '제품': 9, '장점': 9, '도움': 9, '트러블': 25, '시키': 8, '효과': 24, '흡수': 19, '안': 16}

# %%
unique_positive_df_sorted = pd.DataFrame(list(combined_positive_words.items()), columns=['단어','빈도'])
unique_negative_df_sorted = pd.DataFrame(list(combined_negative_words.items()), columns=['단어','빈도'])

unique_negative_df_sorted
# Out:
#      단어  빈도
# 0    부족  89
# 1    수분  71
# 2    바르  16
# 3    지성  95
# 4    없이  48
# 5    부담  74
# 6     없  50
# 7    걱정  21
# 8     때  13
# 9    보습   7
# 10   여름   6
# 11    분   7
# 12    않  55
# 13  여드름  21
# 14    봄   5
# 15   괜찮   4
# 16   많이  15
# 17    나  13
# 18   불편  18
# 19   정말   6
# 20   산뜻  11
# 21    템  12
# 22   추천   5
# 23   당김   4
# 24    속   4
# 25    닦   3
# 26   복합   3
# 27   가능   2
# 28   크크   2
# 29  끈적이   2
# 30   모두   2
# 31    시   2
# 32    수   2
# 33   제형  12
# 34   건조   9
# 35    딱   7
# 36    번   6
# 37    좀   6

# %% [markdown]
# ## 부정

# %%
#부정
#불필요한 글자 제거
df_word = unique_negative_df_sorted.drop(index=[2,4,6,8,11,12,15,16,17,19,21,28,30,31,32,35,36,37])
df_word
# Out:
#      단어  빈도
# 0    부족  89
# 1    수분  71
# 3    지성  95
# 5    부담  74
# 7    걱정  21
# 9    보습   7
# 10   여름   6
# 13  여드름  21
# 14    봄   5
# 18   불편  18
# 20   산뜻  11
# 22   추천   5
# 23   당김   4
# 24    속   4
# 25    닦   3
# 26   복합   3
# 27   가능   2
# 29  끈적이   2
# 33   제형  12
# 34   건조   9

# %%
# DataFrame -> Dictionary
dic_word = df_word.set_index('단어').to_dict()['빈도']
dic_word
# Out:
# {'부족': 89,
#  '수분': 71,
#  '지성': 95,
#  '부담': 74,
#  '걱정': 21,
#  '보습': 7,
#  '여름': 6,
#  '여드름': 21,
#  '봄': 5,
#  '불편': 18,
#  '산뜻': 11,
#  '추천': 5,
#  '당김': 4,
#  '속': 4,
#  '닦': 3,
#  '복합': 3,
#  '가능': 2,
#  '끈적이': 2,
#  '제형': 12,
#  '건조': 9}

# %%
# 채택!!
import numpy as np
from wordcloud import WordCloud #워드클라우드 제작 라이브러리
import matplotlib.pyplot as plt  #워드클라우드 시각화 라이브러리

# 워드클라우드에서 각 단어에 적용할 색상을 결정하는 함수
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    # 색조(hue) 지정
    hue_choices = [173,136]    #np.random.randint(50, 100)   # 색상의 기본 톤 hsl(173, 49%, 14%)  hsl(136, 33%, 80%)
    hue = np.random.choice(hue_choices)
    # 채도(saturation) 지정
    saturation_choices = [49,33]
    saturation = np.random.choice(saturation_choices)
    
    # 밝기는 랜덤 범위로 설정
    lightness = np.random.randint(14, 80)   # 사이의 랜덤 밝기
    
    # hsl 형식으로 색상 값을 반환
    return f"hsl({hue}, {saturation}%, {lightness}%)"

font_path=r"C:\대학교\학생성장지원시스템\(탈잉)실무에 가장 많이 쓰는 PPT 디자인\Jalnan.ttf"

#wordcloud 함수 사용
wc = WordCloud(random_state=42,font_path= font_path , width = 400,
               height = 400, background_color = 'white', color_func = color_func )
img_wordcloud = wc.generate_from_frequencies(dic_word)

plt.figure(figsize = (10, 10)) #크기 지정하기
plt.axis('off') #축 없애기
plt.imshow(img_wordcloud) #결과 보여주기
plt.savefig('Skincare_P_negative_wordcloud') #파일 저장

# %% [markdown]
# ## 긍정

# %%
unique_positive_df_sorted
# Out:
#      단어    빈도
# 0     잘  1215
# 1    구매   278
# 2     되   312
# 3     보   155
# 4    만족   321
# 5     맞   164
# 6     사    63
# 7     랩    81
# 8    가격    49
# 9   라운드    83
# 10    저   122
# 11   감사    47
# 12    주    47
# 13  이벤트    44
# 14    시    43
# 15   라인    72
# 16   진정   136
# 17   남자   144
# 18   친구   139
# 19   선물    82
# 20   순하    74
# 21   아주    32
# 22  소나무    75
# 23    중    33
# 24   자극    43
# 25    쓰    30
# 26  ᆸ니다    45
# 27   너무    15
# 28   제품     9
# 29   장점     9
# 30   도움     9
# 31  트러블    25
# 32   시키     8
# 33   효과    24
# 34   흡수    19
# 35    안    16

# %%
#긍정
#불필요한 단어 제거
df_word2 = unique_positive_df_sorted.drop(index=[0,2,3,5,6,7,9,10,12,14,15,21,23,25,26,27,32,35])
df_word2
# Out:
#      단어   빈도
# 1    구매  278
# 4    만족  321
# 8    가격   49
# 11   감사   47
# 13  이벤트   44
# 16   진정  136
# 17   남자  144
# 18   친구  139
# 19   선물   82
# 20   순하   74
# 22  소나무   75
# 24   자극   43
# 28   제품    9
# 29   장점    9
# 30   도움    9
# 31  트러블   25
# 33   효과   24
# 34   흡수   19

# %%
# DataFrame -> Dictionary
dic_word2 = df_word2.set_index('단어').to_dict()['빈도']
dic_word2
# Out:
# {'구매': 278,
#  '만족': 321,
#  '가격': 49,
#  '감사': 47,
#  '이벤트': 44,
#  '진정': 136,
#  '남자': 144,
#  '친구': 139,
#  '선물': 82,
#  '순하': 74,
#  '소나무': 75,
#  '자극': 43,
#  '제품': 9,
#  '장점': 9,
#  '도움': 9,
#  '트러블': 25,
#  '효과': 24,
#  '흡수': 19}

# %%
# 채택!!
import numpy as np
from wordcloud import WordCloud #워드클라우드 제작 라이브러리
import matplotlib.pyplot as plt  #워드클라우드 시각화 라이브러리

# 워드클라우드에서 각 단어에 적용할 색상을 결정하는 함수
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    # 색조(hue) 지정
    hue_choices = [173,136]    #np.random.randint(50, 100)   # 색상의 기본 톤 hsl(173, 49%, 14%)  hsl(136, 33%, 80%)
    hue = np.random.choice(hue_choices)
    # 채도(saturation) 지정
    saturation_choices = [49,33]
    saturation = np.random.choice(saturation_choices)
    
    # 밝기는 랜덤 범위로 설정
    lightness = np.random.randint(14, 80)   # 사이의 랜덤 밝기
    
    # hsl 형식으로 색상 값을 반환
    return f"hsl({hue}, {saturation}%, {lightness}%)"

font_path=r"C:\대학교\학생성장지원시스템\(탈잉)실무에 가장 많이 쓰는 PPT 디자인\Jalnan.ttf"

#wordcloud 함수 사용
wc = WordCloud(random_state=42,font_path= font_path , width = 400,
               height = 400, background_color = 'white', color_func = color_func )
img_wordcloud = wc.generate_from_frequencies(dic_word2)

plt.figure(figsize = (10, 10)) #크기 지정하기
plt.axis('off') #축 없애기
plt.imshow(img_wordcloud) #결과 보여주기
plt.savefig('Skincare_P_positive_wordcloud') #파일 저장
